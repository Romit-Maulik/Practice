# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
tfd = tfp.distributions

# Set seeds
np.random.seed(10)
tf.random.set_seed(10)

from tensorflow.keras.layers import Input, Dense, LSTM, Dropout, Flatten, Reshape
from tensorflow.keras.layers import Conv2D, UpSampling2D, MaxPooling2D, Dropout
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import Model
from tensorflow.keras import backend as K

from sklearn.preprocessing import StandardScaler, MinMaxScaler
tf.keras.backend.set_floatx('float32')

# %%
train_mode = False

# %%
class toy_model(Model):
    def __init__(self,data_tuple,arch_type='baseline',lrate=0.001,num_epochs=1000,eps_range=0.01):
        super(toy_model, self).__init__()

        train_data = data_tuple[0]
        valid_data = data_tuple[1]
        test_data = data_tuple[2]
        
        self.input_train_data = train_data[:,0].reshape(-1,1)
        self.input_valid_data = valid_data[:,0].reshape(-1,1)
        self.input_test_data = test_data[:,0].reshape(-1,1)
        
        self.output_train_data = train_data[:,1].reshape(-1,1)
        self.output_valid_data = valid_data[:,1].reshape(-1,1)
        self.output_test_data = train_data[:,1].reshape(-1,1)

        self.ntrain = self.input_train_data.shape[0]
        self.nvalid = self.input_valid_data.shape[0]
        self.ntest = self.input_test_data.shape[0]
        self.arch_type = arch_type
        self.num_latent = 6

        self.init_architecture_baseline()
        self.train_op = tf.keras.optimizers.Adam(learning_rate=lrate)

        # If adversarial training is used
        self.eps_range = eps_range
        
        # num epochs
        self.num_epochs = num_epochs

    def init_architecture_baseline(self):

        # Define model architecture
        ## Encoder
        self.l1 = Dense(50,activation='relu')

        if self.arch_type == 'baseline':
            self.out = Dense(1,activation='linear')
        
        elif self.arch_type =='mixture' or self.arch_type == 'ensemble' or self.arch_type == 'swa':
            self.out_mean = Dense(1,activation='linear')
            self.out_logvar = Dense(1,activation='linear') #sigma^2

        if self.arch_type == 'dropout':
            self.out = Dense(1,activation='linear')
            self.dropout_layer = Dropout(0.1)
            
        if self.arch_type == 'flipout':
            self.l1 = tfp.layers.DenseFlipout(50, activation='relu')
            self.out_mean = tfp.layers.DenseFlipout(1,activation='linear')
            self.out_logvar = tfp.layers.DenseFlipout(1,activation='linear') #sigma^2
    

    def call_baseline(self,X):

        # Encode
        hh = self.l1(X)
        out = self.out(hh)

        return out

    def call_dropout(self,X):
        
        # Encode
        hh = self.l1(X)
        hh = self.dropout_layer(hh,training=True)
        out = self.out(hh)

        return out
    
    def call_mixture(self,X):

        # Encode
        hh = self.l1(X)
        mean = self.out_mean(hh)
        logvar = self.out_logvar(hh)

        return mean, logvar
    
    def call_flipout(self,X):

        # Encode
        hh = self.l1(X)
        mean = self.out_mean(hh)
        logvar = self.out_logvar(hh)

        return mean, logvar

    # Running the model
    def call(self,X):
        if self.arch_type == 'baseline':
            recon = self.call_baseline(X)
            return recon
        elif self.arch_type =='dropout':
            recon = self.call_dropout(X)
            return recon
        elif self.arch_type =='mixture' or self.arch_type == 'ensemble' or self.arch_type == 'swa':
            recon_mean, recon_logvar = self.call_mixture(X)
            return recon_mean, recon_logvar
        elif self.arch_type == 'flipout':
            recon_mean, recon_logvar = self.call_flipout(X)
            return recon_mean, recon_logvar
    
    # Regular MSE
    def get_loss(self,X,Y):

        if self.arch_type == 'mixture' or self.arch_type == 'ensemble' or self.arch_type == 'swa': # Log likelihood optimization
            op_mean, op_logvar = self.call(X)
            
            op_var = tf.math.exp(op_logvar)
            half_logvar = 0.5*op_logvar
            
            mse = (tf.math.square(op_mean-Y))*0.5/(op_var+K.epsilon())
            loss = tf.reduce_mean(half_logvar+mse)
            
        elif self.arch_type == 'flipout':
            
            loss = self.flipout_loss(X,Y)
            
        else: 

            op = self.call(X)
            loss = tf.reduce_mean(tf.math.square(op-Y))

        return loss
    
    def flipout_loss(self, X, Y):
        
        op_mean, op_logvar = self.call(X)
        op_var = tf.math.exp(op_logvar)
        half_logvar = 0.5*op_logvar

        mse = (tf.math.square(op_mean-Y))*0.5/(op_var+K.epsilon())
        nll = tf.reduce_mean(half_logvar+mse)
        
        loss_kl = tf.reduce_mean(self.losses)
        
        return nll + loss_kl

    # Regular MSE
    def get_adversarial_loss(self,X,X_adv,Y):

        op_mean, op_logvar = self.call(X_adv)
        
        op_var = tf.math.exp(op_logvar)
        half_logvar = 0.5*op_logvar

        mse = tf.math.square(op_mean-Y)*0.5/(op_var+K.epsilon())
        loss = tf.reduce_mean(half_logvar+mse)

        return loss

    # get gradients - regular
    def get_grad(self,X,Y):
        if self.arch_type == 'ensemble':
            # Adversarial training
            X = tf.convert_to_tensor(X)
            with tf.GradientTape() as tape:
                tape.watch(X)
                L = self.get_loss(X,Y)
                g_temp = tape.gradient(L,X)

            with tf.GradientTape() as tape:
                tape.watch(self.trainable_variables)
                X_adv = X + self.eps_range*tf.math.sign(g_temp)
                L_adv = self.get_adversarial_loss(X,X_adv,Y)
                g = tape.gradient(L+L_adv, self.trainable_variables)
        else:
            # Regular training
            with tf.GradientTape() as tape:
                tape.watch(self.trainable_variables)
                L = self.get_loss(X,Y)
                g = tape.gradient(L, self.trainable_variables)            
        
        return g
    
    # perform gradient descent - regular
    def network_learn(self,X,Y):
        g = self.get_grad(X,Y)
        self.train_op.apply_gradients(zip(g, self.trainable_variables))

    # Train the model
    def train_model(self):
        plot_iter = 0
        stop_iter = 0
        patience = 100
        best_valid_loss = np.inf # Some large number 
        swa_iter = 0

        self.num_batches = 1
        self.train_batch_size = int(self.ntrain/self.num_batches)
        self.valid_batch_size = int(self.nvalid/self.num_batches)
        
        for i in range(self.num_epochs):
            # Training loss
            print('Training iteration:',i)
            
            for batch in range(self.num_batches):
                input_batch = self.input_train_data[batch*self.train_batch_size:(batch+1)*self.train_batch_size]
                output_batch = self.output_train_data[batch*self.train_batch_size:(batch+1)*self.train_batch_size]
                self.network_learn(input_batch,output_batch)

            # Validation loss
            valid_loss = 0.0

            for batch in range(self.num_batches):
                input_batch = self.input_valid_data[batch*self.valid_batch_size:(batch+1)*self.valid_batch_size]
                output_batch = self.output_valid_data[batch*self.valid_batch_size:(batch+1)*self.valid_batch_size]
                valid_loss = valid_loss + self.get_loss(input_batch,output_batch).numpy()

            valid_loss = valid_loss/self.nvalid

            # Check early stopping criteria
            if valid_loss < best_valid_loss:
                
                print('Improved validation loss from:',best_valid_loss,' to:', valid_loss)                
                best_valid_loss = valid_loss
                
                if self.arch_type == 'baseline':
                    self.save_weights('./checkpoints/baseline_checkpoint')
                elif self.arch_type == 'dropout':
                    self.save_weights('./checkpoints/dropout_checkpoint')
                elif self.arch_type == 'mixture':
                    self.save_weights('./checkpoints/mixture_checkpoint')
                elif self.arch_type == 'ensemble':
                    self.save_weights('./checkpoints/ensemble_checkpoint')
                elif self.arch_type == 'swa':
                    self.save_weights('./checkpoints/swa_checkpoint')
                elif self.arch_type == 'flipout':
                    self.save_weights('./checkpoints/flipout_checkpoint')
                
                stop_iter = 0
            else:
                print('Validation loss (no improvement):',valid_loss)
                stop_iter = stop_iter + 1

            if stop_iter == patience:
                if self.arch_type == 'swa' and swa_iter < 5:
                    self.save_weights('./checkpoints/swa_checkpoint_'+str(swa_iter))
                    swa_iter +=1
                    
                    stop_iter = 0    
                else:   
                    break
                
    # Load weights
    def restore_model(self):
        if self.arch_type == 'baseline':
            self.load_weights('./checkpoints/baseline_checkpoint')
        elif self.arch_type == 'dropout':
            self.load_weights('./checkpoints/dropout_checkpoint')
        elif self.arch_type == 'mixture':
            self.load_weights('./checkpoints/mixture_checkpoint')
        elif self.arch_type == 'ensemble':
            self.load_weights('./checkpoints/ensemble_checkpoint')
        elif self.arch_type == 'flipout':
            self.load_weights('./checkpoints/flipout_checkpoint')

    # Do some testing
    def model_inference(self,mc_num=100):
        # Restore from checkpoint
        self.restore_model()

        if self.arch_type == 'baseline':

            predictions = self.call(self.input_test_data)
            
            np.save('Baseline_validation.npy',predictions.numpy())
            
            return None

        
        elif self.arch_type == 'dropout':
            
            prediction_list = []
            for i in range(mc_num):
                recon = self.call(self.input_test_data)
                recon = recon.numpy()
                prediction_list.append(recon)

            prediction_list = np.asarray(prediction_list)
            
            np.save('Dropout_validation.npy',prediction_list)
            
            return None
                    
        elif self.arch_type == 'mixture' or self.arch_type == 'ensemble':       

            mean, var = self.call(self.input_test_data)
            mean = mean.numpy()
            var = var.numpy()
            
            np.save(self.arch_type+'_mean_validation.npy',mean)
            np.save(self.arch_type+'_var_validation.npy',var)
            
            return None
        
        elif self.arch_type == 'swa':
            # Average weights - initialization
            self.load_weights('./checkpoints/swa_checkpoint')
            
            mean, logvar = self.call(self.input_test_data)
            mean = mean.numpy()
            var = np.exp(logvar.numpy()) + mean**2
            
            for i in range(5):
                self.load_weights('./checkpoints/swa_checkpoint_'+str(i))
            
                t1, t2 = self.call(self.input_test_data)
                mean = mean + t1.numpy()
                var = var + np.exp(t2.numpy()) + mean**2
                
            ensemble_mean = mean/6.0
            ensemble_var = var/6.0 - ensemble_mean**2
            ensemble_std = np.sqrt(ensemble_var)
            
            np.save('SWA_ensembles_mean_multiple.npy',ensemble_mean)
            np.save('SWA_ensembles_std_multiple.npy',ensemble_std)
            
            return None
        
        elif self.arch_type == 'flipout':
            # Average weights - initialization
            self.load_weights('./checkpoints/flipout_checkpoint')
            
            prediction_list = []
            for i in range(mc_num):
                mean, var = self.call(self.input_test_data)
                mean = mean.numpy()
                              
                prediction_list.append(mean)

            prediction_list = np.asarray(prediction_list)
            
            np.save('Flipout_validation.npy',prediction_list)
            
            return None

# %%
def load_partition_data():
    # Load data
    x = np.random.uniform(low=-4.0,high=4.0,size=(200,1))
    y = x**3 + np.random.normal(0,9)
    
    total_data = np.concatenate((x,y),axis=-1)
    
    train_data = total_data[:40]
    valid_data = total_data[40:60]
    test_data = total_data[60:]

    data_tuple = (train_data, valid_data, test_data)

    return data_tuple

# %%
data_tuple = load_partition_data()
eps_range = 0.01*(np.max(data_tuple[0][:,0])-np.min(data_tuple[0][:,0]))

# %%
baseline_model = toy_model(data_tuple,arch_type='baseline',lrate=0.01,num_epochs=4000,eps_range=eps_range)
if train_mode:
    baseline_model.train_model()
baseline_model.model_inference()
# Load baseline
baseline = np.load('Baseline_validation.npy')

# %%
dropout_model = toy_model(data_tuple,arch_type='dropout',lrate=0.01,num_epochs=4000,eps_range=eps_range)
if train_mode:
    dropout_model.train_model()
dropout_model.model_inference()
# Load dropout
dropout = np.load('Dropout_validation.npy')
dropout_mean = np.mean(dropout,axis=0)
dropout_std = np.std(dropout,axis=0)

# %%
train_mode = True

# %%
flipout_model = toy_model(data_tuple,arch_type='flipout',lrate=0.01,num_epochs=4000,eps_range=eps_range)
if train_mode:
    flipout_model.train_model()
flipout_model.model_inference()
# Load flipout
flipout = np.load('Flipout_validation.npy')
flipout_mean = np.mean(flipout,axis=0)
flipout_std = np.std(flipout,axis=0)
# Out:
# Training iteration: 0
# Improved validation loss from: inf  to: 20.517652893066405
# Training iteration: 1
# Improved validation loss from: 20.517652893066405  to: 17.965107727050782
# Training iteration: 2
# Improved validation loss from: 17.965107727050782  to: 17.85460205078125
# Training iteration: 3
# /home/rmlans/anaconda3/envs/tf2_tfp_env/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py:2281: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Improved validation loss from: 17.85460205078125  to: 16.148684692382812
# Training iteration: 4
# Improved validation loss from: 16.148684692382812  to: 14.579515075683593
# Training iteration: 5
# Improved validation loss from: 14.579515075683593  to: 13.525975036621094
# Training iteration: 6
# Improved validation loss from: 13.525975036621094  to: 11.922164154052734
# Training iteration: 7
# Improved validation loss from: 11.922164154052734  to: 11.579763031005859
# Training iteration: 8
# Improved validation loss from: 11.579763031005859  to: 10.977533721923828
# Training iteration: 9
# Improved validation loss from: 10.977533721923828  to: 10.238905334472657
# Training iteration: 10
# Improved validation loss from: 10.238905334472657  to: 9.253211212158202
# Training iteration: 11
# Improved validation loss from: 9.253211212158202  to: 8.75531234741211
# Training iteration: 12
# Improved validation loss from: 8.75531234741211  to: 8.179708862304688
# Training iteration: 13
# Improved validation loss from: 8.179708862304688  to: 7.6850341796875
# Training iteration: 14
# Improved validation loss from: 7.6850341796875  to: 7.663116455078125
# Training iteration: 15
# Improved validation loss from: 7.663116455078125  to: 7.495487213134766
# Training iteration: 16
# Improved validation loss from: 7.495487213134766  to: 7.082998657226563
# Training iteration: 17
# Improved validation loss from: 7.082998657226563  to: 6.919948577880859
# Training iteration: 18
# Improved validation loss from: 6.919948577880859  to: 6.857730102539063
# Training iteration: 19
# Improved validation loss from: 6.857730102539063  to: 6.608060455322265
# Training iteration: 20
# Improved validation loss from: 6.608060455322265  to: 6.557858276367187
# Training iteration: 21
# Improved validation loss from: 6.557858276367187  to: 6.400064086914062
# Training iteration: 22
# Improved validation loss from: 6.400064086914062  to: 6.374879837036133
# Training iteration: 23
# Improved validation loss from: 6.374879837036133  to: 6.290757369995117
# Training iteration: 24
# Improved validation loss from: 6.290757369995117  to: 6.235789108276367
# Training iteration: 25
# Improved validation loss from: 6.235789108276367  to: 6.207014846801758
# Training iteration: 26
# Improved validation loss from: 6.207014846801758  to: 6.165750122070312
# Training iteration: 27
# Improved validation loss from: 6.165750122070312  to: 6.135150146484375
# Training iteration: 28
# Improved validation loss from: 6.135150146484375  to: 6.087759780883789
# Training iteration: 29
# Improved validation loss from: 6.087759780883789  to: 6.04583854675293
# Training iteration: 30
# Improved validation loss from: 6.04583854675293  to: 6.028897857666015
# Training iteration: 31
# Improved validation loss from: 6.028897857666015  to: 6.011134338378906
# Training iteration: 32
# Improved validation loss from: 6.011134338378906  to: 5.973743057250976
# Training iteration: 33
# Improved validation loss from: 5.973743057250976  to: 5.945424652099609
# Training iteration: 34
# Improved validation loss from: 5.945424652099609  to: 5.932189559936523
# Training iteration: 35
# Improved validation loss from: 5.932189559936523  to: 5.893723678588867
# Training iteration: 36
# Improved validation loss from: 5.893723678588867  to: 5.869660568237305
# Training iteration: 37
# Improved validation loss from: 5.869660568237305  to: 5.856228637695312
# Training iteration: 38
# Improved validation loss from: 5.856228637695312  to: 5.834358215332031
# Training iteration: 39
# Improved validation loss from: 5.834358215332031  to: 5.812245178222656
# Training iteration: 40
# Improved validation loss from: 5.812245178222656  to: 5.799699783325195
# Training iteration: 41
# Improved validation loss from: 5.799699783325195  to: 5.773532485961914
# Training iteration: 42
# Improved validation loss from: 5.773532485961914  to: 5.750876235961914
# Training iteration: 43
# Improved validation loss from: 5.750876235961914  to: 5.7292827606201175
# Training iteration: 44
# Improved validation loss from: 5.7292827606201175  to: 5.707633590698242
# Training iteration: 45
# Improved validation loss from: 5.707633590698242  to: 5.6904243469238285
# Training iteration: 46
# Improved validation loss from: 5.6904243469238285  to: 5.667929458618164
# Training iteration: 47
# Improved validation loss from: 5.667929458618164  to: 5.642258071899414
# Training iteration: 48
# Improved validation loss from: 5.642258071899414  to: 5.623744964599609
# Training iteration: 49
# Improved validation loss from: 5.623744964599609  to: 5.604905319213867
# Training iteration: 50
# Improved validation loss from: 5.604905319213867  to: 5.582660675048828
# Training iteration: 51
# Improved validation loss from: 5.582660675048828  to: 5.564835739135742
# Training iteration: 52
# Improved validation loss from: 5.564835739135742  to: 5.543936157226563
# Training iteration: 53
# Improved validation loss from: 5.543936157226563  to: 5.526055908203125
# Training iteration: 54
# Improved validation loss from: 5.526055908203125  to: 5.502545547485352
# Training iteration: 55
# Improved validation loss from: 5.502545547485352  to: 5.486150741577148
# Training iteration: 56
# Improved validation loss from: 5.486150741577148  to: 5.457561492919922
# Training iteration: 57
# Improved validation loss from: 5.457561492919922  to: 5.438091659545899
# Training iteration: 58
# Improved validation loss from: 5.438091659545899  to: 5.419729614257813
# Training iteration: 59
# Improved validation loss from: 5.419729614257813  to: 5.395903396606445
# Training iteration: 60
# Improved validation loss from: 5.395903396606445  to: 5.374503326416016
# Training iteration: 61
# Improved validation loss from: 5.374503326416016  to: 5.355143356323242
# Training iteration: 62
# Improved validation loss from: 5.355143356323242  to: 5.335336303710937
# Training iteration: 63
# Improved validation loss from: 5.335336303710937  to: 5.31614990234375
# Training iteration: 64
# Improved validation loss from: 5.31614990234375  to: 5.290732574462891
# Training iteration: 65
# Improved validation loss from: 5.290732574462891  to: 5.270526123046875
# Training iteration: 66
# Improved validation loss from: 5.270526123046875  to: 5.25689926147461
# Training iteration: 67
# Improved validation loss from: 5.25689926147461  to: 5.2366798400878904
# Training iteration: 68
# Improved validation loss from: 5.2366798400878904  to: 5.218159103393555
# Training iteration: 69
# Improved validation loss from: 5.218159103393555  to: 5.191286849975586
# Training iteration: 70
# Improved validation loss from: 5.191286849975586  to: 5.167833709716797
# Training iteration: 71
# Improved validation loss from: 5.167833709716797  to: 5.154417419433594
# Training iteration: 72
# Improved validation loss from: 5.154417419433594  to: 5.1257789611816404
# Training iteration: 73
# Improved validation loss from: 5.1257789611816404  to: 5.111165237426758
# Training iteration: 74
# Improved validation loss from: 5.111165237426758  to: 5.089937591552735
# Training iteration: 75
# Improved validation loss from: 5.089937591552735  to: 5.063109970092773
# Training iteration: 76
# Improved validation loss from: 5.063109970092773  to: 5.044099807739258
# Training iteration: 77
# Improved validation loss from: 5.044099807739258  to: 5.028960800170898
# Training iteration: 78
# Improved validation loss from: 5.028960800170898  to: 5.000466918945312
# Training iteration: 79
# Improved validation loss from: 5.000466918945312  to: 4.9884590148925785
# Training iteration: 80
# Improved validation loss from: 4.9884590148925785  to: 4.9633842468261715
# Training iteration: 81
# Improved validation loss from: 4.9633842468261715  to: 4.945902252197266
# Training iteration: 82
# Improved validation loss from: 4.945902252197266  to: 4.9155120849609375
# Training iteration: 83
# Improved validation loss from: 4.9155120849609375  to: 4.89886245727539
# Training iteration: 84
# Improved validation loss from: 4.89886245727539  to: 4.879890060424804
# Training iteration: 85
# Improved validation loss from: 4.879890060424804  to: 4.860514831542969
# Training iteration: 86
# Improved validation loss from: 4.860514831542969  to: 4.846984100341797
# Training iteration: 87
# Improved validation loss from: 4.846984100341797  to: 4.818312072753907
# Training iteration: 88
# Improved validation loss from: 4.818312072753907  to: 4.800811767578125
# Training iteration: 89
# Improved validation loss from: 4.800811767578125  to: 4.782764053344726
# Training iteration: 90
# Improved validation loss from: 4.782764053344726  to: 4.753509521484375
# Training iteration: 91
# Improved validation loss from: 4.753509521484375  to: 4.738970565795898
# Training iteration: 92
# Improved validation loss from: 4.738970565795898  to: 4.711320495605468
# Training iteration: 93
# Improved validation loss from: 4.711320495605468  to: 4.695538711547852
# Training iteration: 94
# Improved validation loss from: 4.695538711547852  to: 4.667928314208984
# Training iteration: 95
# Improved validation loss from: 4.667928314208984  to: 4.653617095947266
# Training iteration: 134
# Improved validation loss from: 3.875428009033203  to: 3.8634376525878906
# Training iteration: 135
# Improved validation loss from: 3.8634376525878906  to: 3.851837158203125
# Training iteration: 136
# Improved validation loss from: 3.851837158203125  to: 3.813861846923828
# Training iteration: 137
# Improved validation loss from: 3.813861846923828  to: 3.789565658569336
# Training iteration: 138
# Improved validation loss from: 3.789565658569336  to: 3.776335906982422
# Training iteration: 139
# Improved validation loss from: 3.776335906982422  to: 3.7533248901367187
# Training iteration: 140
# Improved validation loss from: 3.7533248901367187  to: 3.7433135986328123
# Training iteration: 141
# Improved validation loss from: 3.7433135986328123  to: 3.7260677337646486
# Training iteration: 142
# Improved validation loss from: 3.7260677337646486  to: 3.697544479370117
# Training iteration: 143
# Improved validation loss from: 3.697544479370117  to: 3.6779495239257813
# Training iteration: 144
# Improved validation loss from: 3.6779495239257813  to: 3.6541278839111326
# Training iteration: 145
# Improved validation loss from: 3.6541278839111326  to: 3.639703369140625
# Training iteration: 146
# Improved validation loss from: 3.639703369140625  to: 3.6201026916503904
# Training iteration: 147
# Improved validation loss from: 3.6201026916503904  to: 3.6055534362792967
# Training iteration: 148
# Improved validation loss from: 3.6055534362792967  to: 3.5744441986083983
# Training iteration: 149
# Improved validation loss from: 3.5744441986083983  to: 3.5660480499267577
# Training iteration: 150
# Improved validation loss from: 3.5660480499267577  to: 3.5365226745605467
# Training iteration: 151
# Improved validation loss from: 3.5365226745605467  to: 3.5309684753417967
# Training iteration: 152
# Improved validation loss from: 3.5309684753417967  to: 3.501327896118164
# Training iteration: 153
# Improved validation loss from: 3.501327896118164  to: 3.474562072753906
# Training iteration: 154
# Improved validation loss from: 3.474562072753906  to: 3.4610622406005858
# Training iteration: 155
# Improved validation loss from: 3.4610622406005858  to: 3.435189437866211
# Training iteration: 156
# Improved validation loss from: 3.435189437866211  to: 3.4226425170898436
# Training iteration: 157
# Improved validation loss from: 3.4226425170898436  to: 3.401852035522461
# Training iteration: 158
# Improved validation loss from: 3.401852035522461  to: 3.3775848388671874
# Training iteration: 159
# Validation loss (no improvement): 3.416310501098633
# Training iteration: 160
# Improved validation loss from: 3.3775848388671874  to: 3.3572696685791015
# Training iteration: 161
# Improved validation loss from: 3.3572696685791015  to: 3.339784622192383
# Training iteration: 162
# Improved validation loss from: 3.339784622192383  to: 3.3209991455078125
# Training iteration: 163
# Improved validation loss from: 3.3209991455078125  to: 3.2853431701660156
# Training iteration: 164
# Improved validation loss from: 3.2853431701660156  to: 3.2645301818847656
# Training iteration: 165
# Validation loss (no improvement): 3.267264175415039
# Training iteration: 166
# Improved validation loss from: 3.2645301818847656  to: 3.2285552978515626
# Training iteration: 167
# Improved validation loss from: 3.2285552978515626  to: 3.220742034912109
# Training iteration: 168
# Improved validation loss from: 3.220742034912109  to: 3.1932830810546875
# Training iteration: 169
# Improved validation loss from: 3.1932830810546875  to: 3.1840290069580077
# Training iteration: 170
# Improved validation loss from: 3.1840290069580077  to: 3.1578090667724608
# Training iteration: 171
# Validation loss (no improvement): 3.191485786437988
# Training iteration: 172
# Improved validation loss from: 3.1578090667724608  to: 3.1150108337402345
# Training iteration: 173
# Validation loss (no improvement): 3.1169759750366213
# Training iteration: 174
# Improved validation loss from: 3.1150108337402345  to: 3.0849367141723634
# Training iteration: 175
# Improved validation loss from: 3.0849367141723634  to: 3.0624414443969727
# Training iteration: 176
# Improved validation loss from: 3.0624414443969727  to: 3.0448320388793944
# Training iteration: 177
# Validation loss (no improvement): 3.053165054321289
# Training iteration: 178
# Improved validation loss from: 3.0448320388793944  to: 3.0099937438964846
# Training iteration: 179
# Improved validation loss from: 3.0099937438964846  to: 2.986538887023926
# Training iteration: 180
# Improved validation loss from: 2.986538887023926  to: 2.9717279434204102
# Training iteration: 181
# Improved validation loss from: 2.9717279434204102  to: 2.964577293395996
# Training iteration: 182
# Improved validation loss from: 2.964577293395996  to: 2.9407655715942385
# Training iteration: 183
# Validation loss (no improvement): 2.945476531982422
# Training iteration: 184
# Improved validation loss from: 2.9407655715942385  to: 2.913336181640625
# Training iteration: 185
# Improved validation loss from: 2.913336181640625  to: 2.8723602294921875
# Training iteration: 186
# Validation loss (no improvement): 2.8840137481689454
# Training iteration: 187
# Improved validation loss from: 2.8723602294921875  to: 2.8570919036865234
# Training iteration: 188
# Improved validation loss from: 2.8570919036865234  to: 2.8329307556152346
# Training iteration: 189
# Improved validation loss from: 2.8329307556152346  to: 2.8114034652709963
# Training iteration: 190
# Improved validation loss from: 2.8114034652709963  to: 2.805794906616211
# Training iteration: 191
# Improved validation loss from: 2.805794906616211  to: 2.7739589691162108
# Training iteration: 192
# Validation loss (no improvement): 2.9365921020507812
# Training iteration: 193
# Improved validation loss from: 2.7739589691162108  to: 2.737997055053711
# Training iteration: 194
# Improved validation loss from: 2.737997055053711  to: 2.734822082519531
# Training iteration: 195
# Improved validation loss from: 2.734822082519531  to: 2.7066904067993165
# Training iteration: 196
# Validation loss (no improvement): 2.711004066467285
# Training iteration: 197
# Improved validation loss from: 2.7066904067993165  to: 2.6984737396240233
# Training iteration: 198
# Improved validation loss from: 2.6984737396240233  to: 2.650457191467285
# Training iteration: 199
# Validation loss (no improvement): 2.6549877166748046
# Training iteration: 200
# Improved validation loss from: 2.650457191467285  to: 2.6489326477050783
# Training iteration: 201
# Improved validation loss from: 2.6489326477050783  to: 2.599069023132324
# Training iteration: 202
# Improved validation loss from: 2.599069023132324  to: 2.5982004165649415
# Training iteration: 203
# Improved validation loss from: 2.5982004165649415  to: 2.584072494506836
# Training iteration: 204
# Improved validation loss from: 2.584072494506836  to: 2.552737808227539
# Training iteration: 205
# Improved validation loss from: 2.552737808227539  to: 2.535643196105957
# Training iteration: 206
# Improved validation loss from: 2.535643196105957  to: 2.528373908996582
# Training iteration: 207
# Improved validation loss from: 2.528373908996582  to: 2.515473556518555
# Training iteration: 208
# Improved validation loss from: 2.515473556518555  to: 2.4998374938964845
# Training iteration: 209
# Improved validation loss from: 2.4998374938964845  to: 2.4656686782836914
# Training iteration: 210
# Improved validation loss from: 2.4656686782836914  to: 2.452663230895996
# Training iteration: 211
# Validation loss (no improvement): 2.4546319961547853
# Training iteration: 212
# Improved validation loss from: 2.452663230895996  to: 2.438533401489258
# Training iteration: 213
# Improved validation loss from: 2.438533401489258  to: 2.408162307739258
# Training iteration: 214
# Improved validation loss from: 2.408162307739258  to: 2.3980194091796876
# Training iteration: 215
# Improved validation loss from: 2.3980194091796876  to: 2.3954593658447267
# Training iteration: 216
# Improved validation loss from: 2.3954593658447267  to: 2.3787748336791994
# Training iteration: 217
# Validation loss (no improvement): 2.501349449157715
# Training iteration: 218
# Improved validation loss from: 2.3787748336791994  to: 2.3367128372192383
# Training iteration: 219
# Improved validation loss from: 2.3367128372192383  to: 2.309691619873047
# Training iteration: 220
# Validation loss (no improvement): 2.3143808364868166
# Training iteration: 221
# Improved validation loss from: 2.309691619873047  to: 2.297075653076172
# Training iteration: 222
# Improved validation loss from: 2.297075653076172  to: 2.2631948471069334
# Training iteration: 223
# Improved validation loss from: 2.2631948471069334  to: 2.254429817199707
# Training iteration: 224
# Validation loss (no improvement): 2.3219181060791017
# Training iteration: 225
# Validation loss (no improvement): 2.3724906921386717
# Training iteration: 226
# Improved validation loss from: 2.254429817199707  to: 2.2003597259521483
# Training iteration: 227
# Improved validation loss from: 2.2003597259521483  to: 2.1978551864624025
# Training iteration: 228
# Improved validation loss from: 2.1978551864624025  to: 2.1754776000976563
# Training iteration: 229
# Improved validation loss from: 2.1754776000976563  to: 2.1615293502807615
# Training iteration: 230
# Validation loss (no improvement): 2.2030277252197266
# Training iteration: 231
# Improved validation loss from: 2.1615293502807615  to: 2.1293460845947267
# Training iteration: 232
# Improved validation loss from: 2.1293460845947267  to: 2.120327186584473
# Training iteration: 233
# Improved validation loss from: 2.120327186584473  to: 2.1066909790039063
# Training iteration: 234
# Improved validation loss from: 2.1066909790039063  to: 2.085811996459961
# Training iteration: 235
# Improved validation loss from: 2.085811996459961  to: 2.064959907531738
# Training iteration: 236
# Validation loss (no improvement): 2.0819583892822267
# Training iteration: 237
# Validation loss (no improvement): 2.0759763717651367
# Training iteration: 238
# Improved validation loss from: 2.064959907531738  to: 2.045474815368652
# Training iteration: 239
# Validation loss (no improvement): 2.072657585144043
# Training iteration: 240
# Improved validation loss from: 2.045474815368652  to: 1.9926124572753907
# Training iteration: 241
# Validation loss (no improvement): 2.007736015319824
# Training iteration: 242
# Validation loss (no improvement): 2.0229482650756836
# Training iteration: 243
# Improved validation loss from: 1.9926124572753907  to: 1.9656320571899415
# Training iteration: 244
# Improved validation loss from: 1.9656320571899415  to: 1.9434722900390624
# Training iteration: 245
# Improved validation loss from: 1.9434722900390624  to: 1.9260442733764649
# Training iteration: 246
# Validation loss (no improvement): 1.9429576873779297
# Training iteration: 247
# Improved validation loss from: 1.9260442733764649  to: 1.9167167663574218
# Training iteration: 248
# Improved validation loss from: 1.9167167663574218  to: 1.8980051040649415
# Training iteration: 249
# Improved validation loss from: 1.8980051040649415  to: 1.8664440155029296
# Training iteration: 250
# Validation loss (no improvement): 1.8791847229003906
# Training iteration: 251
# Improved validation loss from: 1.8664440155029296  to: 1.8483808517456055
# Training iteration: 252
# Improved validation loss from: 1.8483808517456055  to: 1.8310838699340821
# Training iteration: 253
# Improved validation loss from: 1.8310838699340821  to: 1.8296424865722656
# Training iteration: 254
# Validation loss (no improvement): 1.8657957077026368
# Training iteration: 255
# Improved validation loss from: 1.8296424865722656  to: 1.7863908767700196
# Training iteration: 256
# Improved validation loss from: 1.7863908767700196  to: 1.784684944152832
# Training iteration: 257
# Validation loss (no improvement): 1.818841552734375
# Training iteration: 258
# Validation loss (no improvement): 1.8141897201538086
# Training iteration: 259
# Validation loss (no improvement): 1.810948371887207
# Training iteration: 260
# Improved validation loss from: 1.784684944152832  to: 1.7393695831298828
# Training iteration: 261
# Improved validation loss from: 1.7393695831298828  to: 1.7390813827514648
# Training iteration: 262
# Validation loss (no improvement): 1.7607189178466798
# Training iteration: 263
# Improved validation loss from: 1.7390813827514648  to: 1.7295339584350586
# Training iteration: 264
# Improved validation loss from: 1.7295339584350586  to: 1.7122783660888672
# Training iteration: 265
# Improved validation loss from: 1.7122783660888672  to: 1.6936594009399415
# Training iteration: 266
# Improved validation loss from: 1.6936594009399415  to: 1.6849164962768555
# Training iteration: 267
# Improved validation loss from: 1.6849164962768555  to: 1.676707649230957
# Training iteration: 268
# Improved validation loss from: 1.676707649230957  to: 1.6518903732299806
# Training iteration: 269
# Improved validation loss from: 1.6518903732299806  to: 1.642142105102539
# Training iteration: 270
# Improved validation loss from: 1.642142105102539  to: 1.6298593521118163
# Training iteration: 271
# Improved validation loss from: 1.6298593521118163  to: 1.6297149658203125
# Training iteration: 272
# Improved validation loss from: 1.6297149658203125  to: 1.5936543464660644
# Training iteration: 273
# Validation loss (no improvement): 1.5950523376464845
# Training iteration: 274
# Validation loss (no improvement): 1.621485137939453
# Training iteration: 275
# Validation loss (no improvement): 1.6074554443359375
# Training iteration: 276
# Improved validation loss from: 1.5936543464660644  to: 1.5754545211791993
# Training iteration: 277
# Improved validation loss from: 1.5754545211791993  to: 1.54233980178833
# Training iteration: 278
# Validation loss (no improvement): 1.5842622756958007
# Training iteration: 279
# Improved validation loss from: 1.54233980178833  to: 1.5288838386535644
# Training iteration: 280
# Improved validation loss from: 1.5288838386535644  to: 1.5253057479858398
# Training iteration: 281
# Improved validation loss from: 1.5253057479858398  to: 1.5122705459594727
# Training iteration: 282
# Improved validation loss from: 1.5122705459594727  to: 1.509335708618164
# Training iteration: 283
# Improved validation loss from: 1.509335708618164  to: 1.486297035217285
# Training iteration: 284
# Validation loss (no improvement): 1.589858627319336
# Training iteration: 285
# Validation loss (no improvement): 1.5063257217407227
# Training iteration: 286
# Validation loss (no improvement): 1.5128596305847168
# Training iteration: 287
# Improved validation loss from: 1.486297035217285  to: 1.4674962997436523
# Training iteration: 288
# Improved validation loss from: 1.4674962997436523  to: 1.4222650527954102
# Training iteration: 289
# Validation loss (no improvement): 2.797617721557617
# Training iteration: 290
# Validation loss (no improvement): 1.644137191772461
# Training iteration: 291
# Validation loss (no improvement): 1.4618876457214356
# Training iteration: 292
# Improved validation loss from: 1.4222650527954102  to: 1.3946522712707519
# Training iteration: 293
# Improved validation loss from: 1.3946522712707519  to: 1.388085174560547
# Training iteration: 294
# Validation loss (no improvement): 1.4461187362670898
# Training iteration: 295
# Validation loss (no improvement): 1.424960231781006
# Training iteration: 296
# Improved validation loss from: 1.388085174560547  to: 1.374619197845459
# Training iteration: 297
# Improved validation loss from: 1.374619197845459  to: 1.3615875244140625
# Training iteration: 298
# Validation loss (no improvement): 1.366946315765381
# Training iteration: 299
# Improved validation loss from: 1.3615875244140625  to: 1.3519733428955079
# Training iteration: 300
# Validation loss (no improvement): 1.4118291854858398
# Training iteration: 301
# Improved validation loss from: 1.3519733428955079  to: 1.3259646415710449
# Training iteration: 302
# Validation loss (no improvement): 1.3444343566894532
# Training iteration: 303
# Improved validation loss from: 1.3259646415710449  to: 1.302937889099121
# Training iteration: 304
# Improved validation loss from: 1.302937889099121  to: 1.2983551979064942
# Training iteration: 305
# Validation loss (no improvement): 1.3403974533081056
# Training iteration: 306
# Validation loss (no improvement): 1.3195470809936523
# Training iteration: 307
# Validation loss (no improvement): 1.3082016944885253
# Training iteration: 308
# Validation loss (no improvement): 1.29931697845459
# Training iteration: 309
# Improved validation loss from: 1.2983551979064942  to: 1.274546241760254
# Training iteration: 310
# Improved validation loss from: 1.274546241760254  to: 1.2745059967041015
# Training iteration: 311
# Improved validation loss from: 1.2745059967041015  to: 1.2624370574951171
# Training iteration: 312
# Improved validation loss from: 1.2624370574951171  to: 1.2519981384277343
# Training iteration: 313
# Validation loss (no improvement): 1.2998414993286134
# Training iteration: 314
# Validation loss (no improvement): 1.327855682373047
# Training iteration: 315
# Validation loss (no improvement): 14.062197875976562
# Training iteration: 316
# Improved validation loss from: 1.2519981384277343  to: 1.2236759185791015
# Training iteration: 317
# Improved validation loss from: 1.2236759185791015  to: 1.2031920433044434
# Training iteration: 318
# Validation loss (no improvement): 1.218660545349121
# Training iteration: 319
# Validation loss (no improvement): 1.2141902923583985
# Training iteration: 320
# Validation loss (no improvement): 1.2139249801635743
# Training iteration: 321
# Improved validation loss from: 1.2031920433044434  to: 1.1889310836791993
# Training iteration: 322
# Improved validation loss from: 1.1889310836791993  to: 1.1573768615722657
# Training iteration: 323
# Validation loss (no improvement): 1.2231765747070313
# Training iteration: 324
# Validation loss (no improvement): 1.1769095420837403
# Training iteration: 325
# Validation loss (no improvement): 1.1796577453613282
# Training iteration: 326
# Validation loss (no improvement): 1.5703542709350586
# Training iteration: 327
# Validation loss (no improvement): 1.241244125366211
# Training iteration: 328
# Validation loss (no improvement): 1.180152702331543
# Training iteration: 329
# Improved validation loss from: 1.1573768615722657  to: 1.1528226852416992
# Training iteration: 330
# Improved validation loss from: 1.1528226852416992  to: 1.1518314361572266
# Training iteration: 331
# Improved validation loss from: 1.1518314361572266  to: 1.1376239776611328
# Training iteration: 332
# Improved validation loss from: 1.1376239776611328  to: 1.1222139358520509
# Training iteration: 333
# Improved validation loss from: 1.1222139358520509  to: 1.108775520324707
# Training iteration: 334
# Validation loss (no improvement): 1.1221359252929688
# Training iteration: 335
# Validation loss (no improvement): 1.141015625
# Validation loss (no improvement): 1.0182158470153808
# Training iteration: 383
# Improved validation loss from: 1.0048656463623047  to: 0.9994293212890625
# Training iteration: 384
# Improved validation loss from: 0.9994293212890625  to: 0.990328598022461
# Training iteration: 385
# Validation loss (no improvement): 1.057687473297119
# Training iteration: 386
# Validation loss (no improvement): 1.0665069580078126
# Training iteration: 387
# Validation loss (no improvement): 1.0148794174194335
# Training iteration: 388
# Validation loss (no improvement): 1.0783845901489257
# Training iteration: 389
# Validation loss (no improvement): 1.0013068199157715
# Training iteration: 390
# Validation loss (no improvement): 1.0236216545104981
# Training iteration: 391
# Validation loss (no improvement): 0.9932329177856445
# Training iteration: 392
# Validation loss (no improvement): 1.0507917404174805
# Training iteration: 393
# Validation loss (no improvement): 1.0029923439025878
# Training iteration: 394
# Validation loss (no improvement): 1.1454654693603517
# Training iteration: 395
# Validation loss (no improvement): 1.2767863273620605
# Training iteration: 396
# Validation loss (no improvement): 1.0249645233154296
# Training iteration: 397
# Validation loss (no improvement): 1.047831916809082
# Training iteration: 398
# Improved validation loss from: 0.990328598022461  to: 0.9886775970458984
# Training iteration: 399
# Validation loss (no improvement): 1.0087117195129394
# Training iteration: 400
# Validation loss (no improvement): 1.0530044555664062
# Training iteration: 401
# Validation loss (no improvement): 1.1086956024169923
# Training iteration: 402
# Validation loss (no improvement): 1.047726535797119
# Training iteration: 403
# Validation loss (no improvement): 1.0713937759399415
# Training iteration: 404
# Validation loss (no improvement): 1.0379152297973633
# Training iteration: 405
# Validation loss (no improvement): 1.0262201309204102
# Training iteration: 406
# Validation loss (no improvement): 1.0361438751220704
# Training iteration: 407
# Validation loss (no improvement): 1.0472643852233887
# Training iteration: 408
# Validation loss (no improvement): 1.0112127304077148
# Training iteration: 409
# Validation loss (no improvement): 1.0228143692016602
# Training iteration: 410
# Validation loss (no improvement): 1.001994514465332
# Training iteration: 411
# Validation loss (no improvement): 1.0774383544921875
# Training iteration: 412
# Validation loss (no improvement): 1.0037412643432617
# Training iteration: 413
# Improved validation loss from: 0.9886775970458984  to: 0.984184741973877
# Training iteration: 414
# Improved validation loss from: 0.984184741973877  to: 0.9459461212158203
# Training iteration: 415
# Validation loss (no improvement): 1.0446176528930664
# Training iteration: 416
# Validation loss (no improvement): 1.0315801620483398
# Training iteration: 417
# Validation loss (no improvement): 0.9902660369873046
# Training iteration: 418
# Validation loss (no improvement): 1.0758583068847656
# Training iteration: 419
# Validation loss (no improvement): 1.033029270172119
# Training iteration: 420
# Validation loss (no improvement): 1.0837053298950194
# Training iteration: 421
# Validation loss (no improvement): 0.9803402900695801
# Training iteration: 422
# Validation loss (no improvement): 1.0160258293151856
# Training iteration: 423
# Validation loss (no improvement): 1.0486092567443848
# Training iteration: 424
# Validation loss (no improvement): 1.099148941040039
# Training iteration: 425
# Validation loss (no improvement): 0.9999597549438477
# Training iteration: 426
# Validation loss (no improvement): 1.0375910758972169
# Training iteration: 427
# Improved validation loss from: 0.9459461212158203  to: 0.9451156616210937
# Training iteration: 428
# Validation loss (no improvement): 0.9752687454223633
# Training iteration: 429
# Validation loss (no improvement): 1.0992271423339843
# Training iteration: 527
# Validation loss (no improvement): 1.031911277770996
# Training iteration: 528
# Validation loss (no improvement): 1.0953113555908203
# Training iteration: 529
# Validation loss (no improvement): 1.1531618118286133
# Training iteration: 530
# Validation loss (no improvement): 1.1174787521362304
# Training iteration: 531
# Validation loss (no improvement): 1.233365249633789
# Training iteration: 532
# Validation loss (no improvement): 1.119715404510498
# Training iteration: 533
# Validation loss (no improvement): 1.0907224655151366
# Training iteration: 534
# Validation loss (no improvement): 1.0790229797363282
# Training iteration: 535
# Validation loss (no improvement): 1.0967209815979004
# Training iteration: 536
# Validation loss (no improvement): 1.1106658935546876
# Training iteration: 537
# Validation loss (no improvement): 1.1237869262695312
# Training iteration: 538
# Validation loss (no improvement): 1.1405290603637694
# Training iteration: 539
# Validation loss (no improvement): 1.1934017181396483
# Training iteration: 540
# Validation loss (no improvement): 1.1490776062011718
# Training iteration: 541
# Validation loss (no improvement): 1.1645037651062011
# Training iteration: 542
# Validation loss (no improvement): 1.0550844192504882
# Training iteration: 543
# Validation loss (no improvement): 1.0632805824279785
# Training iteration: 544
# Validation loss (no improvement): 1.0438760757446288
# Training iteration: 545
# Validation loss (no improvement): 1.1094041824340821
# Training iteration: 546
# Validation loss (no improvement): 1.0582637786865234
# Training iteration: 547
# Validation loss (no improvement): 1.0716203689575194
# Training iteration: 548
# Validation loss (no improvement): 1.0682498931884765
# Training iteration: 549
# Validation loss (no improvement): 1.163940143585205
# Training iteration: 550
# Validation loss (no improvement): 1.0467144012451173
# Training iteration: 551
# Validation loss (no improvement): 1.1171706199645997
# Training iteration: 552
# Validation loss (no improvement): 1.0808798789978027
# Training iteration: 553
# Validation loss (no improvement): 1.1080442428588868
# Training iteration: 554
# Validation loss (no improvement): 1.1184627532958984
# Training iteration: 555
# Validation loss (no improvement): 1.0349441528320313
# Training iteration: 556
# Validation loss (no improvement): 1.0705852508544922
# Training iteration: 557
# Validation loss (no improvement): 1.080402946472168
# Training iteration: 558
# Validation loss (no improvement): 1.1748122215270995
# Training iteration: 559
# Validation loss (no improvement): 1.0155595779418944
# Training iteration: 560
# Validation loss (no improvement): 1.0506240844726562
# Training iteration: 561
# Validation loss (no improvement): 1.1345348358154297
# Training iteration: 562
# Validation loss (no improvement): 1.0822333335876464
# Training iteration: 563
# Validation loss (no improvement): 1.1040790557861329
# Training iteration: 564
# Validation loss (no improvement): 1.0579912185668945
# Training iteration: 565
# Validation loss (no improvement): 1.0007514953613281
# Training iteration: 566
# Validation loss (no improvement): 1.1057136535644532
# Training iteration: 567
# Validation loss (no improvement): 1.1089704513549805
# Training iteration: 568
# Validation loss (no improvement): 1.1014411926269532
# Training iteration: 569
# Validation loss (no improvement): 1.026041030883789
# Training iteration: 570
# Validation loss (no improvement): 1.0252498626708983
# Training iteration: 571
# Validation loss (no improvement): 1.0990490913391113
# Training iteration: 572
# Validation loss (no improvement): 1.0745512008666993

# %%
train_mode = False

# %%
mixture_model = toy_model(data_tuple,arch_type='mixture',lrate=0.01,num_epochs=4000,eps_range=eps_range)
if train_mode:
    mixture_model.train_model()
mixture_model.model_inference()
# Load mixture
mixture_mean = np.load('mixture_mean_validation.npy')
mixture_logvar = np.load('mixture_var_validation.npy')
mixture_std = np.sqrt(np.exp(mixture_logvar))

# %%
swa_model = toy_model(data_tuple,arch_type='swa',lrate=0.01,num_epochs=4000,eps_range=eps_range)
if train_mode:
    swa_model.train_model()
swa_model.model_inference()
# Load swa
swa_mean = np.load('SWA_ensembles_mean_multiple.npy')
swa_std = np.load('SWA_ensembles_std_multiple.npy')

# %%
if train_mode:

    ensemble_model_1 = toy_model(data_tuple,arch_type='ensemble',lrate=0.01,num_epochs=4000,eps_range=eps_range)
    ensemble_model_1.train_model()
    ensemble_model_1.model_inference()
    ensemble_mean_1 = np.load('ensemble_mean_validation.npy')
    ensemble_logvar_1 = np.load('ensemble_var_validation.npy')
    ensemble_std_1 = np.sqrt(np.exp(ensemble_logvar_1))
    
    ensemble_model_2 = toy_model(data_tuple,arch_type='ensemble',lrate=0.01,num_epochs=4000,eps_range=eps_range)
    ensemble_model_2.train_model()
    ensemble_model_2.model_inference()
    ensemble_mean_2 = np.load('ensemble_mean_validation.npy')
    ensemble_logvar_2 = np.load('ensemble_var_validation.npy')
    ensemble_std_2 = np.sqrt(np.exp(ensemble_logvar_2))
    
    ensemble_model_3 = toy_model(data_tuple,arch_type='ensemble',lrate=0.01,num_epochs=4000,eps_range=eps_range)
    ensemble_model_3.train_model()
    ensemble_model_3.model_inference()
    ensemble_mean_3 = np.load('ensemble_mean_validation.npy')
    ensemble_logvar_3 = np.load('ensemble_var_validation.npy')
    ensemble_std_3 = np.sqrt(np.exp(ensemble_logvar_3))
    
    ensemble_model_4 = toy_model(data_tuple,arch_type='ensemble',lrate=0.01,num_epochs=4000,eps_range=eps_range)
    ensemble_model_4.train_model()
    ensemble_model_4.model_inference()
    ensemble_mean_4 = np.load('ensemble_mean_validation.npy')
    ensemble_logvar_4 = np.load('ensemble_var_validation.npy')
    ensemble_std_4 = np.sqrt(np.exp(ensemble_logvar_4))
    
    ensemble_model_5 = toy_model(data_tuple,arch_type='ensemble',lrate=0.01,num_epochs=4000,eps_range=eps_range)
    ensemble_model_5.train_model()
    ensemble_model_5.model_inference()
    ensemble_mean_5 = np.load('ensemble_mean_validation.npy')
    ensemble_logvar_5 = np.load('ensemble_var_validation.npy')
    ensemble_std_5 = np.sqrt(np.exp(ensemble_logvar_5))
    
    ensemble_mean = (ensemble_mean_1+ensemble_mean_2+ensemble_mean_3+ensemble_mean_4+ensemble_mean_5)/5.0

    ensemble_var = ensemble_mean_1**2 + ensemble_std_1**2 + ensemble_mean_2**2 + ensemble_std_2**2 + ensemble_mean_3**2 + ensemble_std_3**2 + ensemble_mean_4**2 + ensemble_std_4**2 + ensemble_mean_5**2 + ensemble_std_5**2
    ensemble_var = ensemble_var/5.0 - ensemble_mean**2
    ensemble_std = np.sqrt(ensemble_var)
    
    np.save('Deep_ensembles_mean.npy',ensemble_mean)
    np.save('Deep_ensembles_std.npy',ensemble_std)
    
else:
    ensemble_mean = np.load('Deep_ensembles_mean.npy')
    ensemble_std = np.load('Deep_ensembles_std.npy')

# %%
arr1inds = data_tuple[2][:,0].argsort()

# %%
plt.figure()
plt.plot(data_tuple[2][arr1inds,0],data_tuple[2][arr1inds,1],label='Truth')
plt.plot(data_tuple[2][arr1inds,0],baseline[arr1inds,0],label='Baseline')
plt.plot(data_tuple[2][arr1inds,0],dropout_mean[arr1inds,0],label='Dropout mean')
plt.plot(data_tuple[2][arr1inds,0],mixture_mean[arr1inds,0],label='Mixture mean')
plt.plot(data_tuple[2][arr1inds,0],ensemble_mean[arr1inds,0],label='Ensemble mean')
plt.plot(data_tuple[2][arr1inds,0],swa_mean[arr1inds,0],label='SWA mean')
plt.plot(data_tuple[2][arr1inds,0],flipout_mean[arr1inds,0],label='Flipout mean')
plt.legend()
plt.ylim()
plt.show()

# %%
plt.figure()
plt.plot(data_tuple[2][arr1inds,0],data_tuple[2][arr1inds,1],label='Truth')
plt.plot(data_tuple[2][arr1inds,0],flipout_mean[arr1inds,0],label='Flipout mean')
plt.fill_between(x=data_tuple[2][arr1inds,0],y1=flipout_mean[arr1inds,0]-3*flipout_std[arr1inds,0],y2=flipout_mean[arr1inds,0]+3*flipout_std[arr1inds,0])
# plt.ylim(-100,100)
plt.legend()
plt.ylim()
plt.show()

# %%
plt.figure()
plt.plot(data_tuple[2][arr1inds,0],data_tuple[2][arr1inds,1],label='Truth')
plt.plot(data_tuple[2][arr1inds,0],dropout_mean[arr1inds,0],label='Dropout mean')
plt.fill_between(x=data_tuple[2][arr1inds,0],y1=dropout_mean[arr1inds,0]-3*dropout_std[arr1inds,0],y2=dropout_mean[arr1inds,0]+3*dropout_std[arr1inds,0])
plt.legend()
plt.ylim()
plt.show()

# %%
plt.figure()
plt.plot(data_tuple[2][arr1inds,0],data_tuple[2][arr1inds,1],label='Truth')
plt.plot(data_tuple[2][arr1inds,0],mixture_mean[arr1inds,0],label='Mixture mean')
plt.fill_between(x=data_tuple[2][arr1inds,0],y1=mixture_mean[arr1inds,0]-3*mixture_std[arr1inds,0],y2=mixture_mean[arr1inds,0]+3*mixture_std[arr1inds,0])
plt.legend()
plt.ylim()
plt.show()

# %%
plt.figure()
plt.plot(data_tuple[2][arr1inds,0],data_tuple[2][arr1inds,1],label='Truth')
plt.plot(data_tuple[2][arr1inds,0],mixture_mean[arr1inds,0],label='Ensemble mean')
plt.fill_between(x=data_tuple[2][arr1inds,0],y1=ensemble_mean[arr1inds,0]-3*ensemble_std[arr1inds,0],y2=ensemble_mean[arr1inds,0]+3*ensemble_std[arr1inds,0])
plt.legend()
plt.ylim()
plt.show()

# %%
plt.figure()
plt.plot(data_tuple[2][arr1inds,0],data_tuple[2][arr1inds,1],label='Truth')
plt.plot(data_tuple[2][arr1inds,0],swa_mean[arr1inds,0],label='SWA mean')
plt.fill_between(x=data_tuple[2][arr1inds,0],y1=swa_mean[arr1inds,0]-3*swa_std[arr1inds,0],y2=swa_mean[arr1inds,0]+3*swa_std[arr1inds,0])
plt.legend()
plt.ylim()
plt.show()
