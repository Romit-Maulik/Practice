# %%
import numpy as np
import tensorflow as tf

# Set seeds
np.random.seed(10)
tf.random.set_seed(10)

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda, Dropout, Reshape, Flatten
from tensorflow.keras.layers import Conv1D, TimeDistributed, UpSampling1D, MaxPooling1D
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential, Model

# %% [markdown]
# ### Some global variables

# %%
Rnum = 4000
x = np.linspace(0.0,1.0,num=128)
dx = 1.0/np.shape(x)[0]
tsteps = np.linspace(0.0,2.0,num=1000)
dt = 2.0/np.shape(tsteps)[0]
mode = 'train'

# %% [markdown]
# ### Functions for full-order snapshots of Burgers Equation

# %%
def exact_solution(Rnum,t):
    t0 = np.exp(Rnum/8.0)

    return (x/(t+1))/(1.0+np.sqrt((t+1)/t0)*np.exp(Rnum*(x*x)/(4.0*t+4)))

def collect_snapshots(Rnum):
    snapshot_matrix = np.zeros(shape=(np.shape(x)[0],np.shape(tsteps)[0]))

    trange = np.arange(np.shape(tsteps)[0])
    for t in trange:
        snapshot_matrix[:,t] = exact_solution(Rnum,tsteps[t])[:]

    return np.transpose(snapshot_matrix)

# %% [markdown]
# ### Collect some snapshot data for CNN-LSTM embedding

# %%
snapshots_train = collect_snapshots(Rnum)
snapshots_train = np.expand_dims(snapshots_train,-1)

snapshots_valid = snapshots_train[500:]
snapshots_train = snapshots_train[:500]
# Out:
# /home/rmlans/anaconda3/envs/tf2_env/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Do some shifting for evolution predictions

# %%
snapshots_evolve = snapshots_train[1:]
snapshots_train = snapshots_train[0:-1]

# %% [markdown]
# ### ML related presets

# %%
weights_filepath = 'best_weights.h5'
lrate = 0.001

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Autoencoder and LSTM

# %%
# Encoder
encoder_inputs = Input(shape=(128,1),name='Field')

x = Conv1D(25,kernel_size=3,activation='relu',padding='same')(encoder_inputs)
enc_l2 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(15,kernel_size=3,activation='relu',padding='same')(enc_l2)
enc_l3 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(10,kernel_size=3,activation='relu',padding='same')(enc_l3)
enc_l4 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(5,kernel_size=3,activation='relu',padding='same')(enc_l4)
enc_l5 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(2,kernel_size=3,activation=None,padding='same')(enc_l5)
enc_l6 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(1,kernel_size=3,activation=None,padding='same')(enc_l6)
encoded = MaxPooling1D(2,padding='same')(x)

# LSTM
# encoded_lstm = Flatten()(encoded)
# parameter_inputs = Input(shape=(1,),name='Viscosity')
# lstm_inputs = tf.keras.layers.concatenate([encoded_lstm, parameter_inputs])
# lstm_inputs = Reshape((1,3))(lstm_inputs)

lstm_inputs = Reshape((1,2))(encoded)
x = LSTM(40,input_shape=(1, 3),return_sequences=True)(lstm_inputs)
x = LSTM(40,return_sequences=True)(x)
lstm_outputs = Dense(2,activation=None)(x)
  
# Decoder - using LSTM
lstm_decoder_inputs = Reshape((2,1))(lstm_outputs)

x = Conv1D(1,kernel_size=3,activation=None,padding='same')(lstm_decoder_inputs)
dec_l1 = UpSampling1D(2)(x)

x = Conv1D(5,kernel_size=3,activation=None,padding='same')(dec_l1)
dec_l2 = UpSampling1D(2)(x)

x = Conv1D(10,kernel_size=3,activation='relu',padding='same')(dec_l2)
dec_l3 = UpSampling1D(2)(x)

x = Conv1D(15,kernel_size=3,activation='relu',padding='same')(dec_l3)
dec_l4 = UpSampling1D(2)(x)

x = Conv1D(20,kernel_size=3,activation='relu',padding='same')(dec_l4)
dec_l5 = UpSampling1D(2)(x)

x = Conv1D(25,kernel_size=3,activation='relu',padding='same')(dec_l5)
dec_l6 = UpSampling1D(2)(x)

lstm_decoder_outputs = Conv1D(1,1,activation=None,padding='same')(dec_l6)

# Decoder - using AE only
x = Conv1D(1,kernel_size=3,activation=None,padding='same')(encoded)
dec_l1 = UpSampling1D(2)(x)

x = Conv1D(5,kernel_size=3,activation='relu',padding='same')(dec_l1)
dec_l2 = UpSampling1D(2)(x)

x = Conv1D(10,kernel_size=3,activation='relu',padding='same')(dec_l2)
dec_l3 = UpSampling1D(2)(x)

x = Conv1D(15,kernel_size=3,activation='relu',padding='same')(dec_l3)
dec_l4 = UpSampling1D(2)(x)

x = Conv1D(20,kernel_size=3,activation='relu',padding='same')(dec_l4)
dec_l5 = UpSampling1D(2)(x)

x = Conv1D(25,kernel_size=3,activation='relu',padding='same')(dec_l5)
dec_l6 = UpSampling1D(2)(x)

ae_decoder_outputs = Conv1D(1,1,activation=None,padding='same')(dec_l6)
    
model = Model(inputs=[encoder_inputs],outputs=[ae_decoder_outputs,lstm_decoder_outputs],name='CAE-LSTM')
   
# design network
my_adam = optimizers.Adam(lr=lrate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint]

# fit network
model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination])    
model.summary()

num_epochs = 500
batch_size = 32

if mode == 'train':
    train_history = model.fit(x=snapshots_train, 
                              y=[snapshots_train,snapshots_evolve], 
                              epochs=num_epochs, 
                              batch_size=batch_size, 
                              callbacks=callbacks_list,
                              validation_split=0.1)
# Out:
# Model: "CAE-LSTM"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Field (InputLayer)              [(None, 128, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 128, 25)      100         Field[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 64, 25)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 64, 15)       1140        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 32, 15)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 32, 10)       460         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 16, 10)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 16, 5)        155         max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 8, 5)         0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 8, 2)         32          max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 4, 2)         0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 4, 1)         7           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 2, 1)         0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 1, 40)        6880        reshape[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 1, 40)        12960       lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 2)         82          lstm_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 1)         0           dense[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 2, 1)         4           max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 2, 1)         4           reshape_1[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_6 (UpSampling1D)  (None, 4, 1)         0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling1d (UpSampling1D)    (None, 4, 1)         0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 4, 5)         20          up_sampling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 4, 5)         20          up_sampling1d[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_7 (UpSampling1D)  (None, 8, 5)         0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 8, 5)         0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 8, 10)        160         up_sampling1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 8, 10)        160         up_sampling1d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_8 (UpSampling1D)  (None, 16, 10)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_2 (UpSampling1D)  (None, 16, 10)       0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 16, 15)       465         up_sampling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 16, 15)       465         up_sampling1d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_9 (UpSampling1D)  (None, 32, 15)       0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_3 (UpSampling1D)  (None, 32, 15)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 32, 20)       920         up_sampling1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 32, 20)       920         up_sampling1d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_10 (UpSampling1D) (None, 64, 20)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_4 (UpSampling1D)  (None, 64, 20)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 64, 25)       1525        up_sampling1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 64, 25)       1525        up_sampling1d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_11 (UpSampling1D) (None, 128, 25)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_5 (UpSampling1D)  (None, 128, 25)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 128, 1)       26          up_sampling1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 128, 1)       26          up_sampling1d_5[0][0]
# ==================================================================================================
# Total params: 28,056
# Trainable params: 28,056
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0493 - conv1d_19_loss: 0.0260 - conv1d_12_loss: 0.0234 - conv1d_19_coeff_determination: -71328.3047 - conv1d_12_coeff_determination: -108837976.0000
# Epoch 00001: val_loss improved from inf to 0.02560, saving model to best_weights.h5
# 15/15 [==============================] - 1s 67ms/step - loss: 0.0483 - conv1d_19_loss: 0.0253 - conv1d_12_loss: 0.0230 - conv1d_19_coeff_determination: -61824.3633 - conv1d_12_coeff_determination: -94326248.0000 - val_loss: 0.0256 - val_conv1d_19_loss: 0.0120 - val_conv1d_12_loss: 0.0136 - val_conv1d_19_coeff_determination: -20.4429 - val_conv1d_12_coeff_determination: -17.6231
# Epoch 2/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0298 - conv1d_19_loss: 0.0151 - conv1d_12_loss: 0.0147 - conv1d_19_coeff_determination: -13.5296 - conv1d_12_coeff_determination: -17.8865
# Epoch 00002: val_loss improved from 0.02560 to 0.01732, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0295 - conv1d_19_loss: 0.0149 - conv1d_12_loss: 0.0145 - conv1d_19_coeff_determination: -12.5885 - conv1d_12_coeff_determination: -16.0805 - val_loss: 0.0173 - val_conv1d_19_loss: 0.0094 - val_conv1d_12_loss: 0.0079 - val_conv1d_19_coeff_determination: -3.6655 - val_conv1d_12_coeff_determination: -1.8009
# Epoch 3/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0161 - conv1d_19_loss: 0.0088 - conv1d_12_loss: 0.0073 - conv1d_19_coeff_determination: -1.2732 - conv1d_12_coeff_determination: -0.2904
# Epoch 00003: val_loss improved from 0.01732 to 0.01379, saving model to best_weights.h5
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0161 - conv1d_19_loss: 0.0088 - conv1d_12_loss: 0.0073 - conv1d_19_coeff_determination: -1.1469 - conv1d_12_coeff_determination: -0.2219 - val_loss: 0.0138 - val_conv1d_19_loss: 0.0059 - val_conv1d_12_loss: 0.0079 - val_conv1d_19_coeff_determination: 0.4898 - val_conv1d_12_coeff_determination: 0.4673
# Epoch 4/500
# 15/15 [==============================] - ETA: 0s - loss: 0.0102 - conv1d_19_loss: 0.0051 - conv1d_12_loss: 0.0051 - conv1d_19_coeff_determination: 0.6639 - conv1d_12_coeff_determination: 0.6818
# Epoch 00004: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0102 - conv1d_19_loss: 0.0051 - conv1d_12_loss: 0.0051 - conv1d_19_coeff_determination: 0.6639 - conv1d_12_coeff_determination: 0.6818 - val_loss: 0.0169 - val_conv1d_19_loss: 0.0079 - val_conv1d_12_loss: 0.0090 - val_conv1d_19_coeff_determination: 0.4860 - val_conv1d_12_coeff_determination: 0.4070
# Epoch 5/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0095 - conv1d_19_loss: 0.0046 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.6812 - conv1d_12_coeff_determination: 0.6600
# Epoch 00005: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0095 - conv1d_19_loss: 0.0046 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.6919 - conv1d_12_coeff_determination: 0.6706 - val_loss: 0.0160 - val_conv1d_19_loss: 0.0076 - val_conv1d_12_loss: 0.0084 - val_conv1d_19_coeff_determination: 0.5057 - val_conv1d_12_coeff_determination: 0.4214
# Epoch 6/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0093 - conv1d_19_loss: 0.0044 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.7047 - conv1d_12_coeff_determination: 0.6637
# Epoch 00006: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0092 - conv1d_19_loss: 0.0044 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.7128 - conv1d_12_coeff_determination: 0.6686 - val_loss: 0.0151 - val_conv1d_19_loss: 0.0069 - val_conv1d_12_loss: 0.0082 - val_conv1d_19_coeff_determination: 0.5082 - val_conv1d_12_coeff_determination: 0.3980
# Epoch 7/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0094 - conv1d_19_loss: 0.0044 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.6854 - conv1d_12_coeff_determination: 0.6477
# Epoch 00007: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0092 - conv1d_19_loss: 0.0043 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.7011 - conv1d_12_coeff_determination: 0.6540 - val_loss: 0.0173 - val_conv1d_19_loss: 0.0090 - val_conv1d_12_loss: 0.0083 - val_conv1d_19_coeff_determination: 0.4745 - val_conv1d_12_coeff_determination: 0.4010
# Epoch 8/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0091 - conv1d_19_loss: 0.0041 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.7364 - conv1d_12_coeff_determination: 0.6581
# Epoch 00008: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0089 - conv1d_19_loss: 0.0040 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.7343 - conv1d_12_coeff_determination: 0.6642 - val_loss: 0.0171 - val_conv1d_19_loss: 0.0082 - val_conv1d_12_loss: 0.0089 - val_conv1d_19_coeff_determination: 0.5654 - val_conv1d_12_coeff_determination: 0.3903
# Epoch 9/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0086 - conv1d_19_loss: 0.0038 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.7556 - conv1d_12_coeff_determination: 0.6735
# Epoch 00009: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0086 - conv1d_19_loss: 0.0038 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.7475 - conv1d_12_coeff_determination: 0.6533 - val_loss: 0.0181 - val_conv1d_19_loss: 0.0096 - val_conv1d_12_loss: 0.0085 - val_conv1d_19_coeff_determination: 0.5527 - val_conv1d_12_coeff_determination: 0.3564
# Epoch 10/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0085 - conv1d_19_loss: 0.0036 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.7715 - conv1d_12_coeff_determination: 0.6560
# Epoch 00010: val_loss did not improve from 0.01379
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0084 - conv1d_19_loss: 0.0036 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.7667 - conv1d_12_coeff_determination: 0.6401 - val_loss: 0.0180 - val_conv1d_19_loss: 0.0094 - val_conv1d_12_loss: 0.0087 - val_conv1d_19_coeff_determination: 0.5833 - val_conv1d_12_coeff_determination: 0.3195
# Epoch 11/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0080 - conv1d_19_loss: 0.0032 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.8075 - conv1d_12_coeff_determination: 0.6602
# Epoch 00011: val_loss improved from 0.01379 to 0.01178, saving model to best_weights.h5
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0079 - conv1d_19_loss: 0.0031 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.8073 - conv1d_12_coeff_determination: 0.6492 - val_loss: 0.0118 - val_conv1d_19_loss: 0.0041 - val_conv1d_12_loss: 0.0077 - val_conv1d_19_coeff_determination: 0.7280 - val_conv1d_12_coeff_determination: 0.3359
# Epoch 12/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0078 - conv1d_19_loss: 0.0029 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.8055 - conv1d_12_coeff_determination: 0.6439
# Epoch 00012: val_loss did not improve from 0.01178
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0077 - conv1d_19_loss: 0.0028 - conv1d_12_loss: 0.0049 - conv1d_19_coeff_determination: 0.8179 - conv1d_12_coeff_determination: 0.6495 - val_loss: 0.0120 - val_conv1d_19_loss: 0.0044 - val_conv1d_12_loss: 0.0076 - val_conv1d_19_coeff_determination: 0.7354 - val_conv1d_12_coeff_determination: 0.3781
# Epoch 13/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0071 - conv1d_19_loss: 0.0023 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.8636 - conv1d_12_coeff_determination: 0.6658
# Epoch 00013: val_loss did not improve from 0.01178
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0071 - conv1d_19_loss: 0.0023 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.8641 - conv1d_12_coeff_determination: 0.6621 - val_loss: 0.0144 - val_conv1d_19_loss: 0.0057 - val_conv1d_12_loss: 0.0087 - val_conv1d_19_coeff_determination: 0.7058 - val_conv1d_12_coeff_determination: 0.3198
# Epoch 14/500
# 12/15 [=======================>......] - ETA: 0s - loss: 0.0070 - conv1d_19_loss: 0.0022 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.8697 - conv1d_12_coeff_determination: 0.6721
# Epoch 00014: val_loss improved from 0.01178 to 0.01176, saving model to best_weights.h5
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0070 - conv1d_19_loss: 0.0022 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.8769 - conv1d_12_coeff_determination: 0.6815 - val_loss: 0.0118 - val_conv1d_19_loss: 0.0033 - val_conv1d_12_loss: 0.0085 - val_conv1d_19_coeff_determination: 0.7855 - val_conv1d_12_coeff_determination: 0.3645
# Epoch 15/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0066 - conv1d_19_loss: 0.0019 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.8866 - conv1d_12_coeff_determination: 0.6756
# Epoch 00015: val_loss did not improve from 0.01176
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0066 - conv1d_19_loss: 0.0019 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.8905 - conv1d_12_coeff_determination: 0.6862 - val_loss: 0.0125 - val_conv1d_19_loss: 0.0042 - val_conv1d_12_loss: 0.0083 - val_conv1d_19_coeff_determination: 0.7641 - val_conv1d_12_coeff_determination: 0.3558
# Epoch 16/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0064 - conv1d_19_loss: 0.0017 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9055 - conv1d_12_coeff_determination: 0.6746
# Epoch 00016: val_loss improved from 0.01176 to 0.01000, saving model to best_weights.h5
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0064 - conv1d_19_loss: 0.0017 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9043 - conv1d_12_coeff_determination: 0.6616 - val_loss: 0.0100 - val_conv1d_19_loss: 0.0022 - val_conv1d_12_loss: 0.0078 - val_conv1d_19_coeff_determination: 0.8333 - val_conv1d_12_coeff_determination: 0.3285
# Epoch 17/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0062 - conv1d_19_loss: 0.0015 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9093 - conv1d_12_coeff_determination: 0.6695
# Epoch 00017: val_loss did not improve from 0.01000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0062 - conv1d_19_loss: 0.0015 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9117 - conv1d_12_coeff_determination: 0.6776 - val_loss: 0.0106 - val_conv1d_19_loss: 0.0032 - val_conv1d_12_loss: 0.0075 - val_conv1d_19_coeff_determination: 0.8116 - val_conv1d_12_coeff_determination: 0.3505
# Epoch 18/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0060 - conv1d_19_loss: 0.0013 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9262 - conv1d_12_coeff_determination: 0.6763
# Epoch 00018: val_loss did not improve from 0.01000
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0060 - conv1d_19_loss: 0.0013 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9277 - conv1d_12_coeff_determination: 0.6792 - val_loss: 0.0103 - val_conv1d_19_loss: 0.0025 - val_conv1d_12_loss: 0.0078 - val_conv1d_19_coeff_determination: 0.8439 - val_conv1d_12_coeff_determination: 0.3783
# Epoch 19/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0058 - conv1d_19_loss: 0.0011 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9390 - conv1d_12_coeff_determination: 0.6794
# Epoch 00019: val_loss did not improve from 0.01000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0057 - conv1d_19_loss: 0.0011 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9407 - conv1d_12_coeff_determination: 0.6900 - val_loss: 0.0102 - val_conv1d_19_loss: 0.0022 - val_conv1d_12_loss: 0.0080 - val_conv1d_19_coeff_determination: 0.8545 - val_conv1d_12_coeff_determination: 0.3336
# Epoch 20/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0055 - conv1d_19_loss: 9.5561e-04 - conv1d_12_loss: 0.0046 - conv1d_19_coeff_determination: 0.9468 - conv1d_12_coeff_determination: 0.6906
# Epoch 00020: val_loss did not improve from 0.01000
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0056 - conv1d_19_loss: 9.5344e-04 - conv1d_12_loss: 0.0046 - conv1d_19_coeff_determination: 0.9469 - conv1d_12_coeff_determination: 0.6764 - val_loss: 0.0104 - val_conv1d_19_loss: 0.0023 - val_conv1d_12_loss: 0.0081 - val_conv1d_19_coeff_determination: 0.8554 - val_conv1d_12_coeff_determination: 0.1887
# Epoch 21/500
# 11/15 [=====================>........] - ETA: 0s - loss: 0.0057 - conv1d_19_loss: 8.8581e-04 - conv1d_12_loss: 0.0048 - conv1d_19_coeff_determination: 0.9514 - conv1d_12_coeff_determination: 0.6570
# Epoch 00021: val_loss improved from 0.01000 to 0.00923, saving model to best_weights.h5
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0056 - conv1d_19_loss: 8.6151e-04 - conv1d_12_loss: 0.0047 - conv1d_19_coeff_determination: 0.9522 - conv1d_12_coeff_determination: 0.6730 - val_loss: 0.0092 - val_conv1d_19_loss: 0.0018 - val_conv1d_12_loss: 0.0074 - val_conv1d_19_coeff_determination: 0.8703 - val_conv1d_12_coeff_determination: 0.3390
# Epoch 22/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0053 - conv1d_19_loss: 7.2810e-04 - conv1d_12_loss: 0.0045 - conv1d_19_coeff_determination: 0.9602 - conv1d_12_coeff_determination: 0.6874
# Epoch 00022: val_loss improved from 0.00923 to 0.00880, saving model to best_weights.h5
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0053 - conv1d_19_loss: 7.2549e-04 - conv1d_12_loss: 0.0045 - conv1d_19_coeff_determination: 0.9591 - conv1d_12_coeff_determination: 0.6751 - val_loss: 0.0088 - val_conv1d_19_loss: 0.0016 - val_conv1d_12_loss: 0.0072 - val_conv1d_19_coeff_determination: 0.8738 - val_conv1d_12_coeff_determination: 0.3803
# Epoch 23/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0051 - conv1d_19_loss: 6.7955e-04 - conv1d_12_loss: 0.0045 - conv1d_19_coeff_determination: 0.9628 - conv1d_12_coeff_determination: 0.6935
# Epoch 00023: val_loss did not improve from 0.00880
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0051 - conv1d_19_loss: 6.8018e-04 - conv1d_12_loss: 0.0045 - conv1d_19_coeff_determination: 0.9625 - conv1d_12_coeff_determination: 0.6876 - val_loss: 0.0093 - val_conv1d_19_loss: 0.0016 - val_conv1d_12_loss: 0.0076 - val_conv1d_19_coeff_determination: 0.8803 - val_conv1d_12_coeff_determination: 0.2179
# Epoch 24/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0051 - conv1d_19_loss: 6.3999e-04 - conv1d_12_loss: 0.0045 - conv1d_19_coeff_determination: 0.9654 - conv1d_12_coeff_determination: 0.6948
# Epoch 00024: val_loss improved from 0.00880 to 0.00843, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0051 - conv1d_19_loss: 6.3752e-04 - conv1d_12_loss: 0.0045 - conv1d_19_coeff_determination: 0.9651 - conv1d_12_coeff_determination: 0.7012 - val_loss: 0.0084 - val_conv1d_19_loss: 0.0016 - val_conv1d_12_loss: 0.0069 - val_conv1d_19_coeff_determination: 0.8796 - val_conv1d_12_coeff_determination: 0.3442
# Epoch 25/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0048 - conv1d_19_loss: 6.0188e-04 - conv1d_12_loss: 0.0042 - conv1d_19_coeff_determination: 0.9676 - conv1d_12_coeff_determination: 0.7130
# Epoch 00025: val_loss improved from 0.00843 to 0.00751, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0048 - conv1d_19_loss: 6.0143e-04 - conv1d_12_loss: 0.0042 - conv1d_19_coeff_determination: 0.9681 - conv1d_12_coeff_determination: 0.7100 - val_loss: 0.0075 - val_conv1d_19_loss: 0.0015 - val_conv1d_12_loss: 0.0060 - val_conv1d_19_coeff_determination: 0.8752 - val_conv1d_12_coeff_determination: 0.4912
# Epoch 26/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0045 - conv1d_19_loss: 5.7118e-04 - conv1d_12_loss: 0.0039 - conv1d_19_coeff_determination: 0.9693 - conv1d_12_coeff_determination: 0.7332
# Epoch 00026: val_loss improved from 0.00751 to 0.00608, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0044 - conv1d_19_loss: 5.6938e-04 - conv1d_12_loss: 0.0039 - conv1d_19_coeff_determination: 0.9699 - conv1d_12_coeff_determination: 0.7402 - val_loss: 0.0061 - val_conv1d_19_loss: 0.0014 - val_conv1d_12_loss: 0.0046 - val_conv1d_19_coeff_determination: 0.8869 - val_conv1d_12_coeff_determination: 0.5627
# Epoch 27/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0039 - conv1d_19_loss: 5.5094e-04 - conv1d_12_loss: 0.0034 - conv1d_19_coeff_determination: 0.9706 - conv1d_12_coeff_determination: 0.7762
# Epoch 00027: val_loss improved from 0.00608 to 0.00555, saving model to best_weights.h5
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0039 - conv1d_19_loss: 5.4826e-04 - conv1d_12_loss: 0.0034 - conv1d_19_coeff_determination: 0.9713 - conv1d_12_coeff_determination: 0.7833 - val_loss: 0.0056 - val_conv1d_19_loss: 0.0014 - val_conv1d_12_loss: 0.0041 - val_conv1d_19_coeff_determination: 0.8881 - val_conv1d_12_coeff_determination: 0.5630
# Epoch 28/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0029 - conv1d_19_loss: 5.2399e-04 - conv1d_12_loss: 0.0024 - conv1d_19_coeff_determination: 0.9720 - conv1d_12_coeff_determination: 0.8501
# Epoch 00028: val_loss improved from 0.00555 to 0.00448, saving model to best_weights.h5
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0029 - conv1d_19_loss: 5.2136e-04 - conv1d_12_loss: 0.0024 - conv1d_19_coeff_determination: 0.9727 - conv1d_12_coeff_determination: 0.8540 - val_loss: 0.0045 - val_conv1d_19_loss: 0.0015 - val_conv1d_12_loss: 0.0030 - val_conv1d_19_coeff_determination: 0.8778 - val_conv1d_12_coeff_determination: 0.6904
# Epoch 29/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0023 - conv1d_19_loss: 5.2419e-04 - conv1d_12_loss: 0.0018 - conv1d_19_coeff_determination: 0.9720 - conv1d_12_coeff_determination: 0.8932
# Epoch 00029: val_loss improved from 0.00448 to 0.00406, saving model to best_weights.h5
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0023 - conv1d_19_loss: 5.2397e-04 - conv1d_12_loss: 0.0018 - conv1d_19_coeff_determination: 0.9722 - conv1d_12_coeff_determination: 0.8971 - val_loss: 0.0041 - val_conv1d_19_loss: 0.0014 - val_conv1d_12_loss: 0.0027 - val_conv1d_19_coeff_determination: 0.8861 - val_conv1d_12_coeff_determination: 0.7207
# Epoch 30/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0019 - conv1d_19_loss: 4.8594e-04 - conv1d_12_loss: 0.0014 - conv1d_19_coeff_determination: 0.9740 - conv1d_12_coeff_determination: 0.9175
# Epoch 00030: val_loss improved from 0.00406 to 0.00339, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0019 - conv1d_19_loss: 4.8272e-04 - conv1d_12_loss: 0.0014 - conv1d_19_coeff_determination: 0.9748 - conv1d_12_coeff_determination: 0.9201 - val_loss: 0.0034 - val_conv1d_19_loss: 0.0014 - val_conv1d_12_loss: 0.0020 - val_conv1d_19_coeff_determination: 0.8858 - val_conv1d_12_coeff_determination: 0.7984
# Epoch 31/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0016 - conv1d_19_loss: 4.6049e-04 - conv1d_12_loss: 0.0011 - conv1d_19_coeff_determination: 0.9754 - conv1d_12_coeff_determination: 0.9372
# Epoch 00031: val_loss improved from 0.00339 to 0.00291, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0016 - conv1d_19_loss: 4.6002e-04 - conv1d_12_loss: 0.0011 - conv1d_19_coeff_determination: 0.9759 - conv1d_12_coeff_determination: 0.9378 - val_loss: 0.0029 - val_conv1d_19_loss: 0.0013 - val_conv1d_12_loss: 0.0016 - val_conv1d_19_coeff_determination: 0.8932 - val_conv1d_12_coeff_determination: 0.8688
# Epoch 32/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0014 - conv1d_19_loss: 4.3665e-04 - conv1d_12_loss: 9.2643e-04 - conv1d_19_coeff_determination: 0.9767 - conv1d_12_coeff_determination: 0.9487
# Epoch 00032: val_loss improved from 0.00291 to 0.00276, saving model to best_weights.h5
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0014 - conv1d_19_loss: 4.3418e-04 - conv1d_12_loss: 9.1941e-04 - conv1d_19_coeff_determination: 0.9777 - conv1d_12_coeff_determination: 0.9504 - val_loss: 0.0028 - val_conv1d_19_loss: 0.0013 - val_conv1d_12_loss: 0.0015 - val_conv1d_19_coeff_determination: 0.8919 - val_conv1d_12_coeff_determination: 0.8748
# Epoch 33/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0012 - conv1d_19_loss: 4.2172e-04 - conv1d_12_loss: 7.8890e-04 - conv1d_19_coeff_determination: 0.9773 - conv1d_12_coeff_determination: 0.9565
# Epoch 00033: val_loss improved from 0.00276 to 0.00267, saving model to best_weights.h5
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012 - conv1d_19_loss: 4.2127e-04 - conv1d_12_loss: 7.8856e-04 - conv1d_19_coeff_determination: 0.9781 - conv1d_12_coeff_determination: 0.9571 - val_loss: 0.0027 - val_conv1d_19_loss: 0.0012 - val_conv1d_12_loss: 0.0014 - val_conv1d_19_coeff_determination: 0.8986 - val_conv1d_12_coeff_determination: 0.8778
# Epoch 34/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0011 - conv1d_19_loss: 4.0497e-04 - conv1d_12_loss: 7.2587e-04 - conv1d_19_coeff_determination: 0.9784 - conv1d_12_coeff_determination: 0.9603
# Epoch 00034: val_loss did not improve from 0.00267
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0011 - conv1d_19_loss: 4.0506e-04 - conv1d_12_loss: 7.2598e-04 - conv1d_19_coeff_determination: 0.9785 - conv1d_12_coeff_determination: 0.9608 - val_loss: 0.0027 - val_conv1d_19_loss: 0.0012 - val_conv1d_12_loss: 0.0015 - val_conv1d_19_coeff_determination: 0.9128 - val_conv1d_12_coeff_determination: 0.8718
# Epoch 35/500
# 14/15 [===========================>..] - ETA: 0s - loss: 0.0013 - conv1d_19_loss: 4.7556e-04 - conv1d_12_loss: 7.7580e-04 - conv1d_19_coeff_determination: 0.9746 - conv1d_12_coeff_determination: 0.9570
# Epoch 00035: val_loss improved from 0.00267 to 0.00243, saving model to best_weights.h5
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0012 - conv1d_19_loss: 4.7494e-04 - conv1d_12_loss: 7.7496e-04 - conv1d_19_coeff_determination: 0.9755 - conv1d_12_coeff_determination: 0.9583 - val_loss: 0.0024 - val_conv1d_19_loss: 0.0012 - val_conv1d_12_loss: 0.0012 - val_conv1d_19_coeff_determination: 0.8995 - val_conv1d_12_coeff_determination: 0.9057
# Epoch 36/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0011 - conv1d_19_loss: 4.2325e-04 - conv1d_12_loss: 6.6151e-04 - conv1d_19_coeff_determination: 0.9775 - conv1d_12_coeff_determination: 0.9638
# Epoch 00036: val_loss improved from 0.00243 to 0.00220, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 0.0011 - conv1d_19_loss: 4.1984e-04 - conv1d_12_loss: 6.5923e-04 - conv1d_19_coeff_determination: 0.9779 - conv1d_12_coeff_determination: 0.9635 - val_loss: 0.0022 - val_conv1d_19_loss: 0.0010 - val_conv1d_12_loss: 0.0012 - val_conv1d_19_coeff_determination: 0.9193 - val_conv1d_12_coeff_determination: 0.9083
# Epoch 37/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0010 - conv1d_19_loss: 3.9748e-04 - conv1d_12_loss: 6.0581e-04 - conv1d_19_coeff_determination: 0.9789 - conv1d_12_coeff_determination: 0.9672
# Epoch 00037: val_loss did not improve from 0.00220
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0010 - conv1d_19_loss: 3.9543e-04 - conv1d_12_loss: 6.0537e-04 - conv1d_19_coeff_determination: 0.9797 - conv1d_12_coeff_determination: 0.9679 - val_loss: 0.0023 - val_conv1d_19_loss: 0.0011 - val_conv1d_12_loss: 0.0012 - val_conv1d_19_coeff_determination: 0.9102 - val_conv1d_12_coeff_determination: 0.8942
# Epoch 38/500
# 14/15 [===========================>..] - ETA: 0s - loss: 9.6613e-04 - conv1d_19_loss: 3.7188e-04 - conv1d_12_loss: 5.9425e-04 - conv1d_19_coeff_determination: 0.9801 - conv1d_12_coeff_determination: 0.9674
# Epoch 00038: val_loss improved from 0.00220 to 0.00209, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 9.6518e-04 - conv1d_19_loss: 3.7137e-04 - conv1d_12_loss: 5.9381e-04 - conv1d_19_coeff_determination: 0.9809 - conv1d_12_coeff_determination: 0.9682 - val_loss: 0.0021 - val_conv1d_19_loss: 0.0011 - val_conv1d_12_loss: 0.0010 - val_conv1d_19_coeff_determination: 0.9132 - val_conv1d_12_coeff_determination: 0.9179
# Epoch 39/500
# 13/15 [=========================>....] - ETA: 0s - loss: 9.2882e-04 - conv1d_19_loss: 3.7105e-04 - conv1d_12_loss: 5.5777e-04 - conv1d_19_coeff_determination: 0.9802 - conv1d_12_coeff_determination: 0.9697
# Epoch 00039: val_loss did not improve from 0.00209
# 15/15 [==============================] - 0s 11ms/step - loss: 9.2381e-04 - conv1d_19_loss: 3.6974e-04 - conv1d_12_loss: 5.5407e-04 - conv1d_19_coeff_determination: 0.9807 - conv1d_12_coeff_determination: 0.9707 - val_loss: 0.0022 - val_conv1d_19_loss: 0.0011 - val_conv1d_12_loss: 0.0011 - val_conv1d_19_coeff_determination: 0.9124 - val_conv1d_12_coeff_determination: 0.9137
# Epoch 40/500
# 13/15 [=========================>....] - ETA: 0s - loss: 9.2193e-04 - conv1d_19_loss: 3.7400e-04 - conv1d_12_loss: 5.4792e-04 - conv1d_19_coeff_determination: 0.9801 - conv1d_12_coeff_determination: 0.9705
# Epoch 00040: val_loss did not improve from 0.00209
# 15/15 [==============================] - 0s 10ms/step - loss: 9.0691e-04 - conv1d_19_loss: 3.6706e-04 - conv1d_12_loss: 5.3986e-04 - conv1d_19_coeff_determination: 0.9810 - conv1d_12_coeff_determination: 0.9717 - val_loss: 0.0021 - val_conv1d_19_loss: 0.0011 - val_conv1d_12_loss: 9.9215e-04 - val_conv1d_19_coeff_determination: 0.9123 - val_conv1d_12_coeff_determination: 0.9173
# Epoch 41/500
# 13/15 [=========================>....] - ETA: 0s - loss: 8.7178e-04 - conv1d_19_loss: 3.6654e-04 - conv1d_12_loss: 5.0524e-04 - conv1d_19_coeff_determination: 0.9805 - conv1d_12_coeff_determination: 0.9728
# Epoch 00041: val_loss improved from 0.00209 to 0.00190, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 8.6008e-04 - conv1d_19_loss: 3.6241e-04 - conv1d_12_loss: 4.9767e-04 - conv1d_19_coeff_determination: 0.9814 - conv1d_12_coeff_determination: 0.9741 - val_loss: 0.0019 - val_conv1d_19_loss: 9.6933e-04 - val_conv1d_12_loss: 9.2740e-04 - val_conv1d_19_coeff_determination: 0.9173 - val_conv1d_12_coeff_determination: 0.9261
# Epoch 42/500
# 14/15 [===========================>..] - ETA: 0s - loss: 8.3217e-04 - conv1d_19_loss: 3.5688e-04 - conv1d_12_loss: 4.7529e-04 - conv1d_19_coeff_determination: 0.9810 - conv1d_12_coeff_determination: 0.9744
# Epoch 00042: val_loss did not improve from 0.00190
# 15/15 [==============================] - 0s 9ms/step - loss: 8.3215e-04 - conv1d_19_loss: 3.5692e-04 - conv1d_12_loss: 4.7523e-04 - conv1d_19_coeff_determination: 0.9807 - conv1d_12_coeff_determination: 0.9743 - val_loss: 0.0019 - val_conv1d_19_loss: 9.6482e-04 - val_conv1d_12_loss: 9.6776e-04 - val_conv1d_19_coeff_determination: 0.9235 - val_conv1d_12_coeff_determination: 0.9243
# Epoch 43/500
# 12/15 [=======================>......] - ETA: 0s - loss: 7.9808e-04 - conv1d_19_loss: 3.3924e-04 - conv1d_12_loss: 4.5885e-04 - conv1d_19_coeff_determination: 0.9820 - conv1d_12_coeff_determination: 0.9754
# Epoch 00043: val_loss did not improve from 0.00190
# 15/15 [==============================] - 0s 11ms/step - loss: 8.0005e-04 - conv1d_19_loss: 3.3885e-04 - conv1d_12_loss: 4.6120e-04 - conv1d_19_coeff_determination: 0.9827 - conv1d_12_coeff_determination: 0.9757 - val_loss: 0.0023 - val_conv1d_19_loss: 0.0010 - val_conv1d_12_loss: 0.0012 - val_conv1d_19_coeff_determination: 0.9140 - val_conv1d_12_coeff_determination: 0.9067
# Epoch 44/500
# 13/15 [=========================>....] - ETA: 0s - loss: 9.0984e-04 - conv1d_19_loss: 3.7178e-04 - conv1d_12_loss: 5.3806e-04 - conv1d_19_coeff_determination: 0.9802 - conv1d_12_coeff_determination: 0.9710
# Epoch 00044: val_loss improved from 0.00190 to 0.00171, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 9.0557e-04 - conv1d_19_loss: 3.6991e-04 - conv1d_12_loss: 5.3566e-04 - conv1d_19_coeff_determination: 0.9810 - conv1d_12_coeff_determination: 0.9716 - val_loss: 0.0017 - val_conv1d_19_loss: 8.5498e-04 - val_conv1d_12_loss: 8.5306e-04 - val_conv1d_19_coeff_determination: 0.9323 - val_conv1d_12_coeff_determination: 0.9294
# Epoch 45/500
# 13/15 [=========================>....] - ETA: 0s - loss: 8.7630e-04 - conv1d_19_loss: 3.7490e-04 - conv1d_12_loss: 5.0140e-04 - conv1d_19_coeff_determination: 0.9800 - conv1d_12_coeff_determination: 0.9728
# Epoch 00045: val_loss did not improve from 0.00171
# 15/15 [==============================] - 0s 11ms/step - loss: 8.6729e-04 - conv1d_19_loss: 3.6855e-04 - conv1d_12_loss: 4.9874e-04 - conv1d_19_coeff_determination: 0.9811 - conv1d_12_coeff_determination: 0.9730 - val_loss: 0.0020 - val_conv1d_19_loss: 8.6034e-04 - val_conv1d_12_loss: 0.0011 - val_conv1d_19_coeff_determination: 0.9325 - val_conv1d_12_coeff_determination: 0.9036
# Epoch 46/500
# 13/15 [=========================>....] - ETA: 0s - loss: 0.0010 - conv1d_19_loss: 3.7404e-04 - conv1d_12_loss: 6.4187e-04 - conv1d_19_coeff_determination: 0.9800 - conv1d_12_coeff_determination: 0.9647
# Epoch 00046: val_loss did not improve from 0.00171
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0010 - conv1d_19_loss: 3.7766e-04 - conv1d_12_loss: 6.3272e-04 - conv1d_19_coeff_determination: 0.9807 - conv1d_12_coeff_determination: 0.9667 - val_loss: 0.0020 - val_conv1d_19_loss: 9.5047e-04 - val_conv1d_12_loss: 0.0011 - val_conv1d_19_coeff_determination: 0.9241 - val_conv1d_12_coeff_determination: 0.9227
# Epoch 47/500
# 13/15 [=========================>....] - ETA: 0s - loss: 8.0565e-04 - conv1d_19_loss: 3.4815e-04 - conv1d_12_loss: 4.5750e-04 - conv1d_19_coeff_determination: 0.9815 - conv1d_12_coeff_determination: 0.9757
# Epoch 00047: val_loss did not improve from 0.00171
# 15/15 [==============================] - 0s 11ms/step - loss: 7.9524e-04 - conv1d_19_loss: 3.4419e-04 - conv1d_12_loss: 4.5104e-04 - conv1d_19_coeff_determination: 0.9810 - conv1d_12_coeff_determination: 0.9753 - val_loss: 0.0019 - val_conv1d_19_loss: 9.0360e-04 - val_conv1d_12_loss: 0.0010 - val_conv1d_19_coeff_determination: 0.9277 - val_conv1d_12_coeff_determination: 0.9228
# Epoch 48/500
# 13/15 [=========================>....] - ETA: 0s - loss: 7.6204e-04 - conv1d_19_loss: 3.2690e-04 - conv1d_12_loss: 4.3515e-04 - conv1d_19_coeff_determination: 0.9826 - conv1d_12_coeff_determination: 0.9767
# Epoch 00048: val_loss did not improve from 0.00171
# 15/15 [==============================] - 0s 10ms/step - loss: 7.5996e-04 - conv1d_19_loss: 3.2664e-04 - conv1d_12_loss: 4.3332e-04 - conv1d_19_coeff_determination: 0.9822 - conv1d_12_coeff_determination: 0.9770 - val_loss: 0.0018 - val_conv1d_19_loss: 7.9002e-04 - val_conv1d_12_loss: 9.7532e-04 - val_conv1d_19_coeff_determination: 0.9352 - val_conv1d_12_coeff_determination: 0.9253
# Epoch 49/500
# 13/15 [=========================>....] - ETA: 0s - loss: 7.4775e-04 - conv1d_19_loss: 3.2968e-04 - conv1d_12_loss: 4.1807e-04 - conv1d_19_coeff_determination: 0.9825 - conv1d_12_coeff_determination: 0.9776
# Epoch 00049: val_loss improved from 0.00171 to 0.00170, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 7.3764e-04 - conv1d_19_loss: 3.2265e-04 - conv1d_12_loss: 4.1499e-04 - conv1d_19_coeff_determination: 0.9832 - conv1d_12_coeff_determination: 0.9781 - val_loss: 0.0017 - val_conv1d_19_loss: 8.0213e-04 - val_conv1d_12_loss: 9.0231e-04 - val_conv1d_19_coeff_determination: 0.9347 - val_conv1d_12_coeff_determination: 0.9283
# Epoch 50/500
# 14/15 [===========================>..] - ETA: 0s - loss: 7.1397e-04 - conv1d_19_loss: 3.1714e-04 - conv1d_12_loss: 3.9683e-04 - conv1d_19_coeff_determination: 0.9832 - conv1d_12_coeff_determination: 0.9787
# Epoch 00050: val_loss improved from 0.00170 to 0.00169, saving model to best_weights.h5
# 15/15 [==============================] - 0s 11ms/step - loss: 7.1304e-04 - conv1d_19_loss: 3.1658e-04 - conv1d_12_loss: 3.9646e-04 - conv1d_19_coeff_determination: 0.9840 - conv1d_12_coeff_determination: 0.9793 - val_loss: 0.0017 - val_conv1d_19_loss: 7.9491e-04 - val_conv1d_12_loss: 8.9645e-04 - val_conv1d_19_coeff_determination: 0.9360 - val_conv1d_12_coeff_determination: 0.9288
# Epoch 51/500
# 15/15 [==============================] - ETA: 0s - loss: 6.9802e-04 - conv1d_19_loss: 3.0743e-04 - conv1d_12_loss: 3.9059e-04 - conv1d_19_coeff_determination: 0.9845 - conv1d_12_coeff_determination: 0.9798
# Epoch 00051: val_loss did not improve from 0.00169
# 15/15 [==============================] - 0s 9ms/step - loss: 6.9802e-04 - conv1d_19_loss: 3.0743e-04 - conv1d_12_loss: 3.9059e-04 - conv1d_19_coeff_determination: 0.9845 - conv1d_12_coeff_determination: 0.9798 - val_loss: 0.0017 - val_conv1d_19_loss: 7.9354e-04 - val_conv1d_12_loss: 9.4135e-04 - val_conv1d_19_coeff_determination: 0.9337 - val_conv1d_12_coeff_determination: 0.9231
# Epoch 52/500
# 14/15 [===========================>..] - ETA: 0s - loss: 6.9074e-04 - conv1d_19_loss: 3.0632e-04 - conv1d_12_loss: 3.8442e-04 - conv1d_19_coeff_determination: 0.9837 - conv1d_12_coeff_determination: 0.9794
# Epoch 00052: val_loss did not improve from 0.00169
# 15/15 [==============================] - 0s 9ms/step - loss: 6.9028e-04 - conv1d_19_loss: 3.0588e-04 - conv1d_12_loss: 3.8440e-04 - conv1d_19_coeff_determination: 0.9844 - conv1d_12_coeff_determination: 0.9793 - val_loss: 0.0021 - val_conv1d_19_loss: 9.6165e-04 - val_conv1d_12_loss: 0.0012 - val_conv1d_19_coeff_determination: 0.9236 - val_conv1d_12_coeff_determination: 0.9100
# Epoch 53/500
# 14/15 [===========================>..] - ETA: 0s - loss: 7.5946e-04 - conv1d_19_loss: 3.4126e-04 - conv1d_12_loss: 4.1820e-04 - conv1d_19_coeff_determination: 0.9818 - conv1d_12_coeff_determination: 0.9776
# Epoch 00053: val_loss did not improve from 0.00169
# 15/15 [==============================] - 0s 10ms/step - loss: 7.6167e-04 - conv1d_19_loss: 3.4251e-04 - conv1d_12_loss: 4.1917e-04 - conv1d_19_coeff_determination: 0.9805 - conv1d_12_coeff_determination: 0.9767 - val_loss: 0.0022 - val_conv1d_19_loss: 9.2412e-04 - val_conv1d_12_loss: 0.0012 - val_conv1d_19_coeff_determination: 0.9294 - val_conv1d_12_coeff_determination: 0.9082
# Epoch 54/500
# 13/15 [=========================>....] - ETA: 0s - loss: 7.4938e-04 - conv1d_19_loss: 3.4441e-04 - conv1d_12_loss: 4.0497e-04 - conv1d_19_coeff_determination: 0.9817 - conv1d_12_coeff_determination: 0.9783
# Epoch 00054: val_loss did not improve from 0.00169
# 15/15 [==============================] - 0s 11ms/step - loss: 7.4230e-04 - conv1d_19_loss: 3.3965e-04 - conv1d_12_loss: 4.0265e-04 - conv1d_19_coeff_determination: 0.9810 - conv1d_12_coeff_determination: 0.9776 - val_loss: 0.0017 - val_conv1d_19_loss: 8.4185e-04 - val_conv1d_12_loss: 9.0473e-04 - val_conv1d_19_coeff_determination: 0.9350 - val_conv1d_12_coeff_determination: 0.9293
# Epoch 55/500
# 13/15 [=========================>....] - ETA: 0s - loss: 6.9619e-04 - conv1d_19_loss: 3.0093e-04 - conv1d_12_loss: 3.9526e-04 - conv1d_19_coeff_determination: 0.9841 - conv1d_12_coeff_determination: 0.9789
# Epoch 00055: val_loss improved from 0.00169 to 0.00160, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 7.0245e-04 - conv1d_19_loss: 3.0554e-04 - conv1d_12_loss: 3.9691e-04 - conv1d_19_coeff_determination: 0.9828 - conv1d_12_coeff_determination: 0.9783 - val_loss: 0.0016 - val_conv1d_19_loss: 7.0686e-04 - val_conv1d_12_loss: 8.9465e-04 - val_conv1d_19_coeff_determination: 0.9429 - val_conv1d_12_coeff_determination: 0.9265
# Epoch 56/500
# 14/15 [===========================>..] - ETA: 0s - loss: 6.7226e-04 - conv1d_19_loss: 3.0535e-04 - conv1d_12_loss: 3.6690e-04 - conv1d_19_coeff_determination: 0.9839 - conv1d_12_coeff_determination: 0.9804
# Epoch 00056: val_loss improved from 0.00160 to 0.00157, saving model to best_weights.h5
# 15/15 [==============================] - 0s 12ms/step - loss: 6.7297e-04 - conv1d_19_loss: 3.0578e-04 - conv1d_12_loss: 3.6718e-04 - conv1d_19_coeff_determination: 0.9829 - conv1d_12_coeff_determination: 0.9798 - val_loss: 0.0016 - val_conv1d_19_loss: 7.3216e-04 - val_conv1d_12_loss: 8.3487e-04 - val_conv1d_19_coeff_determination: 0.9408 - val_conv1d_12_coeff_determination: 0.9314
# Epoch 57/500
# 13/15 [=========================>....] - ETA: 0s - loss: 6.7381e-04 - conv1d_19_loss: 3.0268e-04 - conv1d_12_loss: 3.7114e-04 - conv1d_19_coeff_determination: 0.9839 - conv1d_12_coeff_determination: 0.9801
# Epoch 00057: val_loss improved from 0.00157 to 0.00156, saving model to best_weights.h5
# 15/15 [==============================] - 0s 13ms/step - loss: 6.6756e-04 - conv1d_19_loss: 3.0022e-04 - conv1d_12_loss: 3.6734e-04 - conv1d_19_coeff_determination: 0.9848 - conv1d_12_coeff_determination: 0.9812 - val_loss: 0.0016 - val_conv1d_19_loss: 6.9187e-04 - val_conv1d_12_loss: 8.7166e-04 - val_conv1d_19_coeff_determination: 0.9447 - val_conv1d_12_coeff_determination: 0.9291
# Epoch 58/500
# 13/15 [=========================>....] - ETA: 0s - loss: 6.5448e-04 - conv1d_19_loss: 3.0051e-04 - conv1d_12_loss: 3.5397e-04 - conv1d_19_coeff_determination: 0.9841 - conv1d_12_coeff_determination: 0.9812
# Epoch 00058: val_loss did not improve from 0.00156
# 15/15 [==============================] - 0s 11ms/step - loss: 6.6114e-04 - conv1d_19_loss: 3.0477e-04 - conv1d_12_loss: 3.5637e-04 - conv1d_19_coeff_determination: 0.9831 - conv1d_12_coeff_determination: 0.9801 - val_loss: 0.0017 - val_conv1d_19_loss: 7.8310e-04 - val_conv1d_12_loss: 8.9635e-04 - val_conv1d_19_coeff_determination: 0.9347 - val_conv1d_12_coeff_determination: 0.9277
# Epoch 59/500
# 13/15 [=========================>....] - ETA: 0s - loss: 6.6036e-04 - conv1d_19_loss: 2.9754e-04 - conv1d_12_loss: 3.6282e-04 - conv1d_19_coeff_determination: 0.9842 - conv1d_12_coeff_determination: 0.9806
# Epoch 00059: val_loss did not improve from 0.00156
# 15/15 [==============================] - 0s 11ms/step - loss: 6.5773e-04 - conv1d_19_loss: 2.9707e-04 - conv1d_12_loss: 3.6066e-04 - conv1d_19_coeff_determination: 0.9850 - conv1d_12_coeff_determination: 0.9815 - val_loss: 0.0019 - val_conv1d_19_loss: 8.6092e-04 - val_conv1d_12_loss: 0.0010 - val_conv1d_19_coeff_determination: 0.9325 - val_conv1d_12_coeff_determination: 0.9224
# Epoch 60/500
# ...
# Epoch 477/500
# 11/15 [=====================>........] - ETA: 0s - loss: 5.1653e-04 - conv1d_19_loss: 2.5891e-04 - conv1d_12_loss: 2.5762e-04 - conv1d_19_coeff_determination: 0.9863 - conv1d_12_coeff_determination: 0.9863
# Epoch 00477: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 12ms/step - loss: 5.1730e-04 - conv1d_19_loss: 2.5862e-04 - conv1d_12_loss: 2.5867e-04 - conv1d_19_coeff_determination: 0.9871 - conv1d_12_coeff_determination: 0.9871 - val_loss: 0.0013 - val_conv1d_19_loss: 5.7433e-04 - val_conv1d_12_loss: 7.2068e-04 - val_conv1d_19_coeff_determination: 0.9530 - val_conv1d_12_coeff_determination: 0.9393
# Epoch 478/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.2008e-04 - conv1d_19_loss: 2.5822e-04 - conv1d_12_loss: 2.6185e-04 - conv1d_19_coeff_determination: 0.9863 - conv1d_12_coeff_determination: 0.9861
# Epoch 00478: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.2130e-04 - conv1d_19_loss: 2.5831e-04 - conv1d_12_loss: 2.6299e-04 - conv1d_19_coeff_determination: 0.9852 - conv1d_12_coeff_determination: 0.9849 - val_loss: 0.0014 - val_conv1d_19_loss: 5.5174e-04 - val_conv1d_12_loss: 8.5142e-04 - val_conv1d_19_coeff_determination: 0.9537 - val_conv1d_12_coeff_determination: 0.9284
# Epoch 479/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.0436e-04 - conv1d_19_loss: 2.5450e-04 - conv1d_12_loss: 2.4986e-04 - conv1d_19_coeff_determination: 0.9865 - conv1d_12_coeff_determination: 0.9868
# Epoch 00479: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 12ms/step - loss: 5.1219e-04 - conv1d_19_loss: 2.5807e-04 - conv1d_12_loss: 2.5412e-04 - conv1d_19_coeff_determination: 0.9853 - conv1d_12_coeff_determination: 0.9853 - val_loss: 0.0012 - val_conv1d_19_loss: 5.6916e-04 - val_conv1d_12_loss: 6.2724e-04 - val_conv1d_19_coeff_determination: 0.9528 - val_conv1d_12_coeff_determination: 0.9462
# Epoch 480/500
# 11/15 [=====================>........] - ETA: 0s - loss: 5.5522e-04 - conv1d_19_loss: 2.6742e-04 - conv1d_12_loss: 2.8779e-04 - conv1d_19_coeff_determination: 0.9859 - conv1d_12_coeff_determination: 0.9849
# Epoch 00480: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 12ms/step - loss: 5.3633e-04 - conv1d_19_loss: 2.5889e-04 - conv1d_12_loss: 2.7744e-04 - conv1d_19_coeff_determination: 0.9862 - conv1d_12_coeff_determination: 0.9849 - val_loss: 0.0014 - val_conv1d_19_loss: 6.3345e-04 - val_conv1d_12_loss: 7.6764e-04 - val_conv1d_19_coeff_determination: 0.9479 - val_conv1d_12_coeff_determination: 0.9343
# Epoch 481/500
# 13/15 [=========================>....] - ETA: 0s - loss: 5.2985e-04 - conv1d_19_loss: 2.5813e-04 - conv1d_12_loss: 2.7172e-04 - conv1d_19_coeff_determination: 0.9863 - conv1d_12_coeff_determination: 0.9856
# Epoch 00481: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.3711e-04 - conv1d_19_loss: 2.6207e-04 - conv1d_12_loss: 2.7504e-04 - conv1d_19_coeff_determination: 0.9858 - conv1d_12_coeff_determination: 0.9849 - val_loss: 0.0014 - val_conv1d_19_loss: 5.8957e-04 - val_conv1d_12_loss: 7.9323e-04 - val_conv1d_19_coeff_determination: 0.9526 - val_conv1d_12_coeff_determination: 0.9351
# Epoch 482/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1930e-04 - conv1d_19_loss: 2.6088e-04 - conv1d_12_loss: 2.5842e-04 - conv1d_19_coeff_determination: 0.9862 - conv1d_12_coeff_determination: 0.9864
# Epoch 00482: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.2206e-04 - conv1d_19_loss: 2.6236e-04 - conv1d_12_loss: 2.5970e-04 - conv1d_19_coeff_determination: 0.9869 - conv1d_12_coeff_determination: 0.9870 - val_loss: 0.0015 - val_conv1d_19_loss: 7.0227e-04 - val_conv1d_12_loss: 8.2450e-04 - val_conv1d_19_coeff_determination: 0.9435 - val_conv1d_12_coeff_determination: 0.9303
# Epoch 483/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1665e-04 - conv1d_19_loss: 2.5495e-04 - conv1d_12_loss: 2.6170e-04 - conv1d_19_coeff_determination: 0.9865 - conv1d_12_coeff_determination: 0.9861
# Epoch 00483: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0960e-04 - conv1d_19_loss: 2.5258e-04 - conv1d_12_loss: 2.5701e-04 - conv1d_19_coeff_determination: 0.9874 - conv1d_12_coeff_determination: 0.9871 - val_loss: 0.0013 - val_conv1d_19_loss: 5.7664e-04 - val_conv1d_12_loss: 7.5491e-04 - val_conv1d_19_coeff_determination: 0.9527 - val_conv1d_12_coeff_determination: 0.9364
# Epoch 484/500
# 12/15 [=======================>......] - ETA: 0s - loss: 4.9311e-04 - conv1d_19_loss: 2.4607e-04 - conv1d_12_loss: 2.4704e-04 - conv1d_19_coeff_determination: 0.9870 - conv1d_12_coeff_determination: 0.9869
# Epoch 00484: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 4.9789e-04 - conv1d_19_loss: 2.4854e-04 - conv1d_12_loss: 2.4935e-04 - conv1d_19_coeff_determination: 0.9856 - conv1d_12_coeff_determination: 0.9854 - val_loss: 0.0012 - val_conv1d_19_loss: 5.3493e-04 - val_conv1d_12_loss: 7.1188e-04 - val_conv1d_19_coeff_determination: 0.9561 - val_conv1d_12_coeff_determination: 0.9407
# Epoch 485/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1016e-04 - conv1d_19_loss: 2.4893e-04 - conv1d_12_loss: 2.6123e-04 - conv1d_19_coeff_determination: 0.9869 - conv1d_12_coeff_determination: 0.9862
# Epoch 00485: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.1525e-04 - conv1d_19_loss: 2.5225e-04 - conv1d_12_loss: 2.6300e-04 - conv1d_19_coeff_determination: 0.9871 - conv1d_12_coeff_determination: 0.9864 - val_loss: 0.0012 - val_conv1d_19_loss: 5.3542e-04 - val_conv1d_12_loss: 7.0223e-04 - val_conv1d_19_coeff_determination: 0.9563 - val_conv1d_12_coeff_determination: 0.9396
# Epoch 486/500
# 13/15 [=========================>....] - ETA: 0s - loss: 5.1358e-04 - conv1d_19_loss: 2.5431e-04 - conv1d_12_loss: 2.5927e-04 - conv1d_19_coeff_determination: 0.9866 - conv1d_12_coeff_determination: 0.9863
# Epoch 00486: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.1455e-04 - conv1d_19_loss: 2.5458e-04 - conv1d_12_loss: 2.5997e-04 - conv1d_19_coeff_determination: 0.9857 - conv1d_12_coeff_determination: 0.9852 - val_loss: 0.0013 - val_conv1d_19_loss: 5.9352e-04 - val_conv1d_12_loss: 7.0317e-04 - val_conv1d_19_coeff_determination: 0.9516 - val_conv1d_12_coeff_determination: 0.9411
# Epoch 487/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1865e-04 - conv1d_19_loss: 2.5757e-04 - conv1d_12_loss: 2.6108e-04 - conv1d_19_coeff_determination: 0.9864 - conv1d_12_coeff_determination: 0.9862
# Epoch 00487: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0714e-04 - conv1d_19_loss: 2.5197e-04 - conv1d_12_loss: 2.5518e-04 - conv1d_19_coeff_determination: 0.9872 - conv1d_12_coeff_determination: 0.9871 - val_loss: 0.0013 - val_conv1d_19_loss: 5.9054e-04 - val_conv1d_12_loss: 7.5130e-04 - val_conv1d_19_coeff_determination: 0.9506 - val_conv1d_12_coeff_determination: 0.9363
# Epoch 488/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.0195e-04 - conv1d_19_loss: 2.4986e-04 - conv1d_12_loss: 2.5209e-04 - conv1d_19_coeff_determination: 0.9868 - conv1d_12_coeff_determination: 0.9866
# Epoch 00488: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 12ms/step - loss: 5.0976e-04 - conv1d_19_loss: 2.5392e-04 - conv1d_12_loss: 2.5583e-04 - conv1d_19_coeff_determination: 0.9874 - conv1d_12_coeff_determination: 0.9873 - val_loss: 0.0012 - val_conv1d_19_loss: 5.5235e-04 - val_conv1d_12_loss: 6.7563e-04 - val_conv1d_19_coeff_determination: 0.9540 - val_conv1d_12_coeff_determination: 0.9427
# Epoch 489/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1698e-04 - conv1d_19_loss: 2.5634e-04 - conv1d_12_loss: 2.6064e-04 - conv1d_19_coeff_determination: 0.9865 - conv1d_12_coeff_determination: 0.9863
# Epoch 00489: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0456e-04 - conv1d_19_loss: 2.5033e-04 - conv1d_12_loss: 2.5424e-04 - conv1d_19_coeff_determination: 0.9876 - conv1d_12_coeff_determination: 0.9874 - val_loss: 0.0014 - val_conv1d_19_loss: 6.0937e-04 - val_conv1d_12_loss: 7.6176e-04 - val_conv1d_19_coeff_determination: 0.9501 - val_conv1d_12_coeff_determination: 0.9365
# Epoch 490/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.2344e-04 - conv1d_19_loss: 2.6154e-04 - conv1d_12_loss: 2.6190e-04 - conv1d_19_coeff_determination: 0.9862 - conv1d_12_coeff_determination: 0.9862
# Epoch 00490: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 12ms/step - loss: 5.0029e-04 - conv1d_19_loss: 2.4996e-04 - conv1d_12_loss: 2.5033e-04 - conv1d_19_coeff_determination: 0.9868 - conv1d_12_coeff_determination: 0.9866 - val_loss: 0.0013 - val_conv1d_19_loss: 5.6904e-04 - val_conv1d_12_loss: 7.5170e-04 - val_conv1d_19_coeff_determination: 0.9541 - val_conv1d_12_coeff_determination: 0.9370
# Epoch 491/500
# 12/15 [=======================>......] - ETA: 0s - loss: 4.9690e-04 - conv1d_19_loss: 2.5037e-04 - conv1d_12_loss: 2.4653e-04 - conv1d_19_coeff_determination: 0.9868 - conv1d_12_coeff_determination: 0.9870
# Epoch 00491: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 4.9900e-04 - conv1d_19_loss: 2.5044e-04 - conv1d_12_loss: 2.4856e-04 - conv1d_19_coeff_determination: 0.9872 - conv1d_12_coeff_determination: 0.9874 - val_loss: 0.0013 - val_conv1d_19_loss: 5.9034e-04 - val_conv1d_12_loss: 6.8247e-04 - val_conv1d_19_coeff_determination: 0.9512 - val_conv1d_12_coeff_determination: 0.9425
# Epoch 492/500
# 13/15 [=========================>....] - ETA: 0s - loss: 5.1199e-04 - conv1d_19_loss: 2.5491e-04 - conv1d_12_loss: 2.5708e-04 - conv1d_19_coeff_determination: 0.9865 - conv1d_12_coeff_determination: 0.9864
# Epoch 00492: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 4.9972e-04 - conv1d_19_loss: 2.4900e-04 - conv1d_12_loss: 2.5071e-04 - conv1d_19_coeff_determination: 0.9868 - conv1d_12_coeff_determination: 0.9864 - val_loss: 0.0012 - val_conv1d_19_loss: 5.5510e-04 - val_conv1d_12_loss: 6.9008e-04 - val_conv1d_19_coeff_determination: 0.9533 - val_conv1d_12_coeff_determination: 0.9415
# Epoch 493/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1122e-04 - conv1d_19_loss: 2.5259e-04 - conv1d_12_loss: 2.5863e-04 - conv1d_19_coeff_determination: 0.9867 - conv1d_12_coeff_determination: 0.9863
# Epoch 00493: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0899e-04 - conv1d_19_loss: 2.5213e-04 - conv1d_12_loss: 2.5685e-04 - conv1d_19_coeff_determination: 0.9875 - conv1d_12_coeff_determination: 0.9872 - val_loss: 0.0012 - val_conv1d_19_loss: 5.3519e-04 - val_conv1d_12_loss: 6.2225e-04 - val_conv1d_19_coeff_determination: 0.9570 - val_conv1d_12_coeff_determination: 0.9473
# Epoch 494/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.0842e-04 - conv1d_19_loss: 2.5192e-04 - conv1d_12_loss: 2.5650e-04 - conv1d_19_coeff_determination: 0.9868 - conv1d_12_coeff_determination: 0.9865
# Epoch 00494: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.1538e-04 - conv1d_19_loss: 2.5529e-04 - conv1d_12_loss: 2.6009e-04 - conv1d_19_coeff_determination: 0.9863 - conv1d_12_coeff_determination: 0.9858 - val_loss: 0.0014 - val_conv1d_19_loss: 6.3128e-04 - val_conv1d_12_loss: 7.7202e-04 - val_conv1d_19_coeff_determination: 0.9486 - val_conv1d_12_coeff_determination: 0.9357
# Epoch 495/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.0386e-04 - conv1d_19_loss: 2.5084e-04 - conv1d_12_loss: 2.5302e-04 - conv1d_19_coeff_determination: 0.9867 - conv1d_12_coeff_determination: 0.9866
# Epoch 00495: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.1029e-04 - conv1d_19_loss: 2.5356e-04 - conv1d_12_loss: 2.5673e-04 - conv1d_19_coeff_determination: 0.9856 - conv1d_12_coeff_determination: 0.9855 - val_loss: 0.0014 - val_conv1d_19_loss: 5.9906e-04 - val_conv1d_12_loss: 7.7494e-04 - val_conv1d_19_coeff_determination: 0.9502 - val_conv1d_12_coeff_determination: 0.9352
# Epoch 496/500
# 11/15 [=====================>........] - ETA: 0s - loss: 5.0703e-04 - conv1d_19_loss: 2.5479e-04 - conv1d_12_loss: 2.5224e-04 - conv1d_19_coeff_determination: 0.9865 - conv1d_12_coeff_determination: 0.9866
# Epoch 00496: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0869e-04 - conv1d_19_loss: 2.5552e-04 - conv1d_12_loss: 2.5316e-04 - conv1d_19_coeff_determination: 0.9858 - conv1d_12_coeff_determination: 0.9857 - val_loss: 0.0012 - val_conv1d_19_loss: 5.1740e-04 - val_conv1d_12_loss: 6.7625e-04 - val_conv1d_19_coeff_determination: 0.9573 - val_conv1d_12_coeff_determination: 0.9425
# Epoch 497/500
# 13/15 [=========================>....] - ETA: 0s - loss: 5.3325e-04 - conv1d_19_loss: 2.5802e-04 - conv1d_12_loss: 2.7522e-04 - conv1d_19_coeff_determination: 0.9863 - conv1d_12_coeff_determination: 0.9854
# Epoch 00497: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 12ms/step - loss: 5.3326e-04 - conv1d_19_loss: 2.5860e-04 - conv1d_12_loss: 2.7466e-04 - conv1d_19_coeff_determination: 0.9872 - conv1d_12_coeff_determination: 0.9864 - val_loss: 0.0014 - val_conv1d_19_loss: 5.6995e-04 - val_conv1d_12_loss: 8.0109e-04 - val_conv1d_19_coeff_determination: 0.9539 - val_conv1d_12_coeff_determination: 0.9317
# Epoch 498/500
# 13/15 [=========================>....] - ETA: 0s - loss: 5.0688e-04 - conv1d_19_loss: 2.5310e-04 - conv1d_12_loss: 2.5378e-04 - conv1d_19_coeff_determination: 0.9866 - conv1d_12_coeff_determination: 0.9865
# Epoch 00498: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0749e-04 - conv1d_19_loss: 2.5257e-04 - conv1d_12_loss: 2.5492e-04 - conv1d_19_coeff_determination: 0.9857 - conv1d_12_coeff_determination: 0.9856 - val_loss: 0.0013 - val_conv1d_19_loss: 5.9787e-04 - val_conv1d_12_loss: 7.4237e-04 - val_conv1d_19_coeff_determination: 0.9501 - val_conv1d_12_coeff_determination: 0.9380
# Epoch 499/500
# 13/15 [=========================>....] - ETA: 0s - loss: 5.0093e-04 - conv1d_19_loss: 2.5068e-04 - conv1d_12_loss: 2.5025e-04 - conv1d_19_coeff_determination: 0.9867 - conv1d_12_coeff_determination: 0.9867
# Epoch 00499: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0275e-04 - conv1d_19_loss: 2.5126e-04 - conv1d_12_loss: 2.5149e-04 - conv1d_19_coeff_determination: 0.9874 - conv1d_12_coeff_determination: 0.9874 - val_loss: 0.0013 - val_conv1d_19_loss: 5.6709e-04 - val_conv1d_12_loss: 7.2362e-04 - val_conv1d_19_coeff_determination: 0.9538 - val_conv1d_12_coeff_determination: 0.9384
# Epoch 500/500
# 12/15 [=======================>......] - ETA: 0s - loss: 5.1216e-04 - conv1d_19_loss: 2.5546e-04 - conv1d_12_loss: 2.5670e-04 - conv1d_19_coeff_determination: 0.9865 - conv1d_12_coeff_determination: 0.9864
# Epoch 00500: val_loss did not improve from 0.00092
# 15/15 [==============================] - 0s 11ms/step - loss: 5.0431e-04 - conv1d_19_loss: 2.5206e-04 - conv1d_12_loss: 2.5225e-04 - conv1d_19_coeff_determination: 0.9873 - conv1d_12_coeff_determination: 0.9873 - val_loss: 0.0013 - val_conv1d_19_loss: 5.5403e-04 - val_conv1d_12_loss: 7.1103e-04 - val_conv1d_19_coeff_determination: 0.9551 - val_conv1d_12_coeff_determination: 0.9407

# %% [markdown]
# ### Check accuracy of Autoencoder

# %%
import matplotlib.pyplot as plt
model.load_weights(weights_filepath)
recoded_1 = model.predict(snapshots_valid)[0]

for i in range(0,snapshots_valid.shape[0],50):
    plt.figure(figsize=(7,6))
    plt.plot(snapshots_valid[i,:,0:],label='Truth',linewidth=3)
    plt.plot(recoded_1[i,:,0:],'ro',label='Reconstructed')
    plt.xlabel('x')
    plt.ylabel('u')
    plt.ylim((0,0.5))
    plt.tight_layout()
    plt.legend()
    plt.show()
