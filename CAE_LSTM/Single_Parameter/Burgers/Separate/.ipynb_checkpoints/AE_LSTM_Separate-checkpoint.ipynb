# %%
import numpy as np
import tensorflow as tf

# Set seeds
np.random.seed(10)
tf.random.set_seed(10)

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda, Dropout, Reshape, Flatten
from tensorflow.keras.layers import Conv1D, TimeDistributed, UpSampling1D, MaxPooling1D
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential, Model

# %% [markdown]
# ### Some global variables

# %%
Rnum = 1000
x = np.linspace(0.0,1.0,num=128)
dx = 1.0/np.shape(x)[0]
tsteps = np.linspace(0.0,2.0,num=400)
dt = 2.0/np.shape(tsteps)[0]
mode = 'train'

# %% [markdown]
# ### Functions for full-order snapshots of Burgers Equation

# %%
def exact_solution(Rnum,t):
    t0 = np.exp(Rnum/8.0)

    return (x/(t+1))/(1.0+np.sqrt((t+1)/t0)*np.exp(Rnum*(x*x)/(4.0*t+4)))

def collect_snapshots(Rnum):
    snapshot_matrix = np.zeros(shape=(np.shape(x)[0],np.shape(tsteps)[0]))

    trange = np.arange(np.shape(tsteps)[0])
    for t in trange:
        snapshot_matrix[:,t] = exact_solution(Rnum,tsteps[t])[:]

    return np.transpose(snapshot_matrix)

# %% [markdown]
# ### Collect some snapshot data for CNN-LSTM embedding

# %%
snapshots_train = collect_snapshots(Rnum)
snapshots_train = np.expand_dims(snapshots_train,-1)

# %% [markdown]
# ### Do some shifting for evolution predictions

# %%
snapshots_evolve = snapshots_train[1:]
snapshots_train = snapshots_train[0:-1]

# %% [markdown]
# ### ML related presets

# %%
weights_filepath = 'best_weights.h5'
lrate = 0.001

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Autoencoder and LSTM

# %%
# Encoder
encoder_inputs = Input(shape=(128,1),name='Field')

x = Conv1D(25,kernel_size=3,activation='swish',padding='same')(encoder_inputs)
enc_l2 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(15,kernel_size=3,activation='swish',padding='same')(enc_l2)
enc_l3 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(10,kernel_size=3,activation='swish',padding='same')(enc_l3)
enc_l4 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(5,kernel_size=3,activation='swish',padding='same')(enc_l4)
enc_l5 = MaxPooling1D(2,padding='same')(x)

x = Flatten()(enc_l5)
x = Dense(8,activation='swish')(x)
x = Dense(4,activation='swish')(x)
encoded = Dense(2,activation='linear')(x)

# LSTM
lstm_inputs = Reshape((1,2))(encoded)
x = LSTM(40,return_sequences=True)(lstm_inputs)
lstm_outputs = Dense(2,activation=None)(x)

# Decoder architecture (shared)
dec_layer_1 = Flatten()
dec_layer_2 = Dense(2,activation='swish')
dec_layer_3 = Dense(4,activation='swish')
dec_layer_4 = Dense(8,activation='linear')
dec_layer_5 = Reshape((8,1))

dec_layer_6 = Conv1D(5,kernel_size=3,activation='swish',padding='same')
dec_layer_7 = Conv1D(10,kernel_size=3,activation='swish',padding='same')
dec_layer_8 = Conv1D(15,kernel_size=3,activation='swish',padding='same')
dec_layer_9 = Conv1D(20,kernel_size=3,activation='swish',padding='same')
dec_layer_10 = Conv1D(1,kernel_size=3,activation=None,padding='same')

# Decoder - using LSTM
x = dec_layer_1(lstm_outputs)
x = dec_layer_2(x)
x = dec_layer_3(x)
x = dec_layer_4(x)
x = dec_layer_5(x)

x = dec_layer_6(x)
x = UpSampling1D(2)(x)

x = dec_layer_7(x)
x = UpSampling1D(2)(x)

x = dec_layer_8(x)
x = UpSampling1D(2)(x)

x = dec_layer_9(x)
x = UpSampling1D(2)(x)

lstm_decoder_outputs = dec_layer_10(x)

# Decoder - using AE only
x = dec_layer_1(encoded)
x = dec_layer_2(x)
x = dec_layer_3(x)
x = dec_layer_4(x)
x = dec_layer_5(x)

x = dec_layer_6(x)
x = UpSampling1D(2)(x)

x = dec_layer_7(x)
x = UpSampling1D(2)(x)

x = dec_layer_8(x)
x = UpSampling1D(2)(x)

x = dec_layer_9(x)
x = UpSampling1D(2)(x)

ae_decoder_outputs = dec_layer_10(x)

# Compile model
model = Model(inputs=[encoder_inputs],outputs=[ae_decoder_outputs,lstm_decoder_outputs],name='CAE-LSTM')
   
# design network
my_adam = optimizers.Adam(lr=lrate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint]

# fit network
model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination],loss_weights=[1.0,0.0])    
model.summary()

num_epochs = 500
batch_size = 4

if mode == 'train':
    train_history = model.fit(x=snapshots_train, 
                              y=[snapshots_train,snapshots_evolve], 
                              epochs=num_epochs, 
                              batch_size=batch_size, 
                              callbacks=callbacks_list,
                              validation_split=0.1)
# Out:
# Model: "CAE-LSTM"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Field (InputLayer)              [(None, 128, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 128, 25)      100         Field[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 64, 25)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 64, 15)       1140        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 32, 15)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 32, 10)       460         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 16, 10)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 16, 5)        155         max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 8, 5)         0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 40)           0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            328         flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            36          dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            10          dense_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 1, 40)        6880        reshape[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 2)         82          lstm[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2)            0           dense_3[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            6           flatten_1[0][0]
#                                                                  flatten_1[1][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            12          dense_4[0][0]
#                                                                  dense_4[1][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 8)            40          dense_5[0][0]
#                                                                  dense_5[1][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 8, 1)         0           dense_6[0][0]
#                                                                  dense_6[1][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 8, 5)         20          reshape_1[0][0]
#                                                                  reshape_1[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_4 (UpSampling1D)  (None, 16, 5)        0           conv1d_4[1][0]
# __________________________________________________________________________________________________
# up_sampling1d (UpSampling1D)    (None, 16, 5)        0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 16, 10)       160         up_sampling1d[0][0]
#                                                                  up_sampling1d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_5 (UpSampling1D)  (None, 32, 10)       0           conv1d_5[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 32, 10)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 32, 15)       465         up_sampling1d_1[0][0]
#                                                                  up_sampling1d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_6 (UpSampling1D)  (None, 64, 15)       0           conv1d_6[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_2 (UpSampling1D)  (None, 64, 15)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 64, 20)       920         up_sampling1d_2[0][0]
#                                                                  up_sampling1d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_7 (UpSampling1D)  (None, 128, 20)      0           conv1d_7[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_3 (UpSampling1D)  (None, 128, 20)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 128, 1)       61          up_sampling1d_3[0][0]
#                                                                  up_sampling1d_7[0][0]
# ==================================================================================================
# Total params: 10,875
# Trainable params: 10,875
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 79/90 [=========================>....] - ETA: 0s - loss: 0.0137 - conv1d_8_loss: 0.0137 - conv1d_8_1_loss: 0.0136 - conv1d_8_coeff_determination: -2035380.2500 - conv1d_8_1_coeff_determination: -2056707.2500
# Epoch 00001: loss improved from inf to 0.01289, saving model to best_weights.h5
# 90/90 [==============================] - 1s 11ms/step - loss: 0.0129 - conv1d_8_loss: 0.0129 - conv1d_8_1_loss: 0.0128 - conv1d_8_coeff_determination: -1786611.5000 - conv1d_8_1_coeff_determination: -1805331.8750 - val_loss: 0.0096 - val_conv1d_8_loss: 0.0096 - val_conv1d_8_1_loss: 0.0086 - val_conv1d_8_coeff_determination: -0.4055 - val_conv1d_8_1_coeff_determination: -0.4782
# Epoch 2/500
# 90/90 [==============================] - ETA: 0s - loss: 0.0052 - conv1d_8_loss: 0.0052 - conv1d_8_1_loss: 0.0062 - conv1d_8_coeff_determination: 0.4141 - conv1d_8_1_coeff_determination: 0.1640
# Epoch 00002: loss improved from 0.01289 to 0.00522, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0052 - conv1d_8_loss: 0.0052 - conv1d_8_1_loss: 0.0062 - conv1d_8_coeff_determination: 0.4141 - conv1d_8_1_coeff_determination: 0.1640 - val_loss: 0.0063 - val_conv1d_8_loss: 0.0063 - val_conv1d_8_1_loss: 0.0072 - val_conv1d_8_coeff_determination: 0.2015 - val_conv1d_8_1_coeff_determination: 0.0767
# Epoch 3/500
# 90/90 [==============================] - ETA: 0s - loss: 0.0028 - conv1d_8_loss: 0.0028 - conv1d_8_1_loss: 0.0066 - conv1d_8_coeff_determination: 0.7562 - conv1d_8_1_coeff_determination: 0.1517
# Epoch 00003: loss improved from 0.00522 to 0.00282, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0028 - conv1d_8_loss: 0.0028 - conv1d_8_1_loss: 0.0066 - conv1d_8_coeff_determination: 0.7562 - conv1d_8_1_coeff_determination: 0.1517 - val_loss: 0.0029 - val_conv1d_8_loss: 0.0029 - val_conv1d_8_1_loss: 0.0058 - val_conv1d_8_coeff_determination: 0.6438 - val_conv1d_8_1_coeff_determination: 0.3093
# Epoch 4/500
# 79/90 [=========================>....] - ETA: 0s - loss: 0.0021 - conv1d_8_loss: 0.0021 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8374 - conv1d_8_1_coeff_determination: 0.1591
# Epoch 00004: loss improved from 0.00282 to 0.00206, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0021 - conv1d_8_loss: 0.0021 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8391 - conv1d_8_1_coeff_determination: 0.1665 - val_loss: 0.0022 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0054 - val_conv1d_8_coeff_determination: 0.7425 - val_conv1d_8_1_coeff_determination: 0.3698
# Epoch 5/500
# 82/90 [==========================>...] - ETA: 0s - loss: 0.0018 - conv1d_8_loss: 0.0018 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.8597 - conv1d_8_1_coeff_determination: 0.1457
# Epoch 00005: loss improved from 0.00206 to 0.00181, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0018 - conv1d_8_loss: 0.0018 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8603 - conv1d_8_1_coeff_determination: 0.1608 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0052 - val_conv1d_8_coeff_determination: 0.7751 - val_conv1d_8_1_coeff_determination: 0.3795
# Epoch 6/500
# 77/90 [========================>.....] - ETA: 0s - loss: 0.0017 - conv1d_8_loss: 0.0017 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.8714 - conv1d_8_1_coeff_determination: 0.1630
# Epoch 00006: loss improved from 0.00181 to 0.00167, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0017 - conv1d_8_loss: 0.0017 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8722 - conv1d_8_1_coeff_determination: 0.1499 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0053 - val_conv1d_8_coeff_determination: 0.7692 - val_conv1d_8_1_coeff_determination: 0.3611
# Epoch 7/500
# 89/90 [============================>.] - ETA: 0s - loss: 0.0016 - conv1d_8_loss: 0.0016 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8821 - conv1d_8_1_coeff_determination: 0.1379
# Epoch 00007: loss improved from 0.00167 to 0.00156, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0016 - conv1d_8_loss: 0.0016 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.8820 - conv1d_8_1_coeff_determination: 0.1436 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0054 - val_conv1d_8_coeff_determination: 0.7733 - val_conv1d_8_1_coeff_determination: 0.3323
# Epoch 8/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0015 - conv1d_8_loss: 0.0015 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8892 - conv1d_8_1_coeff_determination: 0.1183
# Epoch 00008: loss improved from 0.00156 to 0.00146, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0015 - conv1d_8_loss: 0.0015 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.8900 - conv1d_8_1_coeff_determination: 0.1372 - val_loss: 0.0022 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0056 - val_conv1d_8_coeff_determination: 0.7560 - val_conv1d_8_1_coeff_determination: 0.3237
# Epoch 9/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0014 - conv1d_8_loss: 0.0014 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.8960 - conv1d_8_1_coeff_determination: 0.1204
# Epoch 00009: loss improved from 0.00146 to 0.00139, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0014 - conv1d_8_loss: 0.0014 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.8963 - conv1d_8_1_coeff_determination: 0.1327 - val_loss: 0.0024 - val_conv1d_8_loss: 0.0024 - val_conv1d_8_1_loss: 0.0058 - val_conv1d_8_coeff_determination: 0.7537 - val_conv1d_8_1_coeff_determination: 0.3103
# Epoch 10/500
# 86/90 [===========================>..] - ETA: 0s - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9002 - conv1d_8_1_coeff_determination: 0.1527
# Epoch 00010: loss improved from 0.00139 to 0.00134, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9002 - conv1d_8_1_coeff_determination: 0.1592 - val_loss: 0.0024 - val_conv1d_8_loss: 0.0024 - val_conv1d_8_1_loss: 0.0056 - val_conv1d_8_coeff_determination: 0.7336 - val_conv1d_8_1_coeff_determination: 0.2802
# Epoch 11/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.9023 - conv1d_8_1_coeff_determination: 0.1300
# Epoch 00011: loss improved from 0.00134 to 0.00131, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9026 - conv1d_8_1_coeff_determination: 0.1452 - val_loss: 0.0025 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0058 - val_conv1d_8_coeff_determination: 0.7298 - val_conv1d_8_1_coeff_determination: 0.2917
# Epoch 12/500
# 77/90 [========================>.....] - ETA: 0s - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9051 - conv1d_8_1_coeff_determination: 0.1544
# Epoch 00012: loss improved from 0.00131 to 0.00128, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0068 - conv1d_8_coeff_determination: 0.9052 - conv1d_8_1_coeff_determination: 0.1627 - val_loss: 0.0023 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0056 - val_conv1d_8_coeff_determination: 0.7376 - val_conv1d_8_1_coeff_determination: 0.2984
# Epoch 13/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0013 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9073 - conv1d_8_1_coeff_determination: 0.1472
# Epoch 00013: loss improved from 0.00128 to 0.00125, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9075 - conv1d_8_1_coeff_determination: 0.1473 - val_loss: 0.0027 - val_conv1d_8_loss: 0.0027 - val_conv1d_8_1_loss: 0.0062 - val_conv1d_8_coeff_determination: 0.7037 - val_conv1d_8_1_coeff_determination: 0.2400
# Epoch 14/500
# 77/90 [========================>.....] - ETA: 0s - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.9084 - conv1d_8_1_coeff_determination: 0.1419
# Epoch 00014: loss improved from 0.00125 to 0.00123, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0068 - conv1d_8_coeff_determination: 0.9088 - conv1d_8_1_coeff_determination: 0.1725 - val_loss: 0.0025 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0060 - val_conv1d_8_coeff_determination: 0.7210 - val_conv1d_8_1_coeff_determination: 0.2590
# Epoch 15/500
# 79/90 [=========================>....] - ETA: 0s - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0068 - conv1d_8_coeff_determination: 0.9121 - conv1d_8_1_coeff_determination: 0.1645
# Epoch 00015: loss improved from 0.00123 to 0.00119, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0068 - conv1d_8_coeff_determination: 0.9118 - conv1d_8_1_coeff_determination: 0.1665 - val_loss: 0.0028 - val_conv1d_8_loss: 0.0028 - val_conv1d_8_1_loss: 0.0066 - val_conv1d_8_coeff_determination: 0.6933 - val_conv1d_8_1_coeff_determination: 0.2044
# Epoch 16/500
# 80/90 [=========================>....] - ETA: 0s - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0067 - conv1d_8_coeff_determination: 0.9151 - conv1d_8_1_coeff_determination: 0.1868
# Epoch 00016: loss improved from 0.00119 to 0.00115, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0012 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0067 - conv1d_8_coeff_determination: 0.9151 - conv1d_8_1_coeff_determination: 0.1936 - val_loss: 0.0025 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0067 - val_conv1d_8_coeff_determination: 0.7336 - val_conv1d_8_1_coeff_determination: 0.2227
# Epoch 17/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0010 - conv1d_8_loss: 0.0010 - conv1d_8_1_loss: 0.0067 - conv1d_8_coeff_determination: 0.9246 - conv1d_8_1_coeff_determination: 0.1977
# Epoch 00017: loss improved from 0.00115 to 0.00103, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0010 - conv1d_8_loss: 0.0010 - conv1d_8_1_loss: 0.0066 - conv1d_8_coeff_determination: 0.9246 - conv1d_8_1_coeff_determination: 0.2044 - val_loss: 0.0025 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0079 - val_conv1d_8_coeff_determination: 0.7059 - val_conv1d_8_1_coeff_determination: 0.0673
# Epoch 18/500
# 79/90 [=========================>....] - ETA: 0s - loss: 8.5579e-04 - conv1d_8_loss: 8.5579e-04 - conv1d_8_1_loss: 0.0067 - conv1d_8_coeff_determination: 0.9379 - conv1d_8_1_coeff_determination: 0.2010
# Epoch 00018: loss improved from 0.00103 to 0.00084, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 8.3834e-04 - conv1d_8_loss: 8.3834e-04 - conv1d_8_1_loss: 0.0066 - conv1d_8_coeff_determination: 0.9390 - conv1d_8_1_coeff_determination: 0.2183 - val_loss: 0.0023 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.7340 - val_conv1d_8_1_coeff_determination: -0.0193
# Epoch 19/500
# 86/90 [===========================>..] - ETA: 0s - loss: 7.0407e-04 - conv1d_8_loss: 7.0407e-04 - conv1d_8_1_loss: 0.0067 - conv1d_8_coeff_determination: 0.9498 - conv1d_8_1_coeff_determination: 0.2502
# Epoch 00019: loss improved from 0.00084 to 0.00070, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 6.9993e-04 - conv1d_8_loss: 6.9993e-04 - conv1d_8_1_loss: 0.0067 - conv1d_8_coeff_determination: 0.9500 - conv1d_8_1_coeff_determination: 0.2546 - val_loss: 0.0027 - val_conv1d_8_loss: 0.0027 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.6730 - val_conv1d_8_1_coeff_determination: -0.0775
# Epoch 20/500
# 80/90 [=========================>....] - ETA: 0s - loss: 6.6048e-04 - conv1d_8_loss: 6.6048e-04 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9533 - conv1d_8_1_coeff_determination: 0.2521
# Epoch 00020: loss improved from 0.00070 to 0.00065, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 6.4862e-04 - conv1d_8_loss: 6.4862e-04 - conv1d_8_1_loss: 0.0068 - conv1d_8_coeff_determination: 0.9540 - conv1d_8_1_coeff_determination: 0.2626 - val_loss: 0.0025 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0099 - val_conv1d_8_coeff_determination: 0.7253 - val_conv1d_8_1_coeff_determination: -0.0322
# Epoch 21/500
# 84/90 [===========================>..] - ETA: 0s - loss: 6.3342e-04 - conv1d_8_loss: 6.3342e-04 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.9554 - conv1d_8_1_coeff_determination: 0.2671
# Epoch 00021: loss improved from 0.00065 to 0.00063, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 6.2772e-04 - conv1d_8_loss: 6.2772e-04 - conv1d_8_1_loss: 0.0068 - conv1d_8_coeff_determination: 0.9556 - conv1d_8_1_coeff_determination: 0.2804 - val_loss: 0.0021 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0095 - val_conv1d_8_coeff_determination: 0.7426 - val_conv1d_8_1_coeff_determination: -0.0546
# Epoch 22/500
# 81/90 [==========================>...] - ETA: 0s - loss: 5.8915e-04 - conv1d_8_loss: 5.8915e-04 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9588 - conv1d_8_1_coeff_determination: 0.2817
# Epoch 00022: loss improved from 0.00063 to 0.00059, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.8639e-04 - conv1d_8_loss: 5.8639e-04 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9587 - conv1d_8_1_coeff_determination: 0.2843 - val_loss: 0.0024 - val_conv1d_8_loss: 0.0024 - val_conv1d_8_1_loss: 0.0100 - val_conv1d_8_coeff_determination: 0.7292 - val_conv1d_8_1_coeff_determination: -0.0048
# Epoch 23/500
# 84/90 [===========================>..] - ETA: 0s - loss: 5.6488e-04 - conv1d_8_loss: 5.6488e-04 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9602 - conv1d_8_1_coeff_determination: 0.2961
# Epoch 00023: loss improved from 0.00059 to 0.00056, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.6268e-04 - conv1d_8_loss: 5.6268e-04 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9604 - conv1d_8_1_coeff_determination: 0.2976 - val_loss: 0.0021 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0099 - val_conv1d_8_coeff_determination: 0.7683 - val_conv1d_8_1_coeff_determination: 0.0293
# Epoch 24/500
# 77/90 [========================>.....] - ETA: 0s - loss: 5.4802e-04 - conv1d_8_loss: 5.4802e-04 - conv1d_8_1_loss: 0.0069 - conv1d_8_coeff_determination: 0.9616 - conv1d_8_1_coeff_determination: 0.3130
# Epoch 00024: loss improved from 0.00056 to 0.00055, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.4826e-04 - conv1d_8_loss: 5.4826e-04 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.9614 - conv1d_8_1_coeff_determination: 0.3039 - val_loss: 0.0021 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0100 - val_conv1d_8_coeff_determination: 0.7835 - val_conv1d_8_1_coeff_determination: 0.0627
# Epoch 25/500
# 87/90 [============================>.] - ETA: 0s - loss: 5.3828e-04 - conv1d_8_loss: 5.3828e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9621 - conv1d_8_1_coeff_determination: 0.3086
# Epoch 00025: loss improved from 0.00055 to 0.00054, saving model to best_weights.h5
# 90/90 [==============================] - 0s 6ms/step - loss: 5.3851e-04 - conv1d_8_loss: 5.3851e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9619 - conv1d_8_1_coeff_determination: 0.3143 - val_loss: 0.0023 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0099 - val_conv1d_8_coeff_determination: 0.7473 - val_conv1d_8_1_coeff_determination: 0.0275
# Epoch 26/500
# 83/90 [==========================>...] - ETA: 0s - loss: 5.2634e-04 - conv1d_8_loss: 5.2634e-04 - conv1d_8_1_loss: 0.0070 - conv1d_8_coeff_determination: 0.9628 - conv1d_8_1_coeff_determination: 0.3257
# Epoch 00026: loss improved from 0.00054 to 0.00053, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 5.2766e-04 - conv1d_8_loss: 5.2766e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9628 - conv1d_8_1_coeff_determination: 0.3149 - val_loss: 0.0021 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0100 - val_conv1d_8_coeff_determination: 0.7661 - val_conv1d_8_1_coeff_determination: 0.0250
# Epoch 27/500
# 83/90 [==========================>...] - ETA: 0s - loss: 5.2543e-04 - conv1d_8_loss: 5.2543e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9633 - conv1d_8_1_coeff_determination: 0.3065
# Epoch 00027: loss improved from 0.00053 to 0.00052, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.2022e-04 - conv1d_8_loss: 5.2022e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9635 - conv1d_8_1_coeff_determination: 0.3172 - val_loss: 0.0021 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0102 - val_conv1d_8_coeff_determination: 0.7840 - val_conv1d_8_1_coeff_determination: 0.0545
# Epoch 28/500
# 85/90 [===========================>..] - ETA: 0s - loss: 5.0821e-04 - conv1d_8_loss: 5.0821e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9639 - conv1d_8_1_coeff_determination: 0.3201
# Epoch 00028: loss improved from 0.00052 to 0.00050, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.0309e-04 - conv1d_8_loss: 5.0309e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9643 - conv1d_8_1_coeff_determination: 0.3247 - val_loss: 0.0024 - val_conv1d_8_loss: 0.0024 - val_conv1d_8_1_loss: 0.0105 - val_conv1d_8_coeff_determination: 0.7461 - val_conv1d_8_1_coeff_determination: 0.0287
# Epoch 29/500
# 88/90 [============================>.] - ETA: 0s - loss: 4.9040e-04 - conv1d_8_loss: 4.9040e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9656 - conv1d_8_1_coeff_determination: 0.3220
# Epoch 00029: loss improved from 0.00050 to 0.00049, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 4.8873e-04 - conv1d_8_loss: 4.8873e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9656 - conv1d_8_1_coeff_determination: 0.3307 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0104 - val_conv1d_8_coeff_determination: 0.7948 - val_conv1d_8_1_coeff_determination: 0.0826
# Epoch 30/500
# 84/90 [===========================>..] - ETA: 0s - loss: 4.8781e-04 - conv1d_8_loss: 4.8781e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9656 - conv1d_8_1_coeff_determination: 0.3272
# Epoch 00030: loss did not improve from 0.00049
# 90/90 [==============================] - 1s 6ms/step - loss: 4.8921e-04 - conv1d_8_loss: 4.8921e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9656 - conv1d_8_1_coeff_determination: 0.3235 - val_loss: 0.0022 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0108 - val_conv1d_8_coeff_determination: 0.7604 - val_conv1d_8_1_coeff_determination: 0.0333
# Epoch 31/500
# 85/90 [===========================>..] - ETA: 0s - loss: 4.7439e-04 - conv1d_8_loss: 4.7439e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9669 - conv1d_8_1_coeff_determination: 0.3289
# Epoch 00031: loss improved from 0.00049 to 0.00047, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 4.7396e-04 - conv1d_8_loss: 4.7396e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9668 - conv1d_8_1_coeff_determination: 0.3366 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0107 - val_conv1d_8_coeff_determination: 0.7728 - val_conv1d_8_1_coeff_determination: 0.0024
# Epoch 32/500
# 81/90 [==========================>...] - ETA: 0s - loss: 4.6495e-04 - conv1d_8_loss: 4.6495e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9670 - conv1d_8_1_coeff_determination: 0.3402
# Epoch 00032: loss improved from 0.00047 to 0.00046, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 4.6446e-04 - conv1d_8_loss: 4.6446e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9673 - conv1d_8_1_coeff_determination: 0.3374 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0105 - val_conv1d_8_coeff_determination: 0.7942 - val_conv1d_8_1_coeff_determination: 0.0476
# Epoch 33/500
# 90/90 [==============================] - ETA: 0s - loss: 4.5442e-04 - conv1d_8_loss: 4.5442e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9679 - conv1d_8_1_coeff_determination: 0.3418
# Epoch 00033: loss improved from 0.00046 to 0.00045, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 4.5442e-04 - conv1d_8_loss: 4.5442e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9679 - conv1d_8_1_coeff_determination: 0.3418 - val_loss: 0.0022 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0106 - val_conv1d_8_coeff_determination: 0.7356 - val_conv1d_8_1_coeff_determination: -0.0694
# Epoch 34/500
# 84/90 [===========================>..] - ETA: 0s - loss: 4.5003e-04 - conv1d_8_loss: 4.5003e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9681 - conv1d_8_1_coeff_determination: 0.3395
# Epoch 00034: loss improved from 0.00045 to 0.00045, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 4.4917e-04 - conv1d_8_loss: 4.4917e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9684 - conv1d_8_1_coeff_determination: 0.3435 - val_loss: 0.0021 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0108 - val_conv1d_8_coeff_determination: 0.7766 - val_conv1d_8_1_coeff_determination: 0.0056
# Epoch 35/500
# 90/90 [==============================] - ETA: 0s - loss: 4.2346e-04 - conv1d_8_loss: 4.2346e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9701 - conv1d_8_1_coeff_determination: 0.3458
# Epoch 00035: loss improved from 0.00045 to 0.00042, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 4.2346e-04 - conv1d_8_loss: 4.2346e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9701 - conv1d_8_1_coeff_determination: 0.3458 - val_loss: 0.0018 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0106 - val_conv1d_8_coeff_determination: 0.8097 - val_conv1d_8_1_coeff_determination: -2.9460e-04
# Epoch 36/500
# 84/90 [===========================>..] - ETA: 0s - loss: 4.0090e-04 - conv1d_8_loss: 4.0090e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9719 - conv1d_8_1_coeff_determination: 0.3426
# Epoch 00036: loss improved from 0.00042 to 0.00040, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 3.9789e-04 - conv1d_8_loss: 3.9789e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9721 - conv1d_8_1_coeff_determination: 0.3452 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0111 - val_conv1d_8_coeff_determination: 0.7749 - val_conv1d_8_1_coeff_determination: -0.0439
# Epoch 37/500
# 90/90 [==============================] - ETA: 0s - loss: 3.7072e-04 - conv1d_8_loss: 3.7072e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9738 - conv1d_8_1_coeff_determination: 0.3510
# Epoch 00037: loss improved from 0.00040 to 0.00037, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 3.7072e-04 - conv1d_8_loss: 3.7072e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9738 - conv1d_8_1_coeff_determination: 0.3510 - val_loss: 0.0019 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0113 - val_conv1d_8_coeff_determination: 0.7836 - val_conv1d_8_1_coeff_determination: -0.0278
# Epoch 38/500
# 88/90 [============================>.] - ETA: 0s - loss: 3.7707e-04 - conv1d_8_loss: 3.7707e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9735 - conv1d_8_1_coeff_determination: 0.3572
# Epoch 00038: loss did not improve from 0.00037
# 90/90 [==============================] - 0s 5ms/step - loss: 3.7758e-04 - conv1d_8_loss: 3.7758e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9735 - conv1d_8_1_coeff_determination: 0.3497 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0114 - val_conv1d_8_coeff_determination: 0.7904 - val_conv1d_8_1_coeff_determination: -0.0079
# Epoch 39/500
# 89/90 [============================>.] - ETA: 0s - loss: 3.5453e-04 - conv1d_8_loss: 3.5453e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9751 - conv1d_8_1_coeff_determination: 0.3529
# Epoch 00039: loss improved from 0.00037 to 0.00035, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 3.5472e-04 - conv1d_8_loss: 3.5472e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9750 - conv1d_8_1_coeff_determination: 0.3537 - val_loss: 0.0018 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0110 - val_conv1d_8_coeff_determination: 0.8015 - val_conv1d_8_1_coeff_determination: -0.0327
# Epoch 40/500
# 80/90 [=========================>....] - ETA: 0s - loss: 3.7085e-04 - conv1d_8_loss: 3.7085e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9745 - conv1d_8_1_coeff_determination: 0.3380
# Epoch 00040: loss did not improve from 0.00035
# 90/90 [==============================] - 0s 5ms/step - loss: 3.5993e-04 - conv1d_8_loss: 3.5993e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9749 - conv1d_8_1_coeff_determination: 0.3569 - val_loss: 0.0023 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0114 - val_conv1d_8_coeff_determination: 0.7605 - val_conv1d_8_1_coeff_determination: -0.0358
# Epoch 41/500
# 80/90 [=========================>....] - ETA: 0s - loss: 3.5709e-04 - conv1d_8_loss: 3.5709e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9754 - conv1d_8_1_coeff_determination: 0.3428
# Epoch 00041: loss did not improve from 0.00035
# 90/90 [==============================] - 0s 5ms/step - loss: 3.5629e-04 - conv1d_8_loss: 3.5629e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9753 - conv1d_8_1_coeff_determination: 0.3534 - val_loss: 0.0022 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0114 - val_conv1d_8_coeff_determination: 0.7768 - val_conv1d_8_1_coeff_determination: -0.0087
# Epoch 42/500
# 88/90 [============================>.] - ETA: 0s - loss: 3.2482e-04 - conv1d_8_loss: 3.2482e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9773 - conv1d_8_1_coeff_determination: 0.3499
# Epoch 00042: loss improved from 0.00035 to 0.00033, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 3.2521e-04 - conv1d_8_loss: 3.2521e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9772 - conv1d_8_1_coeff_determination: 0.3534 - val_loss: 0.0019 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0114 - val_conv1d_8_coeff_determination: 0.7952 - val_conv1d_8_1_coeff_determination: 0.0016
# Epoch 43/500
# 85/90 [===========================>..] - ETA: 0s - loss: 3.1420e-04 - conv1d_8_loss: 3.1420e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9782 - conv1d_8_1_coeff_determination: 0.3597
# Epoch 00043: loss improved from 0.00033 to 0.00031, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 3.1499e-04 - conv1d_8_loss: 3.1499e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9781 - conv1d_8_1_coeff_determination: 0.3525 - val_loss: 0.0019 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0113 - val_conv1d_8_coeff_determination: 0.7948 - val_conv1d_8_1_coeff_determination: -0.0216
# Epoch 44/500
# 85/90 [===========================>..] - ETA: 0s - loss: 3.2322e-04 - conv1d_8_loss: 3.2322e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9777 - conv1d_8_1_coeff_determination: 0.3481
# Epoch 00044: loss did not improve from 0.00031
# 90/90 [==============================] - 0s 5ms/step - loss: 3.2025e-04 - conv1d_8_loss: 3.2025e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9778 - conv1d_8_1_coeff_determination: 0.3509 - val_loss: 0.0017 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0110 - val_conv1d_8_coeff_determination: 0.8094 - val_conv1d_8_1_coeff_determination: -0.0105
# Epoch 45/500
# 82/90 [==========================>...] - ETA: 0s - loss: 3.2426e-04 - conv1d_8_loss: 3.2426e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9776 - conv1d_8_1_coeff_determination: 0.3543
# Epoch 00045: loss did not improve from 0.00031
# 90/90 [==============================] - 0s 5ms/step - loss: 3.2307e-04 - conv1d_8_loss: 3.2307e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9774 - conv1d_8_1_coeff_determination: 0.3509 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0113 - val_conv1d_8_coeff_determination: 0.7621 - val_conv1d_8_1_coeff_determination: -0.0367
# Epoch 46/500
# 84/90 [===========================>..] - ETA: 0s - loss: 3.1092e-04 - conv1d_8_loss: 3.1092e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9784 - conv1d_8_1_coeff_determination: 0.3467
# Epoch 00046: loss improved from 0.00031 to 0.00031, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 3.0873e-04 - conv1d_8_loss: 3.0873e-04 - conv1d_8_1_loss: 0.0072 - conv1d_8_coeff_determination: 0.9785 - conv1d_8_1_coeff_determination: 0.3469 - val_loss: 0.0018 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0109 - val_conv1d_8_coeff_determination: 0.8010 - val_conv1d_8_1_coeff_determination: -0.0091
# Epoch 47/500
# 79/90 [=========================>....] - ETA: 0s - loss: 2.8827e-04 - conv1d_8_loss: 2.8827e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9799 - conv1d_8_1_coeff_determination: 0.3423
# Epoch 00047: loss improved from 0.00031 to 0.00030, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.9525e-04 - conv1d_8_loss: 2.9525e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9794 - conv1d_8_1_coeff_determination: 0.3452 - val_loss: 0.0017 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0115 - val_conv1d_8_coeff_determination: 0.8279 - val_conv1d_8_1_coeff_determination: 0.0450
# Epoch 48/500
# 80/90 [=========================>....] - ETA: 0s - loss: 2.9014e-04 - conv1d_8_loss: 2.9014e-04 - conv1d_8_1_loss: 0.0071 - conv1d_8_coeff_determination: 0.9798 - conv1d_8_1_coeff_determination: 0.3588
# Epoch 00048: loss improved from 0.00030 to 0.00029, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.9496e-04 - conv1d_8_loss: 2.9496e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9796 - conv1d_8_1_coeff_determination: 0.3436 - val_loss: 0.0018 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0111 - val_conv1d_8_coeff_determination: 0.8014 - val_conv1d_8_1_coeff_determination: -0.0108
# Epoch 49/500
# 79/90 [=========================>....] - ETA: 0s - loss: 2.8379e-04 - conv1d_8_loss: 2.8379e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9805 - conv1d_8_1_coeff_determination: 0.3425
# Epoch 00049: loss improved from 0.00029 to 0.00028, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.7999e-04 - conv1d_8_loss: 2.7999e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9807 - conv1d_8_1_coeff_determination: 0.3398 - val_loss: 0.0017 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0108 - val_conv1d_8_coeff_determination: 0.8052 - val_conv1d_8_1_coeff_determination: 0.0057
# Epoch 50/500
# 82/90 [==========================>...] - ETA: 0s - loss: 2.6855e-04 - conv1d_8_loss: 2.6855e-04 - conv1d_8_1_loss: 0.0073 - conv1d_8_coeff_determination: 0.9814 - conv1d_8_1_coeff_determination: 0.3448
# Epoch 00050: loss improved from 0.00028 to 0.00027, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.7415e-04 - conv1d_8_loss: 2.7415e-04 - conv1d_8_1_loss: 0.0074 - conv1d_8_coeff_determination: 0.9812 - conv1d_8_1_coeff_determination: 0.3391 - val_loss: 0.0017 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0110 - val_conv1d_8_coeff_determination: 0.8058 - val_conv1d_8_1_coeff_determination: -0.0034
# Epoch 51/500
# 83/90 [==========================>...] - ETA: 0s - loss: 2.6513e-04 - conv1d_8_loss: 2.6513e-04 - conv1d_8_1_loss: 0.0074 - conv1d_8_coeff_determination: 0.9816 - conv1d_8_1_coeff_determination: 0.3351
# Epoch 00051: loss improved from 0.00027 to 0.00026, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.6375e-04 - conv1d_8_loss: 2.6375e-04 - conv1d_8_1_loss: 0.0074 - conv1d_8_coeff_determination: 0.9817 - conv1d_8_1_coeff_determination: 0.3351 - val_loss: 0.0019 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0111 - val_conv1d_8_coeff_determination: 0.7942 - val_conv1d_8_1_coeff_determination: -0.0029
# Epoch 52/500
# 78/90 [=========================>....] - ETA: 0s - loss: 2.7944e-04 - conv1d_8_loss: 2.7944e-04 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9809 - conv1d_8_1_coeff_determination: 0.3314
# Epoch 00052: loss did not improve from 0.00026
# 90/90 [==============================] - 0s 5ms/step - loss: 2.7796e-04 - conv1d_8_loss: 2.7796e-04 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9809 - conv1d_8_1_coeff_determination: 0.3338 - val_loss: 0.0016 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0106 - val_conv1d_8_coeff_determination: 0.8146 - val_conv1d_8_1_coeff_determination: 0.0167
# Epoch 53/500
# 78/90 [=========================>....] - ETA: 0s - loss: 2.5342e-04 - conv1d_8_loss: 2.5342e-04 - conv1d_8_1_loss: 0.0074 - conv1d_8_coeff_determination: 0.9824 - conv1d_8_1_coeff_determination: 0.3341
# Epoch 00053: loss improved from 0.00026 to 0.00025, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.5344e-04 - conv1d_8_loss: 2.5344e-04 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9824 - conv1d_8_1_coeff_determination: 0.3253 - val_loss: 0.0019 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0113 - val_conv1d_8_coeff_determination: 0.8026 - val_conv1d_8_1_coeff_determination: 0.0459
# Epoch 54/500
# 89/90 [============================>.] - ETA: 0s - loss: 2.5384e-04 - conv1d_8_loss: 2.5384e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9826 - conv1d_8_1_coeff_determination: 0.3229
# Epoch 00054: loss improved from 0.00025 to 0.00025, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.5334e-04 - conv1d_8_loss: 2.5334e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9826 - conv1d_8_1_coeff_determination: 0.3253 - val_loss: 0.0020 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0108 - val_conv1d_8_coeff_determination: 0.7778 - val_conv1d_8_1_coeff_determination: 0.0297
# Epoch 55/500
# 89/90 [============================>.] - ETA: 0s - loss: 2.5408e-04 - conv1d_8_loss: 2.5408e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9825 - conv1d_8_1_coeff_determination: 0.3203
# Epoch 00055: loss did not improve from 0.00025
# 90/90 [==============================] - 0s 5ms/step - loss: 2.5378e-04 - conv1d_8_loss: 2.5378e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9825 - conv1d_8_1_coeff_determination: 0.3206 - val_loss: 0.0018 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0108 - val_conv1d_8_coeff_determination: 0.8147 - val_conv1d_8_1_coeff_determination: 0.0636
# Epoch 56/500
# 82/90 [==========================>...] - ETA: 0s - loss: 2.4679e-04 - conv1d_8_loss: 2.4679e-04 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9829 - conv1d_8_1_coeff_determination: 0.3258
# Epoch 00056: loss improved from 0.00025 to 0.00025, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.4606e-04 - conv1d_8_loss: 2.4606e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9832 - conv1d_8_1_coeff_determination: 0.3218 - val_loss: 0.0017 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0108 - val_conv1d_8_coeff_determination: 0.8058 - val_conv1d_8_1_coeff_determination: 0.0289
# Epoch 57/500
# 87/90 [============================>.] - ETA: 0s - loss: 2.4942e-04 - conv1d_8_loss: 2.4942e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9830 - conv1d_8_1_coeff_determination: 0.3186
# Epoch 00057: loss did not improve from 0.00025
# 90/90 [==============================] - 0s 5ms/step - loss: 2.4807e-04 - conv1d_8_loss: 2.4807e-04 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9831 - conv1d_8_1_coeff_determination: 0.3153 - val_loss: 0.0018 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0105 - val_conv1d_8_coeff_determination: 0.8043 - val_conv1d_8_1_coeff_determination: 0.0415
# Epoch 58/500
# 88/90 [============================>.] - ETA: 0s - loss: 2.2639e-04 - conv1d_8_loss: 2.2639e-04 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9845 - conv1d_8_1_coeff_determination: 0.3105
# Epoch 00058: loss improved from 0.00025 to 0.00023, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 2.2517e-04 - conv1d_8_loss: 2.2517e-04 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9846 - conv1d_8_1_coeff_determination: 0.3136 - val_loss: 0.0016 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0105 - val_conv1d_8_coeff_determination: 0.8182 - val_conv1d_8_1_coeff_determination: 0.0469
# Epoch 59/500
# 84/90 [===========================>..] - ETA: 0s - loss: 2.4761e-04 - conv1d_8_loss: 2.4761e-04 - conv1d_8_1_loss: 0.0079 - conv1d_8_coeff_determination: 0.9832 - conv1d_8_1_coeff_determination: 0.3020
# Epoch 00059: loss did not improve from 0.00023
# 90/90 [==============================] - 0s 5ms/step - loss: 2.4283e-04 - conv1d_8_loss: 2.4283e-04 - conv1d_8_1_loss: 0.0078 - conv1d_8_coeff_determination: 0.9834 - conv1d_8_1_coeff_determination: 0.3101 - val_loss: 0.0016 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0106 - val_conv1d_8_coeff_determination: 0.8160 - val_conv1d_8_1_coeff_determination: 0.0346
# Epoch 60/500
# 79/90 [=========================>....] - ETA: 0s - loss: 2.1177e-04 - conv1d_8_loss: 2.1177e-04 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9855 - conv1d_8_1_coeff_determination: 0.3087
# Epoch 00060: loss improved from 0.00023 to 0.00022, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 2.1932e-04 - conv1d_8_loss: 2.1932e-04 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9851 - conv1d_8_1_coeff_determination: 0.3117 - val_loss: 0.0014 - val_conv1d_8_loss: 0.0014 - val_conv1d_8_1_loss: 0.0101 - val_conv1d_8_coeff_determination: 0.8356 - val_conv1d_8_1_coeff_determination: 0.0377
# Epoch 61/500
# ...
# Epoch 172/500
# 79/90 [=========================>....] - ETA: 0s - loss: 2.3291e-05 - conv1d_8_loss: 2.3291e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9984 - conv1d_8_1_coeff_determination: 0.2426
# Epoch 00172: loss did not improve from 0.00002
# 90/90 [==============================] - 0s 4ms/step - loss: 2.3770e-05 - conv1d_8_loss: 2.3770e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9984 - conv1d_8_1_coeff_determination: 0.2396 - val_loss: 7.0853e-04 - val_conv1d_8_loss: 7.0853e-04 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.9207 - val_conv1d_8_1_coeff_determination: 0.0812
# Epoch 173/500
# 90/90 [==============================] - ETA: 0s - loss: 4.0174e-05 - conv1d_8_loss: 4.0174e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9973 - conv1d_8_1_coeff_determination: 0.2423
# Epoch 00173: loss did not improve from 0.00002
# 90/90 [==============================] - 0s 5ms/step - loss: 4.0174e-05 - conv1d_8_loss: 4.0174e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9973 - conv1d_8_1_coeff_determination: 0.2423 - val_loss: 9.1834e-04 - val_conv1d_8_loss: 9.1834e-04 - val_conv1d_8_1_loss: 0.0092 - val_conv1d_8_coeff_determination: 0.8961 - val_conv1d_8_1_coeff_determination: 0.0609
# Epoch 174/500
# 88/90 [============================>.] - ETA: 0s - loss: 2.6785e-05 - conv1d_8_loss: 2.6785e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9982 - conv1d_8_1_coeff_determination: 0.2444
# Epoch 00174: loss did not improve from 0.00002
# 90/90 [==============================] - 0s 5ms/step - loss: 2.6627e-05 - conv1d_8_loss: 2.6627e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9982 - conv1d_8_1_coeff_determination: 0.2400 - val_loss: 7.0813e-04 - val_conv1d_8_loss: 7.0813e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9205 - val_conv1d_8_1_coeff_determination: 0.0898
# Epoch 175/500
# 83/90 [==========================>...] - ETA: 0s - loss: 1.6245e-05 - conv1d_8_loss: 1.6245e-05 - conv1d_8_1_loss: 0.0078 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2141
# Epoch 00175: loss improved from 0.00002 to 0.00002, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6050e-05 - conv1d_8_loss: 1.6050e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2402 - val_loss: 6.6965e-04 - val_conv1d_8_loss: 6.6965e-04 - val_conv1d_8_1_loss: 0.0089 - val_conv1d_8_coeff_determination: 0.9243 - val_conv1d_8_1_coeff_determination: 0.0881
# Epoch 176/500
# 90/90 [==============================] - ETA: 0s - loss: 1.4891e-05 - conv1d_8_loss: 1.4891e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2379
# Epoch 00176: loss improved from 0.00002 to 0.00001, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4891e-05 - conv1d_8_loss: 1.4891e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2379 - val_loss: 8.0524e-04 - val_conv1d_8_loss: 8.0524e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9103 - val_conv1d_8_1_coeff_determination: 0.0873
# Epoch 177/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.6875e-05 - conv1d_8_loss: 1.6875e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2418
# Epoch 00177: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 6ms/step - loss: 1.6694e-05 - conv1d_8_loss: 1.6694e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2392 - val_loss: 7.3977e-04 - val_conv1d_8_loss: 7.3977e-04 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.9177 - val_conv1d_8_1_coeff_determination: 0.0916
# Epoch 178/500
# 87/90 [============================>.] - ETA: 0s - loss: 2.1911e-05 - conv1d_8_loss: 2.1911e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9985 - conv1d_8_1_coeff_determination: 0.2440
# Epoch 00178: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 2.2949e-05 - conv1d_8_loss: 2.2949e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9985 - conv1d_8_1_coeff_determination: 0.2389 - val_loss: 6.4761e-04 - val_conv1d_8_loss: 6.4761e-04 - val_conv1d_8_1_loss: 0.0088 - val_conv1d_8_coeff_determination: 0.9272 - val_conv1d_8_1_coeff_determination: 0.1102
# Epoch 179/500
# 86/90 [===========================>..] - ETA: 0s - loss: 2.7445e-05 - conv1d_8_loss: 2.7445e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9982 - conv1d_8_1_coeff_determination: 0.2431
# Epoch 00179: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 2.6891e-05 - conv1d_8_loss: 2.6891e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9982 - conv1d_8_1_coeff_determination: 0.2402 - val_loss: 7.1431e-04 - val_conv1d_8_loss: 7.1431e-04 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.9200 - val_conv1d_8_1_coeff_determination: 0.0955
# Epoch 180/500
# 84/90 [===========================>..] - ETA: 0s - loss: 1.5425e-05 - conv1d_8_loss: 1.5425e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2308
# Epoch 00180: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 6ms/step - loss: 1.5487e-05 - conv1d_8_loss: 1.5487e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2370 - val_loss: 6.0657e-04 - val_conv1d_8_loss: 6.0657e-04 - val_conv1d_8_1_loss: 0.0089 - val_conv1d_8_coeff_determination: 0.9326 - val_conv1d_8_1_coeff_determination: 0.1003
# Epoch 181/500
# 89/90 [============================>.] - ETA: 0s - loss: 1.6062e-05 - conv1d_8_loss: 1.6062e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2382
# Epoch 00181: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6051e-05 - conv1d_8_loss: 1.6051e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2406 - val_loss: 7.3075e-04 - val_conv1d_8_loss: 7.3075e-04 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.9174 - val_conv1d_8_1_coeff_determination: 0.0880
# Epoch 182/500
# 89/90 [============================>.] - ETA: 0s - loss: 2.5389e-05 - conv1d_8_loss: 2.5389e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9983 - conv1d_8_1_coeff_determination: 0.2327
# Epoch 00182: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 2.5362e-05 - conv1d_8_loss: 2.5362e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9983 - conv1d_8_1_coeff_determination: 0.2380 - val_loss: 6.3983e-04 - val_conv1d_8_loss: 6.3983e-04 - val_conv1d_8_1_loss: 0.0089 - val_conv1d_8_coeff_determination: 0.9280 - val_conv1d_8_1_coeff_determination: 0.1082
# Epoch 183/500
# 79/90 [=========================>....] - ETA: 0s - loss: 4.1389e-05 - conv1d_8_loss: 4.1389e-05 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9973 - conv1d_8_1_coeff_determination: 0.2272
# Epoch 00183: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 3.9276e-05 - conv1d_8_loss: 3.9276e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9974 - conv1d_8_1_coeff_determination: 0.2413 - val_loss: 7.5095e-04 - val_conv1d_8_loss: 7.5095e-04 - val_conv1d_8_1_loss: 0.0092 - val_conv1d_8_coeff_determination: 0.9164 - val_conv1d_8_1_coeff_determination: 0.0885
# Epoch 184/500
# 81/90 [==========================>...] - ETA: 0s - loss: 1.5947e-05 - conv1d_8_loss: 1.5947e-05 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2281
# Epoch 00184: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 6ms/step - loss: 1.5895e-05 - conv1d_8_loss: 1.5895e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2392 - val_loss: 7.3059e-04 - val_conv1d_8_loss: 7.3059e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9176 - val_conv1d_8_1_coeff_determination: 0.0905
# Epoch 185/500
# 82/90 [==========================>...] - ETA: 0s - loss: 1.8289e-05 - conv1d_8_loss: 1.8289e-05 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9988 - conv1d_8_1_coeff_determination: 0.2269
# Epoch 00185: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 6ms/step - loss: 1.8863e-05 - conv1d_8_loss: 1.8863e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9987 - conv1d_8_1_coeff_determination: 0.2386 - val_loss: 7.5278e-04 - val_conv1d_8_loss: 7.5278e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9145 - val_conv1d_8_1_coeff_determination: 0.0839
# Epoch 186/500
# 82/90 [==========================>...] - ETA: 0s - loss: 2.4265e-05 - conv1d_8_loss: 2.4265e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9984 - conv1d_8_1_coeff_determination: 0.2450
# Epoch 00186: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 6ms/step - loss: 2.4856e-05 - conv1d_8_loss: 2.4856e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9983 - conv1d_8_1_coeff_determination: 0.2394 - val_loss: 7.9874e-04 - val_conv1d_8_loss: 7.9874e-04 - val_conv1d_8_1_loss: 0.0093 - val_conv1d_8_coeff_determination: 0.9113 - val_conv1d_8_1_coeff_determination: 0.0845
# Epoch 187/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.4532e-05 - conv1d_8_loss: 1.4532e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2437
# Epoch 00187: loss improved from 0.00001 to 0.00001, saving model to best_weights.h5
# 90/90 [==============================] - 1s 7ms/step - loss: 1.4618e-05 - conv1d_8_loss: 1.4618e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2391 - val_loss: 7.2495e-04 - val_conv1d_8_loss: 7.2495e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9194 - val_conv1d_8_1_coeff_determination: 0.0983
# Epoch 188/500
# 89/90 [============================>.] - ETA: 0s - loss: 1.5220e-05 - conv1d_8_loss: 1.5220e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2349
# Epoch 00188: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5181e-05 - conv1d_8_loss: 1.5181e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2382 - val_loss: 6.8541e-04 - val_conv1d_8_loss: 6.8541e-04 - val_conv1d_8_1_loss: 0.0089 - val_conv1d_8_coeff_determination: 0.9233 - val_conv1d_8_1_coeff_determination: 0.0947
# Epoch 189/500
# 89/90 [============================>.] - ETA: 0s - loss: 1.5119e-05 - conv1d_8_loss: 1.5119e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2384
# Epoch 00189: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 7ms/step - loss: 1.5144e-05 - conv1d_8_loss: 1.5144e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2385 - val_loss: 6.2305e-04 - val_conv1d_8_loss: 6.2305e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9318 - val_conv1d_8_1_coeff_determination: 0.1054
# Epoch 190/500
# 81/90 [==========================>...] - ETA: 0s - loss: 7.0680e-05 - conv1d_8_loss: 7.0680e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9954 - conv1d_8_1_coeff_determination: 0.2426
# Epoch 00190: loss did not improve from 0.00001
# 90/90 [==============================] - 1s 6ms/step - loss: 6.5543e-05 - conv1d_8_loss: 6.5543e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9957 - conv1d_8_1_coeff_determination: 0.2468 - val_loss: 6.7032e-04 - val_conv1d_8_loss: 6.7032e-04 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.9245 - val_conv1d_8_1_coeff_determination: 0.0981
# Epoch 191/500
# 84/90 [===========================>..] - ETA: 0s - loss: 2.0875e-05 - conv1d_8_loss: 2.0875e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9986 - conv1d_8_1_coeff_determination: 0.2442
# Epoch 00191: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 2.0498e-05 - conv1d_8_loss: 2.0498e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9986 - conv1d_8_1_coeff_determination: 0.2417 - val_loss: 6.9131e-04 - val_conv1d_8_loss: 6.9131e-04 - val_conv1d_8_1_loss: 0.0093 - val_conv1d_8_coeff_determination: 0.9240 - val_conv1d_8_1_coeff_determination: 0.0943
# Epoch 192/500
# 85/90 [===========================>..] - ETA: 0s - loss: 1.4728e-05 - conv1d_8_loss: 1.4728e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2390
# Epoch 00192: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 1.4789e-05 - conv1d_8_loss: 1.4789e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9990 - conv1d_8_1_coeff_determination: 0.2424 - val_loss: 6.7669e-04 - val_conv1d_8_loss: 6.7669e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9237 - val_conv1d_8_1_coeff_determination: 0.0900
# Epoch 193/500
# 85/90 [===========================>..] - ETA: 0s - loss: 1.1963e-05 - conv1d_8_loss: 1.1963e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9992 - conv1d_8_1_coeff_determination: 0.2463
# Epoch 00193: loss improved from 0.00001 to 0.00001, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1850e-05 - conv1d_8_loss: 1.1850e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9992 - conv1d_8_1_coeff_determination: 0.2424 - val_loss: 6.6279e-04 - val_conv1d_8_loss: 6.6279e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9254 - val_conv1d_8_1_coeff_determination: 0.0950
# Epoch 194/500
# 88/90 [============================>.] - ETA: 0s - loss: 1.3098e-05 - conv1d_8_loss: 1.3098e-05 - conv1d_8_1_loss: 0.0075 - conv1d_8_coeff_determination: 0.9991 - conv1d_8_1_coeff_determination: 0.2460
# Epoch 00194: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 1.3076e-05 - conv1d_8_loss: 1.3076e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9991 - conv1d_8_1_coeff_determination: 0.2423 - val_loss: 6.9219e-04 - val_conv1d_8_loss: 6.9219e-04 - val_conv1d_8_1_loss: 0.0090 - val_conv1d_8_coeff_determination: 0.9225 - val_conv1d_8_1_coeff_determination: 0.1028
# Epoch 195/500
# 86/90 [===========================>..] - ETA: 0s - loss: 3.6245e-05 - conv1d_8_loss: 3.6245e-05 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9976 - conv1d_8_1_coeff_determination: 0.2300
# Epoch 00195: loss did not improve from 0.00001
# 90/90 [==============================] - 0s 5ms/step - loss: 3.5803e-05 - conv1d_8_loss: 3.5803e-05 - conv1d_8_1_loss: 0.0076 - conv1d_8_coeff_determination: 0.9976 - conv1d_8_1_coeff_determination: 0.2421 - val_loss: 7.0561e-04 - val_conv1d_8_loss: 7.0561e-04 - val_conv1d_8_1_loss: 0.0091 - val_conv1d_8_coeff_determination: 0.9224 - val_conv1d_8_1_coeff_determination: 0.0965
# Epoch 196/500
# 70/90 [======================>.......] - ETA: 0s - loss: 1.7160e-05 - conv1d_8_loss: 1.7160e-05 - conv1d_8_1_loss: 0.0077 - conv1d_8_coeff_determination: 0.9989 - conv1d_8_1_coeff_determination: 0.2297

# %% [markdown]
# ### Check accuracy of Autoencoder

# %%
import matplotlib.pyplot as plt
model.load_weights(weights_filepath)
recoded_1 = model.predict(snapshots_train)[0]

for i in range(0,snapshots_train.shape[0],50):
    plt.figure(figsize=(7,6))
    plt.plot(snapshots_train[i,:,0:],label='Truth',linewidth=3)
    plt.plot(recoded_1[i,:,0:],'ro',label='Reconstructed')
    plt.xlabel('x')
    plt.ylabel('u')
    plt.ylim((0,0.5))
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ### Check accuracy of Autoencoder+LSTM

# %%
import matplotlib.pyplot as plt
model.load_weights(weights_filepath)
recoded_1 = model.predict(snapshots_train)[1]

for i in range(0,snapshots_train.shape[0],50):
    plt.figure(figsize=(7,6))
    plt.plot(snapshots_train[i+1,:,0:],label='Truth',linewidth=3)
    plt.plot(recoded_1[i,:,0:],'ro',label='Reconstructed')
    plt.xlabel('x')
    plt.ylabel('u')
    plt.ylim((0,0.5))
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ### Get encoded representation

# %%
get_latent_representation = K.function([model.layers[0].input],
                                  [model.layers[12].output]) # Layer number 10 is the MaxPooling2D before entry to LSTM
layer_output = get_latent_representation([snapshots_train])[0]

# %%
plt.figure()
plt.plot(layer_output[:,0],label='Dimension 1')
plt.plot(layer_output[:,1],label='Dimension 2')
plt.legend()
plt.show()
