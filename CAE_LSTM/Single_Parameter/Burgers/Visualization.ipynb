# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
latent_continuous = np.load('./Continous/Latent.npy')
latent_separate = np.load('./Separate/Latent.npy')

# %%
plt.figure()
plt.plot(latent_continuous[:,0],label='Dimension 1 coupled')
plt.plot(latent_continuous[:,1],label='Dimension 2 coupled')
plt.plot(latent_separate[:,0],label='Dimension 1 separate')
plt.plot(latent_separate[:,1],label='Dimension 2 separate')
plt.legend()
plt.show()
