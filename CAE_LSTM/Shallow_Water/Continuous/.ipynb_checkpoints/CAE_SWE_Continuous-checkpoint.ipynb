# %% [markdown]
# # Convolutional autoencoders and LSTMs for PDE surrogates

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Set seeds
np.random.seed(10)
tf.random.set_seed(10)

# For ML construction
from tensorflow.keras.layers import Input, Dense, LSTM, Lambda, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, UpSampling2D, MaxPooling2D, Reshape
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential, Model
from tensorflow.keras.regularizers import l1
from tensorflow.keras.utils import plot_model

# For filtering 
from scipy.signal import savgol_filter #1D
from scipy.ndimage import gaussian_filter #nd

# %% [markdown]
# ### Grab data from Github

# %%
# !wget -O train.npy https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/Science_Data/train.npy?raw=true
# !wget -O validation.npy https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/Science_Data/validation.npy?raw=true
# !wget -O SWE_CAE_Weights.h5 https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/saved_models/SWE_CAE_Weights.h5?raw=true
# !wget -O SWE_LSTM_Weights.h5 https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/saved_models/SWE_LSTM_Weights.h5?raw=true
# Out:
# --2020-10-11 12:06:20--  https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/Science_Data/train.npy?raw=true
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/Science_Data/train.npy [following]
# --2020-10-11 12:06:20--  https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/Science_Data/train.npy
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/Science_Data/train.npy [following]
# --2020-10-11 12:06:20--  https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/Science_Data/train.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.76.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.76.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39321728 (38M) [application/octet-stream]
# Saving to: ‘train.npy’
#
# train.npy           100%[===================>]  37.50M  3.52MB/s    in 12s
#
# 2020-10-11 12:06:32 (3.21 MB/s) - ‘train.npy’ saved [39321728/39321728]
#
# --2020-10-11 12:06:32--  https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/Science_Data/validation.npy?raw=true
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/Science_Data/validation.npy [following]
# --2020-10-11 12:06:33--  https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/Science_Data/validation.npy
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/Science_Data/validation.npy [following]
# --2020-10-11 12:06:33--  https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/Science_Data/validation.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.76.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.76.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39321728 (38M) [application/octet-stream]
# Saving to: ‘validation.npy’
#
# validation.npy      100%[===================>]  37.50M  3.36MB/s    in 18s
#
# 2020-10-11 12:06:52 (2.04 MB/s) - ‘validation.npy’ saved [39321728/39321728]
#
# --2020-10-11 12:06:52--  https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/saved_models/SWE_CAE_Weights.h5?raw=true
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/saved_models/SWE_CAE_Weights.h5 [following]
# --2020-10-11 12:06:52--  https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/saved_models/SWE_CAE_Weights.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/saved_models/SWE_CAE_Weights.h5 [following]
# --2020-10-11 12:06:52--  https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/saved_models/SWE_CAE_Weights.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.76.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.76.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101304 (99K) [application/octet-stream]
# Saving to: ‘SWE_CAE_Weights.h5’
#
# SWE_CAE_Weights.h5  100%[===================>]  98.93K  --.-KB/s    in 0.07s
#
# 2020-10-11 12:06:53 (1.41 MB/s) - ‘SWE_CAE_Weights.h5’ saved [101304/101304]
#
# --2020-10-11 12:06:53--  https://github.com/argonne-lcf/ATPESC_MachineLearning/blob/master/AE_and_GAN/saved_models/SWE_LSTM_Weights.h5?raw=true
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/saved_models/SWE_LSTM_Weights.h5 [following]
# --2020-10-11 12:06:53--  https://github.com/argonne-lcf/ATPESC_MachineLearning/raw/master/AE_and_GAN/saved_models/SWE_LSTM_Weights.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/saved_models/SWE_LSTM_Weights.h5 [following]
# --2020-10-11 12:06:53--  https://raw.githubusercontent.com/argonne-lcf/ATPESC_MachineLearning/master/AE_and_GAN/saved_models/SWE_LSTM_Weights.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.76.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.76.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37904 (37K) [application/octet-stream]
# Saving to: ‘SWE_LSTM_Weights.h5’
#
# SWE_LSTM_Weights.h5 100%[===================>]  37.02K  --.-KB/s    in 0.02s
#
# 2020-10-11 12:06:54 (1.97 MB/s) - ‘SWE_LSTM_Weights.h5’ saved [37904/37904]

# %% [markdown]
# ### Load SWE snapshot data into the proper arrays and rescale

# %%
swe_data = np.transpose(np.load('train.npy'))
swe_data_v = np.transpose(np.load('validation.npy'))

swe_train_data = np.zeros(shape=(400,64,64,3)) # Channels last
swe_valid_data = np.zeros(shape=(400,64,64,3)) # Channels last

for i in range(np.shape(swe_data)[0]):
    temp_1 = swe_data[i,0:64*64].reshape(64,64)
    temp_2 = swe_data[i,64*64:2*64*64].reshape(64,64)
    temp_3 = swe_data[i,2*64*64:3*64*64].reshape(64,64)
    swe_train_data[i,:,:,0] = np.transpose(temp_1[:,:])
    swe_train_data[i,:,:,1] = np.transpose(temp_2[:,:])
    swe_train_data[i,:,:,2] = np.transpose(temp_3[:,:])
    
for i in range(np.shape(swe_data)[0]):
    temp_1 = swe_data_v[i,0:64*64].reshape(64,64)
    temp_2 = swe_data_v[i,64*64:2*64*64].reshape(64,64)
    temp_3 = swe_data_v[i,2*64*64:3*64*64].reshape(64,64)
    swe_valid_data[i,:,:,0] = np.transpose(temp_1[:,:])
    swe_valid_data[i,:,:,1] = np.transpose(temp_2[:,:])
    swe_valid_data[i,:,:,2] = np.transpose(temp_3[:,:])

# Scale between 0 and 1
for j in range(3):
    swe_train_data[:,:,:,j] = (swe_train_data[:,:,:,j] - np.min(swe_train_data[:,:,:,0]))/(np.max(swe_train_data[:,:,:,0])-np.min(swe_train_data[:,:,:,0]))
    swe_valid_data[:,:,:,j] = (swe_valid_data[:,:,:,j] - np.min(swe_valid_data[:,:,:,0]))/(np.max(swe_valid_data[:,:,:,0])-np.min(swe_valid_data[:,:,:,0]))

# %% [markdown]
# ### Visualize the data set

# %%
# Visualize multiple time instances
for time in range(0,200,50):
    fig, ax = plt.subplots(nrows=1,ncols=3)
    ax[0].imshow(swe_train_data[time,:,:,0])
    ax[1].imshow(swe_train_data[time,:,:,1])
    ax[2].imshow(swe_train_data[time,:,:,2])
    plt.show()

# %% [markdown]
# ### Do a shift of the training data for one-step prediction in the future

# %%
# Do some shifting to allow for LSTM pipeline
swe_evolve_data = swe_train_data[1:]
swe_train_data = swe_train_data[:-1]

# %% [markdown]
# ### ML Presets and Custom Functions

# %%
mode = 'train'
lrate = 0.001

def mean_absolute_error(y_pred,y_true):
    return K.mean(K.abs(y_true-y_pred))

def max_absolute_error(y_pred,y_true):
    return K.max(K.abs(y_true-y_pred))

# %% [markdown]
# ### Autoencoder + LSTM pipeline

# %%
## Define recursive model architecture
weights_filepath = 'Model_weights.h5'

# Encoder
encoder_inputs = Input(shape=(64,64,3),name='Field')

x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(encoder_inputs)
enc_l2 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(20,kernel_size=(3,3),activation='relu',padding='same')(enc_l2)
enc_l3 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(10,kernel_size=(3,3),activation='relu',padding='same')(enc_l3)
enc_l4 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(15,kernel_size=(3,3),activation='relu',padding='same')(enc_l4)
enc_l5 = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

x = Conv2D(1,kernel_size=(3,3),activation=None,padding='same')(enc_l5)
encoded = MaxPooling2D(pool_size=(2, 2),padding='same')(x)

# LSTM starts
x = Reshape((1,4))(encoded)
x = LSTM(20,input_shape=(1,4,),return_sequences=True)(x)
x = LSTM(20,input_shape=(1,4,),return_sequences=True)(x)
x = Dense(4,activation=None)(x)
lstm_outputs = Reshape((2,2,1))(x)
  
# Decoder starts using LSTM pipeline
x = Conv2D(1,kernel_size=(3,3),activation='relu',padding='same')(lstm_outputs)
dec_l1 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(5,kernel_size=(3,3),activation='relu',padding='same')(dec_l1)
dec_l2 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(10,kernel_size=(3,3),activation='relu',padding='same')(dec_l2)
dec_l3 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(20,kernel_size=(3,3),activation='relu',padding='same')(dec_l3)
dec_l4 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(dec_l4)
dec_l5 = UpSampling2D(size=(2, 2))(x)

ae_lstm_decoded = Conv2D(3,kernel_size=(3,3),activation=None,padding='same')(dec_l5)
    
# Decoder starts using pure autoencoder pipeline
x = Conv2D(1,kernel_size=(3,3),activation='relu',padding='same')(encoded)
dec_l1 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(5,kernel_size=(3,3),activation='relu',padding='same')(dec_l1)
dec_l2 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(10,kernel_size=(3,3),activation='relu',padding='same')(dec_l2)
dec_l3 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(20,kernel_size=(3,3),activation='relu',padding='same')(dec_l3)
dec_l4 = UpSampling2D(size=(2, 2))(x)

x = Conv2D(30,kernel_size=(3,3),activation='relu',padding='same')(dec_l4)
dec_l5 = UpSampling2D(size=(2, 2))(x)

ae_decoded = Conv2D(3,kernel_size=(3,3),activation=None,padding='same')(dec_l5)

model = Model(inputs=encoder_inputs,outputs=[ae_decoded,ae_lstm_decoded],name='CAE')
   
# design network
my_adam = optimizers.Adam(lr=lrate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint]

# fit network
model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[mean_absolute_error,max_absolute_error])    
model.summary()

num_epochs = 5000
batch_size = 4

if mode == 'train':
    train_history = model.fit(x=swe_train_data, y=[swe_train_data,swe_evolve_data], epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
# Out:
# Model: "CAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Field (InputLayer)              [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 30)   840         Field[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 30)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 20)   5420        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 20)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 10)   1810        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 10)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 15)     1365        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 15)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 1)      136         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 1)      0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 4)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 1, 20)        2000        reshape[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 1, 20)        3280        lstm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 4)         84          lstm_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 2, 1)      0           dense[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 2, 2, 1)      10          max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 2, 1)      10          reshape_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 4, 4, 1)      0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 4, 4, 1)      0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 5)      50          up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 5)      50          up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 8, 8, 5)      0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 5)      0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 10)     460         up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 10)     460         up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 16, 16, 10)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 10)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 20)   1820        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 20)   1820        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 32, 32, 20)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 20)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 30)   5430        up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 30)   5430        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 64, 64, 30)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 30)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 3)    813         up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 3)    813         up_sampling2d_4[0][0]
# ==================================================================================================
# Total params: 32,101
# Trainable params: 32,101
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0118 - conv2d_16_loss: 0.0058 - conv2d_10_loss: 0.0060 - conv2d_16_mean_absolute_error: 0.0504 - conv2d_16_max_absolute_error: 0.6057 - conv2d_10_mean_absolute_error: 0.0519 - conv2d_10_max_absolute_error: 0.6034
# Epoch 00001: loss improved from inf to 0.01171, saving model to Model_weights.h5
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0117 - conv2d_16_loss: 0.0057 - conv2d_10_loss: 0.0060 - conv2d_16_mean_absolute_error: 0.0504 - conv2d_16_max_absolute_error: 0.6015 - conv2d_10_mean_absolute_error: 0.0518 - conv2d_10_max_absolute_error: 0.5992
# Epoch 2/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0093 - conv2d_16_loss: 0.0046 - conv2d_10_loss: 0.0048 - conv2d_16_mean_absolute_error: 0.0438 - conv2d_16_max_absolute_error: 0.5790 - conv2d_10_mean_absolute_error: 0.0446 - conv2d_10_max_absolute_error: 0.5777
# Epoch 00002: loss improved from 0.01171 to 0.00929, saving model to Model_weights.h5
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0093 - conv2d_16_loss: 0.0045 - conv2d_10_loss: 0.0047 - conv2d_16_mean_absolute_error: 0.0438 - conv2d_16_max_absolute_error: 0.5753 - conv2d_10_mean_absolute_error: 0.0446 - conv2d_10_max_absolute_error: 0.5746
# Epoch 3/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0086 - conv2d_16_loss: 0.0039 - conv2d_10_loss: 0.0047 - conv2d_16_mean_absolute_error: 0.0408 - conv2d_16_max_absolute_error: 0.6005 - conv2d_10_mean_absolute_error: 0.0441 - conv2d_10_max_absolute_error: 0.6022
# Epoch 00003: loss improved from 0.00929 to 0.00861, saving model to Model_weights.h5
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0086 - conv2d_16_loss: 0.0039 - conv2d_10_loss: 0.0047 - conv2d_16_mean_absolute_error: 0.0408 - conv2d_16_max_absolute_error: 0.5967 - conv2d_10_mean_absolute_error: 0.0441 - conv2d_10_max_absolute_error: 0.5984
# Epoch 4/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0077 - conv2d_16_loss: 0.0036 - conv2d_10_loss: 0.0041 - conv2d_16_mean_absolute_error: 0.0391 - conv2d_16_max_absolute_error: 0.5968 - conv2d_10_mean_absolute_error: 0.0418 - conv2d_10_max_absolute_error: 0.6037
# Epoch 00004: loss improved from 0.00861 to 0.00775, saving model to Model_weights.h5
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0078 - conv2d_16_loss: 0.0036 - conv2d_10_loss: 0.0041 - conv2d_16_mean_absolute_error: 0.0391 - conv2d_16_max_absolute_error: 0.6016 - conv2d_10_mean_absolute_error: 0.0418 - conv2d_10_max_absolute_error: 0.6086
# Epoch 5/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0071 - conv2d_16_loss: 0.0033 - conv2d_10_loss: 0.0038 - conv2d_16_mean_absolute_error: 0.0372 - conv2d_16_max_absolute_error: 0.5730 - conv2d_10_mean_absolute_error: 0.0404 - conv2d_10_max_absolute_error: 0.5885
# Epoch 00005: loss improved from 0.00775 to 0.00709, saving model to Model_weights.h5
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0071 - conv2d_16_loss: 0.0033 - conv2d_10_loss: 0.0038 - conv2d_16_mean_absolute_error: 0.0372 - conv2d_16_max_absolute_error: 0.5741 - conv2d_10_mean_absolute_error: 0.0404 - conv2d_10_max_absolute_error: 0.5906
# Epoch 6/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0066 - conv2d_16_loss: 0.0031 - conv2d_10_loss: 0.0035 - conv2d_16_mean_absolute_error: 0.0362 - conv2d_16_max_absolute_error: 0.5620 - conv2d_10_mean_absolute_error: 0.0388 - conv2d_10_max_absolute_error: 0.5668
# Epoch 00006: loss improved from 0.00709 to 0.00658, saving model to Model_weights.h5
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0066 - conv2d_16_loss: 0.0031 - conv2d_10_loss: 0.0035 - conv2d_16_mean_absolute_error: 0.0361 - conv2d_16_max_absolute_error: 0.5587 - conv2d_10_mean_absolute_error: 0.0387 - conv2d_10_max_absolute_error: 0.5634
# Epoch 7/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0061 - conv2d_16_loss: 0.0029 - conv2d_10_loss: 0.0032 - conv2d_16_mean_absolute_error: 0.0349 - conv2d_16_max_absolute_error: 0.5792 - conv2d_10_mean_absolute_error: 0.0373 - conv2d_10_max_absolute_error: 0.5830
# Epoch 00007: loss improved from 0.00658 to 0.00615, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0062 - conv2d_16_loss: 0.0029 - conv2d_10_loss: 0.0033 - conv2d_16_mean_absolute_error: 0.0350 - conv2d_16_max_absolute_error: 0.5828 - conv2d_10_mean_absolute_error: 0.0373 - conv2d_10_max_absolute_error: 0.5866
# Epoch 8/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0058 - conv2d_16_loss: 0.0028 - conv2d_10_loss: 0.0030 - conv2d_16_mean_absolute_error: 0.0341 - conv2d_16_max_absolute_error: 0.5494 - conv2d_10_mean_absolute_error: 0.0363 - conv2d_10_max_absolute_error: 0.5488
# Epoch 00008: loss improved from 0.00615 to 0.00582, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0058 - conv2d_16_loss: 0.0028 - conv2d_10_loss: 0.0031 - conv2d_16_mean_absolute_error: 0.0342 - conv2d_16_max_absolute_error: 0.5540 - conv2d_10_mean_absolute_error: 0.0363 - conv2d_10_max_absolute_error: 0.5537
# Epoch 9/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0057 - conv2d_16_loss: 0.0027 - conv2d_10_loss: 0.0029 - conv2d_16_mean_absolute_error: 0.0339 - conv2d_16_max_absolute_error: 0.5180 - conv2d_10_mean_absolute_error: 0.0357 - conv2d_10_max_absolute_error: 0.5112
# Epoch 00009: loss improved from 0.00582 to 0.00566, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0057 - conv2d_16_loss: 0.0027 - conv2d_10_loss: 0.0029 - conv2d_16_mean_absolute_error: 0.0339 - conv2d_16_max_absolute_error: 0.5155 - conv2d_10_mean_absolute_error: 0.0357 - conv2d_10_max_absolute_error: 0.5089
# Epoch 10/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0055 - conv2d_16_loss: 0.0026 - conv2d_10_loss: 0.0029 - conv2d_16_mean_absolute_error: 0.0333 - conv2d_16_max_absolute_error: 0.5363 - conv2d_10_mean_absolute_error: 0.0353 - conv2d_10_max_absolute_error: 0.5326
# Epoch 00010: loss improved from 0.00566 to 0.00549, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0055 - conv2d_16_loss: 0.0026 - conv2d_10_loss: 0.0029 - conv2d_16_mean_absolute_error: 0.0333 - conv2d_16_max_absolute_error: 0.5390 - conv2d_10_mean_absolute_error: 0.0352 - conv2d_10_max_absolute_error: 0.5354
# Epoch 11/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0053 - conv2d_16_loss: 0.0026 - conv2d_10_loss: 0.0027 - conv2d_16_mean_absolute_error: 0.0328 - conv2d_16_max_absolute_error: 0.5214 - conv2d_10_mean_absolute_error: 0.0345 - conv2d_10_max_absolute_error: 0.5125
# Epoch 00011: loss improved from 0.00549 to 0.00530, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0053 - conv2d_16_loss: 0.0026 - conv2d_10_loss: 0.0027 - conv2d_16_mean_absolute_error: 0.0328 - conv2d_16_max_absolute_error: 0.5199 - conv2d_10_mean_absolute_error: 0.0345 - conv2d_10_max_absolute_error: 0.5111
# Epoch 12/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0050 - conv2d_16_loss: 0.0024 - conv2d_10_loss: 0.0026 - conv2d_16_mean_absolute_error: 0.0316 - conv2d_16_max_absolute_error: 0.5351 - conv2d_10_mean_absolute_error: 0.0338 - conv2d_10_max_absolute_error: 0.5279
# Epoch 00012: loss improved from 0.00530 to 0.00503, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0050 - conv2d_16_loss: 0.0024 - conv2d_10_loss: 0.0026 - conv2d_16_mean_absolute_error: 0.0315 - conv2d_16_max_absolute_error: 0.5329 - conv2d_10_mean_absolute_error: 0.0338 - conv2d_10_max_absolute_error: 0.5255
# Epoch 13/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0049 - conv2d_16_loss: 0.0023 - conv2d_10_loss: 0.0025 - conv2d_16_mean_absolute_error: 0.0312 - conv2d_16_max_absolute_error: 0.5108 - conv2d_10_mean_absolute_error: 0.0332 - conv2d_10_max_absolute_error: 0.5059
# Epoch 00013: loss improved from 0.00503 to 0.00488, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0049 - conv2d_16_loss: 0.0023 - conv2d_10_loss: 0.0025 - conv2d_16_mean_absolute_error: 0.0313 - conv2d_16_max_absolute_error: 0.5122 - conv2d_10_mean_absolute_error: 0.0332 - conv2d_10_max_absolute_error: 0.5072
# Epoch 14/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0047 - conv2d_16_loss: 0.0022 - conv2d_10_loss: 0.0025 - conv2d_16_mean_absolute_error: 0.0307 - conv2d_16_max_absolute_error: 0.4906 - conv2d_10_mean_absolute_error: 0.0327 - conv2d_10_max_absolute_error: 0.4826
# Epoch 00014: loss improved from 0.00488 to 0.00476, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0048 - conv2d_16_loss: 0.0023 - conv2d_10_loss: 0.0025 - conv2d_16_mean_absolute_error: 0.0308 - conv2d_16_max_absolute_error: 0.4962 - conv2d_10_mean_absolute_error: 0.0328 - conv2d_10_max_absolute_error: 0.4880
# Epoch 15/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0046 - conv2d_16_loss: 0.0022 - conv2d_10_loss: 0.0024 - conv2d_16_mean_absolute_error: 0.0304 - conv2d_16_max_absolute_error: 0.5141 - conv2d_10_mean_absolute_error: 0.0324 - conv2d_10_max_absolute_error: 0.5117
# Epoch 00015: loss improved from 0.00476 to 0.00463, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0046 - conv2d_16_loss: 0.0022 - conv2d_10_loss: 0.0024 - conv2d_16_mean_absolute_error: 0.0304 - conv2d_16_max_absolute_error: 0.5127 - conv2d_10_mean_absolute_error: 0.0324 - conv2d_10_max_absolute_error: 0.5094
# Epoch 16/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0044 - conv2d_16_loss: 0.0021 - conv2d_10_loss: 0.0023 - conv2d_16_mean_absolute_error: 0.0295 - conv2d_16_max_absolute_error: 0.4942 - conv2d_10_mean_absolute_error: 0.0316 - conv2d_10_max_absolute_error: 0.4893
# Epoch 00016: loss improved from 0.00463 to 0.00444, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0044 - conv2d_16_loss: 0.0021 - conv2d_10_loss: 0.0023 - conv2d_16_mean_absolute_error: 0.0295 - conv2d_16_max_absolute_error: 0.4960 - conv2d_10_mean_absolute_error: 0.0317 - conv2d_10_max_absolute_error: 0.4916
# Epoch 17/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0044 - conv2d_16_loss: 0.0021 - conv2d_10_loss: 0.0023 - conv2d_16_mean_absolute_error: 0.0294 - conv2d_16_max_absolute_error: 0.5066 - conv2d_10_mean_absolute_error: 0.0316 - conv2d_10_max_absolute_error: 0.5067
# Epoch 00017: loss improved from 0.00444 to 0.00440, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0044 - conv2d_16_loss: 0.0021 - conv2d_10_loss: 0.0023 - conv2d_16_mean_absolute_error: 0.0294 - conv2d_16_max_absolute_error: 0.5112 - conv2d_10_mean_absolute_error: 0.0316 - conv2d_10_max_absolute_error: 0.5112
# Epoch 18/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0043 - conv2d_16_loss: 0.0020 - conv2d_10_loss: 0.0022 - conv2d_16_mean_absolute_error: 0.0290 - conv2d_16_max_absolute_error: 0.5201 - conv2d_10_mean_absolute_error: 0.0310 - conv2d_10_max_absolute_error: 0.5184
# Epoch 00018: loss improved from 0.00440 to 0.00424, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0042 - conv2d_16_loss: 0.0020 - conv2d_10_loss: 0.0022 - conv2d_16_mean_absolute_error: 0.0289 - conv2d_16_max_absolute_error: 0.5185 - conv2d_10_mean_absolute_error: 0.0309 - conv2d_10_max_absolute_error: 0.5162
# Epoch 19/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0043 - conv2d_16_loss: 0.0020 - conv2d_10_loss: 0.0023 - conv2d_16_mean_absolute_error: 0.0290 - conv2d_16_max_absolute_error: 0.4988 - conv2d_10_mean_absolute_error: 0.0312 - conv2d_10_max_absolute_error: 0.5002
# Epoch 00019: loss did not improve from 0.00424
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0043 - conv2d_16_loss: 0.0020 - conv2d_10_loss: 0.0023 - conv2d_16_mean_absolute_error: 0.0290 - conv2d_16_max_absolute_error: 0.5008 - conv2d_10_mean_absolute_error: 0.0312 - conv2d_10_max_absolute_error: 0.5020
# Epoch 20/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0041 - conv2d_16_loss: 0.0019 - conv2d_10_loss: 0.0022 - conv2d_16_mean_absolute_error: 0.0284 - conv2d_16_max_absolute_error: 0.5064 - conv2d_10_mean_absolute_error: 0.0305 - conv2d_10_max_absolute_error: 0.5076
# Epoch 00020: loss improved from 0.00424 to 0.00411, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0041 - conv2d_16_loss: 0.0019 - conv2d_10_loss: 0.0022 - conv2d_16_mean_absolute_error: 0.0283 - conv2d_16_max_absolute_error: 0.5031 - conv2d_10_mean_absolute_error: 0.0305 - conv2d_10_max_absolute_error: 0.5047
# Epoch 21/5000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0040 - conv2d_16_loss: 0.0019 - conv2d_10_loss: 0.0021 - conv2d_16_mean_absolute_error: 0.0282 - conv2d_16_max_absolute_error: 0.4930 - conv2d_10_mean_absolute_error: 0.0301 - conv2d_10_max_absolute_error: 0.4946
# Epoch 00021: loss improved from 0.00411 to 0.00402, saving model to Model_weights.h5
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0040 - conv2d_16_loss: 0.0019 - conv2d_10_loss: 0.0021 - conv2d_16_mean_absolute_error: 0.0281 - conv2d_16_max_absolute_error: 0.4898 - conv2d_10_mean_absolute_error: 0.0300 - conv2d_10_max_absolute_error: 0.4914
# Epoch 22/5000
#  73/100 [====================>.........] - ETA: 1s - loss: 0.0037 - conv2d_16_loss: 0.0018 - conv2d_10_loss: 0.0020 - conv2d_16_mean_absolute_error: 0.0274 - conv2d_16_max_absolute_error: 0.4516 - conv2d_10_mean_absolute_error: 0.0292 - conv2d_10_max_absolute_error: 0.4517
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-0cef6fcb833a> in <module>
#      80
#      81 if mode == 'train':
# ---> 82     train_history = model.fit(x=swe_train_data, y=[swe_train_data,swe_evolve_data], epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list)
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Check accuracy of autoencoder

# %%
time = 100

model.load_weights(weights_filepath)
recoded_1 = model.predict(swe_train_data[time:time+1,:,:,:])[0]

fig, ax = plt.subplots(nrows=2,ncols=3,figsize=(14,12))

cs1 = ax[0,0].imshow(swe_train_data[time,:,:,0],label='input')
ax[1,0].imshow(gaussian_filter(recoded_1[0,:,:,0],sigma=2),label='decoded')

cs2 = ax[0,1].imshow(swe_train_data[time,:,:,1],label='input')
ax[1,1].imshow(gaussian_filter(recoded_1[0,:,:,1],sigma=2),label='decoded')

cs3 = ax[0,2].imshow(swe_train_data[time,:,:,2],label='input')
ax[1,2].imshow(gaussian_filter(recoded_1[0,:,:,2],sigma=2),label='decoded')

for i in range(2):
    for j in range(3):
        ax[i,j].set_xlabel('x')
        ax[i,j].set_ylabel('y')
        
fig.colorbar(cs1,ax=ax[0,0],fraction=0.046, pad=0.04)
fig.colorbar(cs1,ax=ax[1,0],fraction=0.046, pad=0.04)

fig.colorbar(cs2,ax=ax[0,1],fraction=0.046, pad=0.04)
fig.colorbar(cs2,ax=ax[1,1],fraction=0.046, pad=0.04)

fig.colorbar(cs3,ax=ax[0,2],fraction=0.046, pad=0.04)
fig.colorbar(cs3,ax=ax[1,2],fraction=0.046, pad=0.04)


ax[0,0].set_title(r'True $q_1$')
ax[0,1].set_title(r'True $q_2$')
ax[0,2].set_title(r'True $q_3$')

ax[1,0].set_title(r'Reconstructed $q_1$')
ax[1,1].set_title(r'Reconstructed $q_2$')
ax[1,2].set_title(r'Reconstructed $q_3$')

plt.subplots_adjust(wspace=0.5,hspace=-0.3)
plt.show()

# %%
time = 100

model.load_weights(weights_filepath)
from scipy.ndimage import gaussian_filter
recoded_1 = model.predict(swe_train_data[time:time+1,:,:,:])[1]

fig, ax = plt.subplots(nrows=2,ncols=3,figsize=(14,12))

cs1 = ax[0,0].imshow(swe_evolve_data[time,:,:,0],label='input')
ax[1,0].imshow(gaussian_filter(recoded_1[0,:,:,0],sigma=2),label='decoded')

cs2 = ax[0,1].imshow(swe_evolve_data[time,:,:,1],label='input')
ax[1,1].imshow(gaussian_filter(recoded_1[0,:,:,1],sigma=2),label='decoded')

cs3 = ax[0,2].imshow(swe_evolve_data[time,:,:,2],label='input')
ax[1,2].imshow(gaussian_filter(recoded_1[0,:,:,2],sigma=2),label='decoded')

for i in range(2):
    for j in range(3):
        ax[i,j].set_xlabel('x')
        ax[i,j].set_ylabel('y')
        
fig.colorbar(cs1,ax=ax[0,0],fraction=0.046, pad=0.04)
fig.colorbar(cs1,ax=ax[1,0],fraction=0.046, pad=0.04)

fig.colorbar(cs2,ax=ax[0,1],fraction=0.046, pad=0.04)
fig.colorbar(cs2,ax=ax[1,1],fraction=0.046, pad=0.04)

fig.colorbar(cs3,ax=ax[0,2],fraction=0.046, pad=0.04)
fig.colorbar(cs3,ax=ax[1,2],fraction=0.046, pad=0.04)


ax[0,0].set_title(r'True $q_1$')
ax[0,1].set_title(r'True $q_2$')
ax[0,2].set_title(r'True $q_3$')

ax[1,0].set_title(r'Reconstructed $q_1$')
ax[1,1].set_title(r'Reconstructed $q_2$')
ax[1,2].set_title(r'Reconstructed $q_3$')

plt.subplots_adjust(wspace=0.5,hspace=-0.3)
plt.show()

# %% [markdown]
# ### Check latent representation of the CAE

# %%
time = 100
plt.imshow(layer_output[time,:,:,0])
get_latent_representation = K.function([model.layers[0].input],
                                  [model.layers[10].output]) # Layer number 10 is the MaxPooling2D before entry to LSTM
layer_output = get_latent_representation([swe_train_data])[0]
plt.imshow(layer_output[time,:,:,0])

# %% [markdown]
# ### Check its variation in time

# %%
plt.figure()
plt.plot(layer_output[:,0,0,0],label='Latent 0')
plt.plot(layer_output[:,0,1,0],label='Latent 1')
plt.plot(layer_output[:,1,0,0],label='Latent 2')
plt.plot(layer_output[:,1,1,0],label='Latent 3')
plt.legend()
plt.show()
