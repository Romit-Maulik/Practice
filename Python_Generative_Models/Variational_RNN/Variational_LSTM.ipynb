# %%
import numpy as np
np.random.seed(10)
import tensorflow as tf
tf.random.set_seed(10)
import matplotlib.pyplot as plt

# preprocessing
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
class variational_lstm(tf.keras.Model):
    def __init__(self,data,num_latent):
        super(variational_lstm,self).__init__()
        
        # Set up the data for the LSTM
        self.data_tsteps = np.shape(data)[0]
        self.state_len = np.shape(data)[1]

#         self.preproc_pipeline = Pipeline([('stdscaler', StandardScaler()),('minmax', MinMaxScaler(feature_range=(-1, 1)))])
        self.preproc_pipeline = Pipeline([('minmax', MinMaxScaler())])
        self.data = self.preproc_pipeline.fit_transform(data)
        
        # Need to make minibatches
        self.seq_num = 8
        self.total_size = np.shape(data)[0]

        input_seq = np.zeros(shape=(self.total_size,self.seq_num,self.state_len))  #[samples,n_inputs,state_len]
        output_seq = np.zeros(shape=(self.total_size,self.seq_num,self.state_len)) #[samples,n_outputs,state_len]

        snum = 0
        for t in range(0,self.total_size):
            try:
                input_seq[snum] = self.data[None,t:t+self.seq_num,:]
                output_seq[snum] = self.data[None,t+self.seq_num:t+2*self.seq_num,:]        
                snum = snum + 1
            except:
                print('Max data length reached: Truncating collection')
                input_seq = input_seq[:snum]
                output_seq = output_seq[:snum]
                break

        # Shuffle dataset
        idx = np.arange(snum)
        np.random.shuffle(idx)
        input_seq = input_seq[idx]
        output_seq = output_seq[idx]

        # Split into train and valid
        self.ntrain = int(0.8*snum)
        self.nvalid = snum - self.ntrain

        self.input_seq_train = input_seq[:self.ntrain]
        self.output_seq_train = output_seq[:self.ntrain]

        self.input_seq_valid = input_seq[self.ntrain:]
        self.output_seq_valid = output_seq[self.ntrain:]
        
        # Constants
        self.num_latent = num_latent
        
        # Initializer
        xavier = tf.keras.initializers.GlorotUniform()
        
        # Define inference architecture
        # Encoder
        self.l1=tf.keras.layers.Bidirectional(
            tf.keras.layers.LSTM(20,return_sequences=True,input_shape=(self.seq_num,self.state_len))
        )
        # Latent space
        self.latent_mu = tf.keras.layers.Dense(self.num_latent)
        self.latent_logvar = tf.keras.layers.Dense(self.num_latent)        
        
#         # Decoder
#         self.l2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(20,return_sequences=True))
        self.out = tf.keras.layers.Dense(self.state_len,activation='linear')
        
        # optimizer
        self.train_op = tf.keras.optimizers.Adam(learning_rate=0.001)
        self.mse = tf.keras.losses.MeanSquaredError()
        
    def call(self,X):
        # Call inference
        h1 = self.l1(X)
               
        # Variational assumption quantities
        self.mu = self.latent_mu(h1)
        self.logvar = tf.nn.softmax(self.latent_logvar(h1))
        
        # Shapes
        batch_size = tf.shape(self.mu)[0]
        nl = self.num_latent
        
        # Batch wise latent space operations
        eps = tf.random.normal(shape=(batch_size,self.seq_num,nl),mean=0.0,stddev=1.0)
        self.Z = self.mu + tf.math.exp(0.5*self.logvar)*eps
        
        # Decoder
        out = self.out(self.Z)
        
        return out
    
    def get_loss(self,X,Y):
        Ypred = self.call(X) # MSE
        
        kl_loss = 1 + self.logvar - tf.math.square(self.mu) - tf.math.exp(self.logvar)
        kl_loss = -0.5*tf.reduce_sum(kl_loss) # KL Divergence
        
        return self.mse(Y,Ypred) + kl_loss

    def get_grad(self,X,Y):
        with tf.GradientTape() as tape:
            tape.watch(self.trainable_variables)
            L = self.get_loss(X,Y)
            g = tape.gradient(L, self.trainable_variables)
        return g
    
    # perform gradient descent - regular
    def network_learn(self,X,Y):
        g = self.get_grad(X,Y)
        self.train_op.apply_gradients(zip(g, self.trainable_variables))
           
    # Train the model
    def train_model(self):
        plot_iter = 0
        stop_iter = 0
        patience = 10
        best_valid_loss = 999999.0 # Some large number 

        self.num_batches = 20
        self.train_batch_size = int(self.ntrain/self.num_batches)
        self.valid_batch_size = int((self.nvalid)/self.num_batches)
        
        for i in range(100):
            # Training loss
            print('Training iteration:',i)
            
            for batch in range(self.num_batches):
                input_batch = self.input_seq_train[batch*self.train_batch_size:(batch+1)*self.train_batch_size]
                output_batch = self.output_seq_train[batch*self.train_batch_size:(batch+1)*self.train_batch_size]
                self.network_learn(input_batch,output_batch)

            # Validation loss
            valid_loss = 0.0
            valid_r2 = 0.0

            for batch in range(self.num_batches):
                input_batch = self.input_seq_valid[batch*self.valid_batch_size:(batch+1)*self.valid_batch_size]
                output_batch = self.output_seq_valid[batch*self.valid_batch_size:(batch+1)*self.valid_batch_size]

                valid_loss = valid_loss + self.get_loss(input_batch,output_batch).numpy()
                predictions = self.call(self.input_seq_valid).numpy()
                valid_r2 = valid_r2 + \
                            r2_score(
                                predictions.reshape(self.valid_batch_size,-1),
                                self.output_seq_valid.reshape(self.valid_batch_size,-1)
                            )

            valid_r2 = valid_r2/(batch+1)


            # Check early stopping criteria
            if valid_loss < best_valid_loss:
                
                print('Improved validation loss from:',best_valid_loss,' to:', valid_loss)
                print('Validation R2:',valid_r2)
                
                best_valid_loss = valid_loss
                self.save_weights('./checkpoints/my_checkpoint')
                
                stop_iter = 0
            else:
                print('Validation loss (no improvement):',valid_loss)
                print('Validation R2:',valid_r2)
                stop_iter = stop_iter + 1

            if stop_iter == patience:
                break

    # Load weights
    def restore_model(self):
        self.load_weights('./checkpoints/my_checkpoint') # Load pretrained model

    # Do some testing
    def model_inference(self,test_data):
        # Restore from checkpoint
        self.restore_model()

        # Scale testing data
        test_data = self.preproc_pipeline.transform(test_data)

        # Test sizes
        test_total_size = np.shape(test_data)[0]

        # Input placeholder setup
        rec_input_seq = test_data[:self.seq_num,:].reshape(1,self.seq_num,self.state_len)
        
        # True outputs
        rec_output_seq = np.zeros(shape=(test_total_size,self.seq_num,self.state_len)) #[samples,n_outputs,state_len]
        snum = 0
        for t in range(0,test_total_size,self.seq_num):
            try:
                rec_output_seq[snum] = test_data[None,t+self.seq_num:t+2*self.seq_num,:]        
                snum = snum + 1
            except:
                print('Max data length reached: Truncating collection')
                rec_output_seq = rec_output_seq[:snum]
                break

        # One step predict
        rec_pred = np.copy(rec_output_seq)
        for t in range(0,snum):
            rec_pred[t] = self.call(rec_input_seq).numpy()[0]
            rec_input_seq[0] = rec_output_seq[t]
            
        # Reshape for rescaling
        rec_pred = rec_pred.reshape(snum*self.seq_num,-1)
        rec_output_seq = rec_output_seq.reshape(snum*self.seq_num,-1)
        
        # Rescale
        rec_pred = self.preproc_pipeline.inverse_transform(rec_pred)
        rec_output_seq = self.preproc_pipeline.inverse_transform(rec_output_seq)

        # plot
        rec_pred = rec_pred.reshape(-1,self.state_len)
        rec_output_seq = rec_output_seq.reshape(-1,self.state_len)
        for i in range(self.state_len):
            plt.figure()
            plt.title('Mode '+str(i))
            plt.plot(rec_pred[:,i],label='Predicted')
            plt.plot(rec_output_seq[:,i],label='True')
            plt.legend()
            plt.show()

        return rec_output_seq, rec_pred

# %%
# Loading data
data = np.load('SST_Train.npy').T
# Preprocessing
state_scaler = MinMaxScaler()
scaled_data = state_scaler.fit_transform(data)

# %%
# Initialize model
num_latent = 10
var_model = variational_lstm(scaled_data,num_latent)
# Training model
var_model.train_model() # Train and exit
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0102 12:55:37.884096 139749880981312 base_layer.py:2081] Layer bidirectional is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# Max data length reached: Truncating collection
# Training iteration: 0
# Improved validation loss from: 999999.0  to: 61.42254042625427
# Validation R2: -2.018709590438246
# Training iteration: 1
# Improved validation loss from: 61.42254042625427  to: 54.12973403930664
# Validation R2: -2.340638713657553
# Training iteration: 2
# Improved validation loss from: 54.12973403930664  to: 50.156835079193115
# Validation R2: -1.996052892397778
# Training iteration: 3
# Improved validation loss from: 50.156835079193115  to: 45.959410667419434
# Validation R2: -2.014277392952036
# Training iteration: 4
# Improved validation loss from: 45.959410667419434  to: 42.53434872627258
# Validation R2: -2.3799195284372106
# Training iteration: 5
# Improved validation loss from: 42.53434872627258  to: 41.06671869754791
# Validation R2: -1.956687984203248
# Training iteration: 6
# Improved validation loss from: 41.06671869754791  to: 38.116634130477905
# Validation R2: -1.9589671609118426
# Training iteration: 7
# Improved validation loss from: 38.116634130477905  to: 36.176334500312805
# Validation R2: -2.457280398944703
# Training iteration: 8
# Improved validation loss from: 36.176334500312805  to: 35.28875684738159
# Validation R2: -2.1443232658445353
# Training iteration: 9
# Improved validation loss from: 35.28875684738159  to: 33.1734277009964
# Validation R2: -2.837991580009543
# Training iteration: 10
# Improved validation loss from: 33.1734277009964  to: 31.34606957435608
# Validation R2: -2.60635147294048
# Training iteration: 11
# Improved validation loss from: 31.34606957435608  to: 29.341859698295593
# Validation R2: -2.612393452028259
# Training iteration: 12
# Improved validation loss from: 29.341859698295593  to: 28.98239505290985
# Validation R2: -2.598970879116444
# Training iteration: 13
# Improved validation loss from: 28.98239505290985  to: 27.039499759674072
# Validation R2: -2.7735610893494664
# Training iteration: 14
# Improved validation loss from: 27.039499759674072  to: 26.38600206375122
# Validation R2: -3.0211164359270186
# Training iteration: 15
# Improved validation loss from: 26.38600206375122  to: 25.888193130493164
# Validation R2: -3.021587390595139
# Training iteration: 16
# Improved validation loss from: 25.888193130493164  to: 24.77270483970642
# Validation R2: -3.5081844229969263
# Training iteration: 17
# Improved validation loss from: 24.77270483970642  to: 24.265395641326904
# Validation R2: -4.1083145237793905
# Training iteration: 18
# Improved validation loss from: 24.265395641326904  to: 23.93988823890686
# Validation R2: -3.7374644279752145
# Training iteration: 19
# Improved validation loss from: 23.93988823890686  to: 22.946346044540405
# Validation R2: -4.570463085739036
# Training iteration: 20
# Improved validation loss from: 22.946346044540405  to: 22.38899314403534
# Validation R2: -5.013854919227189
# Training iteration: 21
# Improved validation loss from: 22.38899314403534  to: 22.088293075561523
# Validation R2: -5.085196986777431
# Training iteration: 22
# Improved validation loss from: 22.088293075561523  to: 21.263625502586365
# Validation R2: -5.702139271831072
# Training iteration: 23
# Validation loss (no improvement): 21.268433451652527
# Validation R2: -6.2948092103455195
# Training iteration: 24
# Improved validation loss from: 21.263625502586365  to: 20.849093854427338
# Validation R2: -7.637547801264569
# Training iteration: 25
# Improved validation loss from: 20.849093854427338  to: 20.41471266746521
# Validation R2: -7.573720925615243
# Training iteration: 26
# Improved validation loss from: 20.41471266746521  to: 20.24113827943802
# Validation R2: -8.910204710886841
# Training iteration: 27
# Improved validation loss from: 20.24113827943802  to: 19.95473164319992
# Validation R2: -9.50133367166904
# Training iteration: 28
# Improved validation loss from: 19.95473164319992  to: 19.65143370628357
# Validation R2: -12.288018881411475
# Training iteration: 29
# Improved validation loss from: 19.65143370628357  to: 19.570065557956696
# Validation R2: -12.595710473760052
# Training iteration: 30
# Improved validation loss from: 19.570065557956696  to: 19.295290410518646
# Validation R2: -15.478425601050366
# Training iteration: 31
# Improved validation loss from: 19.295290410518646  to: 19.204252541065216
# Validation R2: -19.11735322954325
# Training iteration: 32
# Improved validation loss from: 19.204252541065216  to: 19.058668434619904
# Validation R2: -21.866298519398338
# Training iteration: 33
# Improved validation loss from: 19.058668434619904  to: 18.871880292892456
# Validation R2: -27.461957478217037
# Training iteration: 34
# Improved validation loss from: 18.871880292892456  to: 18.82458645105362
# Validation R2: -32.38457377536876
# Training iteration: 35
# Improved validation loss from: 18.82458645105362  to: 18.690740168094635
# Validation R2: -36.86043871408242
# Training iteration: 36
# Improved validation loss from: 18.690740168094635  to: 18.64969712495804
# Validation R2: -41.83018355195893
# Training iteration: 37
# Improved validation loss from: 18.64969712495804  to: 18.53294050693512
# Validation R2: -60.55839736140898
# Training iteration: 38
# Improved validation loss from: 18.53294050693512  to: 18.44758450984955
# Validation R2: -67.93725965405056
# Training iteration: 39
# Improved validation loss from: 18.44758450984955  to: 18.418381929397583
# Validation R2: -98.61298971518497
# Training iteration: 40
# Improved validation loss from: 18.418381929397583  to: 18.373750388622284
# Validation R2: -100.22739787445286
# Training iteration: 41
# Improved validation loss from: 18.373750388622284  to: 18.339227974414825
# Validation R2: -146.38667520357245
# Training iteration: 42
# Improved validation loss from: 18.339227974414825  to: 18.252882599830627
# Validation R2: -184.25579625821902
# Training iteration: 43
# Validation loss (no improvement): 18.27518939971924
# Validation R2: -236.34639143391718
# Training iteration: 44
# Improved validation loss from: 18.252882599830627  to: 18.21868985891342
# Validation R2: -262.26528101907155
# Training iteration: 45
# Improved validation loss from: 18.21868985891342  to: 18.20032113790512
# Validation R2: -348.772492995734
# Training iteration: 46
# Improved validation loss from: 18.20032113790512  to: 18.166620671749115
# Validation R2: -510.00390251010697
# Training iteration: 47
# Improved validation loss from: 18.166620671749115  to: 18.154864370822906
# Validation R2: -549.8731805399007
# Training iteration: 48
# Improved validation loss from: 18.154864370822906  to: 18.132723331451416
# Validation R2: -791.1707220739052
# Training iteration: 49
# Validation loss (no improvement): 18.147773504257202
# Validation R2: -1136.7991694461332
# Training iteration: 50
# Improved validation loss from: 18.132723331451416  to: 18.126326858997345
# Validation R2: -812.667070926256
# Training iteration: 51
# Improved validation loss from: 18.126326858997345  to: 18.112594425678253
# Validation R2: -637.8214050742024
# Training iteration: 52
# Improved validation loss from: 18.112594425678253  to: 18.09823912382126
# Validation R2: -510.91125635760307
# Training iteration: 53
# Improved validation loss from: 18.09823912382126  to: 18.083551704883575
# Validation R2: -757.3064830462374
# Training iteration: 54
# Improved validation loss from: 18.083551704883575  to: 18.077339112758636
# Validation R2: -763.552970423007
# Training iteration: 55
# Validation loss (no improvement): 18.081370532512665
# Validation R2: -1332.3351627366765
# Training iteration: 56
# Validation loss (no improvement): 18.08186137676239
# Validation R2: -2459.7095064067207
# Training iteration: 57
# Validation loss (no improvement): 18.07810288667679
# Validation R2: -1851.9326088769144
# Training iteration: 58
# Improved validation loss from: 18.077339112758636  to: 18.071968853473663
# Validation R2: -2003.8322324129706
# Training iteration: 59
# Improved validation loss from: 18.071968853473663  to: 18.06475043296814
# Validation R2: -1982.7140475813314
# Training iteration: 60
# Improved validation loss from: 18.06475043296814  to: 18.05787068605423
# Validation R2: -1782.1440035807664
# Training iteration: 61
# Improved validation loss from: 18.05787068605423  to: 18.054940223693848
# Validation R2: -2266.354965077885
# Training iteration: 62
# Validation loss (no improvement): 18.05612713098526
# Validation R2: -2984.717025388999
# Training iteration: 63
# Validation loss (no improvement): 18.05597758293152
# Validation R2: -3122.879945123601
# Training iteration: 64
# Improved validation loss from: 18.054940223693848  to: 18.05062645673752
# Validation R2: -2774.8782517929876
# Training iteration: 65
# Validation loss (no improvement): 18.055264830589294
# Validation R2: -2770.8617333246934
# Training iteration: 66
# Improved validation loss from: 18.05062645673752  to: 18.049008667469025
# Validation R2: -2465.4364511734884
# Training iteration: 67
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a04de95ea494> in <module>
#       3 var_model = variational_lstm(scaled_data,num_latent)
#       4 # Training model
# ----> 5 var_model.train_model() # Train and exit
#
# <ipython-input-2-36d95237645f> in train_model(self)
#     139
#     140                 valid_loss = valid_loss + self.get_loss(input_batch,output_batch).numpy()
# --> 141                 predictions = self.call(self.input_seq_valid).numpy()
#     142                 valid_r2 = valid_r2 + \
#     143                             r2_score(
#
# <ipython-input-2-36d95237645f> in call(self, X)
#      71     def call(self,X):
#      72         # Call inference
# ---> 73         h1 = self.l1(X)
#      74
#      75         # Variational assumption quantities
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/layers/wrappers.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     529
#     530     if initial_state is None and constants is None:
# --> 531       return super(Bidirectional, self).__call__(inputs, **kwargs)
#     532
#     533     # Applies the same workaround as in `RNN.__call__`
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/layers/wrappers.py in call(self, inputs, training, mask, initial_state, constants)
#     643
#     644       y = self.forward_layer(forward_inputs,
# --> 645                              initial_state=forward_state, **kwargs)
#     646       y_rev = self.backward_layer(backward_inputs,
#     647                                   initial_state=backward_state, **kwargs)
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     652
#     653     if initial_state is None and constants is None:
# --> 654       return super(RNN, self).__call__(inputs, **kwargs)
#     655
#     656     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1182         else:
#    1183           last_output, outputs, new_h, new_c, runtime = standard_lstm(
# -> 1184               **normal_lstm_kwargs)
#    1185       else:
#    1186         (last_output, outputs, new_h, new_c,
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent_v2.py in standard_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, activation, recurrent_activation, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1318       input_length=(sequence_lengths
#    1319                     if sequence_lengths is not None else timesteps),
# -> 1320       zero_output_for_mask=zero_output_for_mask)
#    1321   return (last_output, outputs, new_states[0], new_states[1],
#    1322           _runtime(_RUNTIME_CPU))
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4090     # the value is discarded.
#    4091     output_time_zero, _ = step_function(
# -> 4092         input_time_zero, tuple(initial_states) + tuple(constants))
#    4093     output_ta = tuple(
#    4094         tensor_array_ops.TensorArray(
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent_v2.py in step(cell_inputs, cell_states)
#    1301
#    1302     i = recurrent_activation(z0)
# -> 1303     f = recurrent_activation(z1)
#    1304     c = f * c_tm1 + i * activation(z2)
#    1305     o = recurrent_activation(z3)
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/keras/activations.py in sigmoid(x)
#     285       Tensor will be of same shape and dtype of input `x`.
#     286   """
# --> 287   return nn.sigmoid(x)
#     288
#     289
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in sigmoid(x, name)
#    3366   with ops.name_scope(name, "Sigmoid", [x]) as name:
#    3367     x = ops.convert_to_tensor(x, name="x")
# -> 3368     return gen_math_ops.sigmoid(x, name=name)
#    3369
#    3370
#
# ~/anaconda3/envs/tf2_env/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in sigmoid(x, name)
#    8687       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    8688         _ctx._context_handle, tld.device_name, "Sigmoid", name,
# -> 8689         tld.op_callbacks, x)
#    8690       return _result
#    8691     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
test_data = np.load('SST_Test.npy').T
scaled_test_data = state_scaler.transform(test_data)
true, predicted = var_model.model_inference(scaled_test_data) # Do some inference
# Out:
# Max data length reached: Truncating collection
