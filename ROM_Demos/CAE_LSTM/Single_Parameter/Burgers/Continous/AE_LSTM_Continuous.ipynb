# %%
import numpy as np
import tensorflow as tf

# Set seeds
np.random.seed(10)
tf.random.set_seed(10)

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda, Dropout, Reshape, Flatten
from tensorflow.keras.layers import Conv1D, TimeDistributed, UpSampling1D, MaxPooling1D
from tensorflow.keras import optimizers, models, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model, Sequential, Model

# %% [markdown]
# ### Some global variables

# %%
Rnum = 1000
x = np.linspace(0.0,1.0,num=128)
dx = 1.0/np.shape(x)[0]
tsteps = np.linspace(0.0,2.0,num=400)
dt = 2.0/np.shape(tsteps)[0]
mode = 'train'

# %% [markdown]
# ### Functions for full-order snapshots of Burgers Equation

# %%
def exact_solution(Rnum,t):
    t0 = np.exp(Rnum/8.0)

    return (x/(t+1))/(1.0+np.sqrt((t+1)/t0)*np.exp(Rnum*(x*x)/(4.0*t+4)))

def collect_snapshots(Rnum):
    snapshot_matrix = np.zeros(shape=(np.shape(x)[0],np.shape(tsteps)[0]))

    trange = np.arange(np.shape(tsteps)[0])
    for t in trange:
        snapshot_matrix[:,t] = exact_solution(Rnum,tsteps[t])[:]

    return np.transpose(snapshot_matrix)

# %% [markdown]
# ### Collect some snapshot data for CNN-LSTM embedding

# %%
snapshots_train = collect_snapshots(Rnum)
snapshots_train = np.expand_dims(snapshots_train,-1)

# %% [markdown]
# ### Do some shifting for evolution predictions

# %%
snapshots_evolve = snapshots_train[1:]
snapshots_train = snapshots_train[0:-1]

# %% [markdown]
# ### ML related presets

# %%
weights_filepath = 'best_weights.h5'
lrate = 0.001

def coeff_determination(y_pred, y_true): #Order of function inputs is important here        
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ### Autoencoder and LSTM

# %%
# Encoder
encoder_inputs = Input(shape=(128,1),name='Field')

x = Conv1D(25,kernel_size=3,activation='swish',padding='same')(encoder_inputs)
enc_l2 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(15,kernel_size=3,activation='swish',padding='same')(enc_l2)
enc_l3 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(10,kernel_size=3,activation='swish',padding='same')(enc_l3)
enc_l4 = MaxPooling1D(2,padding='same')(x)

x = Conv1D(5,kernel_size=3,activation='swish',padding='same')(enc_l4)
enc_l5 = MaxPooling1D(2,padding='same')(x)

x = Flatten()(enc_l5)
x = Dense(8,activation='swish')(x)
x = Dense(4,activation='swish')(x)
encoded = Dense(2,activation='linear')(x)

# LSTM
lstm_inputs = Reshape((1,2))(encoded)
x = LSTM(40,return_sequences=True)(lstm_inputs)
lstm_outputs = Dense(2,activation=None)(x)

# Decoder architecture (shared)
dec_layer_1 = Flatten()
dec_layer_2 = Dense(2,activation='swish')
dec_layer_3 = Dense(4,activation='swish')
dec_layer_4 = Dense(8,activation='linear')
dec_layer_5 = Reshape((8,1))

dec_layer_6 = Conv1D(5,kernel_size=3,activation='swish',padding='same')
dec_layer_7 = Conv1D(10,kernel_size=3,activation='swish',padding='same')
dec_layer_8 = Conv1D(15,kernel_size=3,activation='swish',padding='same')
dec_layer_9 = Conv1D(20,kernel_size=3,activation='swish',padding='same')
dec_layer_10 = Conv1D(1,kernel_size=3,activation=None,padding='same')

# Decoder - using LSTM
x = dec_layer_1(lstm_outputs)
x = dec_layer_2(x)
x = dec_layer_3(x)
x = dec_layer_4(x)
x = dec_layer_5(x)

x = dec_layer_6(x)
x = UpSampling1D(2)(x)

x = dec_layer_7(x)
x = UpSampling1D(2)(x)

x = dec_layer_8(x)
x = UpSampling1D(2)(x)

x = dec_layer_9(x)
x = UpSampling1D(2)(x)

lstm_decoder_outputs = dec_layer_10(x)

# Decoder - using AE only
x = dec_layer_1(encoded)
x = dec_layer_2(x)
x = dec_layer_3(x)
x = dec_layer_4(x)
x = dec_layer_5(x)

x = dec_layer_6(x)
x = UpSampling1D(2)(x)

x = dec_layer_7(x)
x = UpSampling1D(2)(x)

x = dec_layer_8(x)
x = UpSampling1D(2)(x)

x = dec_layer_9(x)
x = UpSampling1D(2)(x)

ae_decoder_outputs = dec_layer_10(x)

# Compile model
model = Model(inputs=[encoder_inputs],outputs=[ae_decoder_outputs,lstm_decoder_outputs],name='CAE-LSTM')
   
# design network
my_adam = optimizers.Adam(lr=lrate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

checkpoint = ModelCheckpoint(weights_filepath, monitor='loss', verbose=1, save_best_only=True, mode='min',save_weights_only=True)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
callbacks_list = [checkpoint]

# fit network
model.compile(optimizer=my_adam,loss='mean_squared_error',metrics=[coeff_determination],loss_weights=[1.0,1.0])    
model.summary()

num_epochs = 500
batch_size = 4

if mode == 'train':
    train_history = model.fit(x=snapshots_train, 
                              y=[snapshots_train,snapshots_evolve], 
                              epochs=num_epochs, 
                              batch_size=batch_size, 
                              callbacks=callbacks_list,
                              validation_split=0.1)
# Out:
# Model: "CAE-LSTM"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Field (InputLayer)              [(None, 128, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 128, 25)      100         Field[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 64, 25)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 64, 15)       1140        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 32, 15)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 32, 10)       460         max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 16, 10)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 16, 5)        155         max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 8, 5)         0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 40)           0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            328         flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            36          dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            10          dense_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 2)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 1, 40)        6880        reshape[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 2)         82          lstm[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2)            0           dense_3[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            6           flatten_1[0][0]
#                                                                  flatten_1[1][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            12          dense_4[0][0]
#                                                                  dense_4[1][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 8)            40          dense_5[0][0]
#                                                                  dense_5[1][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 8, 1)         0           dense_6[0][0]
#                                                                  dense_6[1][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 8, 5)         20          reshape_1[0][0]
#                                                                  reshape_1[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_4 (UpSampling1D)  (None, 16, 5)        0           conv1d_4[1][0]
# __________________________________________________________________________________________________
# up_sampling1d (UpSampling1D)    (None, 16, 5)        0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 16, 10)       160         up_sampling1d[0][0]
#                                                                  up_sampling1d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_5 (UpSampling1D)  (None, 32, 10)       0           conv1d_5[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_1 (UpSampling1D)  (None, 32, 10)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 32, 15)       465         up_sampling1d_1[0][0]
#                                                                  up_sampling1d_5[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_6 (UpSampling1D)  (None, 64, 15)       0           conv1d_6[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_2 (UpSampling1D)  (None, 64, 15)       0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 64, 20)       920         up_sampling1d_2[0][0]
#                                                                  up_sampling1d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling1d_7 (UpSampling1D)  (None, 128, 20)      0           conv1d_7[1][0]
# __________________________________________________________________________________________________
# up_sampling1d_3 (UpSampling1D)  (None, 128, 20)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 128, 1)       61          up_sampling1d_3[0][0]
#                                                                  up_sampling1d_7[0][0]
# ==================================================================================================
# Total params: 10,875
# Trainable params: 10,875
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0265 - conv1d_8_loss: 0.0133 - conv1d_8_1_loss: 0.0133 - conv1d_8_coeff_determination: -1914161.5000 - conv1d_8_1_coeff_determination: -1934249.0000
# Epoch 00001: loss improved from inf to 0.02566, saving model to best_weights.h5
# 90/90 [==============================] - 1s 11ms/step - loss: 0.0257 - conv1d_8_loss: 0.0128 - conv1d_8_1_loss: 0.0128 - conv1d_8_coeff_determination: -1786550.7500 - conv1d_8_1_coeff_determination: -1805299.0000 - val_loss: 0.0191 - val_conv1d_8_loss: 0.0094 - val_conv1d_8_1_loss: 0.0097 - val_conv1d_8_coeff_determination: -0.4154 - val_conv1d_8_1_coeff_determination: -0.4097
# Epoch 2/500
# 79/90 [=========================>....] - ETA: 0s - loss: 0.0117 - conv1d_8_loss: 0.0056 - conv1d_8_1_loss: 0.0061 - conv1d_8_coeff_determination: 0.3570 - conv1d_8_1_coeff_determination: 0.2771
# Epoch 00002: loss improved from 0.02566 to 0.01134, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0113 - conv1d_8_loss: 0.0054 - conv1d_8_1_loss: 0.0060 - conv1d_8_coeff_determination: 0.3889 - conv1d_8_1_coeff_determination: 0.2985 - val_loss: 0.0147 - val_conv1d_8_loss: 0.0067 - val_conv1d_8_1_loss: 0.0080 - val_conv1d_8_coeff_determination: 0.1279 - val_conv1d_8_1_coeff_determination: 0.0672
# Epoch 3/500
# 89/90 [============================>.] - ETA: 0s - loss: 0.0069 - conv1d_8_loss: 0.0032 - conv1d_8_1_loss: 0.0038 - conv1d_8_coeff_determination: 0.7292 - conv1d_8_1_coeff_determination: 0.6159
# Epoch 00003: loss improved from 0.01134 to 0.00691, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0069 - conv1d_8_loss: 0.0032 - conv1d_8_1_loss: 0.0037 - conv1d_8_coeff_determination: 0.7303 - conv1d_8_1_coeff_determination: 0.6181 - val_loss: 0.0064 - val_conv1d_8_loss: 0.0028 - val_conv1d_8_1_loss: 0.0036 - val_conv1d_8_coeff_determination: 0.6162 - val_conv1d_8_1_coeff_determination: 0.5552
# Epoch 4/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0043 - conv1d_8_loss: 0.0022 - conv1d_8_1_loss: 0.0022 - conv1d_8_coeff_determination: 0.8345 - conv1d_8_1_coeff_determination: 0.8229
# Epoch 00004: loss improved from 0.00691 to 0.00431, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0043 - conv1d_8_loss: 0.0021 - conv1d_8_1_loss: 0.0022 - conv1d_8_coeff_determination: 0.8352 - conv1d_8_1_coeff_determination: 0.8238 - val_loss: 0.0045 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0025 - val_conv1d_8_coeff_determination: 0.7521 - val_conv1d_8_1_coeff_determination: 0.7059
# Epoch 5/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0037 - conv1d_8_loss: 0.0018 - conv1d_8_1_loss: 0.0019 - conv1d_8_coeff_determination: 0.8589 - conv1d_8_1_coeff_determination: 0.8543
# Epoch 00005: loss improved from 0.00431 to 0.00369, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0037 - conv1d_8_loss: 0.0018 - conv1d_8_1_loss: 0.0019 - conv1d_8_coeff_determination: 0.8591 - conv1d_8_1_coeff_determination: 0.8545 - val_loss: 0.0038 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.7920 - val_conv1d_8_1_coeff_determination: 0.7651
# Epoch 6/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0034 - conv1d_8_loss: 0.0017 - conv1d_8_1_loss: 0.0017 - conv1d_8_coeff_determination: 0.8712 - conv1d_8_1_coeff_determination: 0.8684
# Epoch 00006: loss improved from 0.00369 to 0.00338, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0034 - conv1d_8_loss: 0.0017 - conv1d_8_1_loss: 0.0017 - conv1d_8_coeff_determination: 0.8718 - conv1d_8_1_coeff_determination: 0.8690 - val_loss: 0.0040 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0021 - val_conv1d_8_coeff_determination: 0.7889 - val_conv1d_8_1_coeff_determination: 0.7564
# Epoch 7/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0031 - conv1d_8_loss: 0.0016 - conv1d_8_1_loss: 0.0016 - conv1d_8_coeff_determination: 0.8815 - conv1d_8_1_coeff_determination: 0.8798
# Epoch 00007: loss improved from 0.00338 to 0.00313, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0031 - conv1d_8_loss: 0.0016 - conv1d_8_1_loss: 0.0016 - conv1d_8_coeff_determination: 0.8819 - conv1d_8_1_coeff_determination: 0.8802 - val_loss: 0.0039 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.7862 - val_conv1d_8_1_coeff_determination: 0.7688
# Epoch 8/500
# 90/90 [==============================] - ETA: 0s - loss: 0.0029 - conv1d_8_loss: 0.0015 - conv1d_8_1_loss: 0.0015 - conv1d_8_coeff_determination: 0.8894 - conv1d_8_1_coeff_determination: 0.8881
# Epoch 00008: loss improved from 0.00313 to 0.00294, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0029 - conv1d_8_loss: 0.0015 - conv1d_8_1_loss: 0.0015 - conv1d_8_coeff_determination: 0.8894 - conv1d_8_1_coeff_determination: 0.8881 - val_loss: 0.0044 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0023 - val_conv1d_8_coeff_determination: 0.7649 - val_conv1d_8_1_coeff_determination: 0.7436
# Epoch 9/500
# 82/90 [==========================>...] - ETA: 0s - loss: 0.0028 - conv1d_8_loss: 0.0014 - conv1d_8_1_loss: 0.0014 - conv1d_8_coeff_determination: 0.8953 - conv1d_8_1_coeff_determination: 0.8942
# Epoch 00009: loss improved from 0.00294 to 0.00280, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0028 - conv1d_8_loss: 0.0014 - conv1d_8_1_loss: 0.0014 - conv1d_8_coeff_determination: 0.8957 - conv1d_8_1_coeff_determination: 0.8946 - val_loss: 0.0047 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0024 - val_conv1d_8_coeff_determination: 0.7646 - val_conv1d_8_1_coeff_determination: 0.7457
# Epoch 10/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0027 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.8996 - conv1d_8_1_coeff_determination: 0.8985
# Epoch 00010: loss improved from 0.00280 to 0.00270, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0027 - conv1d_8_loss: 0.0014 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.8997 - conv1d_8_1_coeff_determination: 0.8985 - val_loss: 0.0047 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0025 - val_conv1d_8_coeff_determination: 0.7404 - val_conv1d_8_1_coeff_determination: 0.7202
# Epoch 11/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0027 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.9018 - conv1d_8_1_coeff_determination: 0.9009
# Epoch 00011: loss improved from 0.00270 to 0.00263, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0026 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.9021 - conv1d_8_1_coeff_determination: 0.9013 - val_loss: 0.0050 - val_conv1d_8_loss: 0.0024 - val_conv1d_8_1_loss: 0.0026 - val_conv1d_8_coeff_determination: 0.7367 - val_conv1d_8_1_coeff_determination: 0.7195
# Epoch 12/500
# 79/90 [=========================>....] - ETA: 0s - loss: 0.0026 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.9045 - conv1d_8_1_coeff_determination: 0.9036
# Epoch 00012: loss improved from 0.00263 to 0.00257, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0026 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.9048 - conv1d_8_1_coeff_determination: 0.9039 - val_loss: 0.0047 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0024 - val_conv1d_8_coeff_determination: 0.7481 - val_conv1d_8_1_coeff_determination: 0.7272
# Epoch 13/500
# 80/90 [=========================>....] - ETA: 0s - loss: 0.0025 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.9071 - conv1d_8_1_coeff_determination: 0.9065
# Epoch 00013: loss improved from 0.00257 to 0.00251, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0025 - conv1d_8_loss: 0.0013 - conv1d_8_1_loss: 0.0013 - conv1d_8_coeff_determination: 0.9073 - conv1d_8_1_coeff_determination: 0.9066 - val_loss: 0.0055 - val_conv1d_8_loss: 0.0027 - val_conv1d_8_1_loss: 0.0028 - val_conv1d_8_coeff_determination: 0.7084 - val_conv1d_8_1_coeff_determination: 0.6875
# Epoch 14/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0025 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0012 - conv1d_8_coeff_determination: 0.9087 - conv1d_8_1_coeff_determination: 0.9081
# Epoch 00014: loss improved from 0.00251 to 0.00247, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0025 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0012 - conv1d_8_coeff_determination: 0.9088 - conv1d_8_1_coeff_determination: 0.9081 - val_loss: 0.0048 - val_conv1d_8_loss: 0.0023 - val_conv1d_8_1_loss: 0.0025 - val_conv1d_8_coeff_determination: 0.7374 - val_conv1d_8_1_coeff_determination: 0.7197
# Epoch 15/500
# 82/90 [==========================>...] - ETA: 0s - loss: 0.0024 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0012 - conv1d_8_coeff_determination: 0.9121 - conv1d_8_1_coeff_determination: 0.9116
# Epoch 00015: loss improved from 0.00247 to 0.00239, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0024 - conv1d_8_loss: 0.0012 - conv1d_8_1_loss: 0.0012 - conv1d_8_coeff_determination: 0.9119 - conv1d_8_1_coeff_determination: 0.9114 - val_loss: 0.0056 - val_conv1d_8_loss: 0.0027 - val_conv1d_8_1_loss: 0.0028 - val_conv1d_8_coeff_determination: 0.6970 - val_conv1d_8_1_coeff_determination: 0.6866
# Epoch 16/500
# 78/90 [=========================>....] - ETA: 0s - loss: 0.0023 - conv1d_8_loss: 0.0011 - conv1d_8_1_loss: 0.0011 - conv1d_8_coeff_determination: 0.9158 - conv1d_8_1_coeff_determination: 0.9155
# Epoch 00016: loss improved from 0.00239 to 0.00229, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0023 - conv1d_8_loss: 0.0011 - conv1d_8_1_loss: 0.0011 - conv1d_8_coeff_determination: 0.9157 - conv1d_8_1_coeff_determination: 0.9153 - val_loss: 0.0052 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0027 - val_conv1d_8_coeff_determination: 0.7359 - val_conv1d_8_1_coeff_determination: 0.7116
# Epoch 17/500
# 86/90 [===========================>..] - ETA: 0s - loss: 0.0020 - conv1d_8_loss: 0.0010 - conv1d_8_1_loss: 0.0010 - conv1d_8_coeff_determination: 0.9264 - conv1d_8_1_coeff_determination: 0.9264
# Epoch 00017: loss improved from 0.00229 to 0.00200, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0020 - conv1d_8_loss: 0.0010 - conv1d_8_1_loss: 9.9616e-04 - conv1d_8_coeff_determination: 0.9265 - conv1d_8_1_coeff_determination: 0.9265 - val_loss: 0.0048 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0026 - val_conv1d_8_coeff_determination: 0.7361 - val_conv1d_8_1_coeff_determination: 0.6902
# Epoch 18/500
# 86/90 [===========================>..] - ETA: 0s - loss: 0.0016 - conv1d_8_loss: 8.1840e-04 - conv1d_8_1_loss: 8.1919e-04 - conv1d_8_coeff_determination: 0.9407 - conv1d_8_1_coeff_determination: 0.9400
# Epoch 00018: loss improved from 0.00200 to 0.00163, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0016 - conv1d_8_loss: 8.1414e-04 - conv1d_8_1_loss: 8.1467e-04 - conv1d_8_coeff_determination: 0.9410 - conv1d_8_1_coeff_determination: 0.9403 - val_loss: 0.0049 - val_conv1d_8_loss: 0.0024 - val_conv1d_8_1_loss: 0.0025 - val_conv1d_8_coeff_determination: 0.7243 - val_conv1d_8_1_coeff_determination: 0.7165
# Epoch 19/500
# 83/90 [==========================>...] - ETA: 0s - loss: 0.0014 - conv1d_8_loss: 6.9256e-04 - conv1d_8_1_loss: 6.9336e-04 - conv1d_8_coeff_determination: 0.9511 - conv1d_8_1_coeff_determination: 0.9508
# Epoch 00019: loss improved from 0.00163 to 0.00137, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0014 - conv1d_8_loss: 6.8621e-04 - conv1d_8_1_loss: 6.8684e-04 - conv1d_8_coeff_determination: 0.9512 - conv1d_8_1_coeff_determination: 0.9509 - val_loss: 0.0058 - val_conv1d_8_loss: 0.0027 - val_conv1d_8_1_loss: 0.0030 - val_conv1d_8_coeff_determination: 0.6657 - val_conv1d_8_1_coeff_determination: 0.6289
# Epoch 20/500
# 86/90 [===========================>..] - ETA: 0s - loss: 0.0013 - conv1d_8_loss: 6.3615e-04 - conv1d_8_1_loss: 6.3660e-04 - conv1d_8_coeff_determination: 0.9549 - conv1d_8_1_coeff_determination: 0.9547
# Epoch 00020: loss improved from 0.00137 to 0.00126, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0013 - conv1d_8_loss: 6.3227e-04 - conv1d_8_1_loss: 6.3255e-04 - conv1d_8_coeff_determination: 0.9551 - conv1d_8_1_coeff_determination: 0.9549 - val_loss: 0.0053 - val_conv1d_8_loss: 0.0025 - val_conv1d_8_1_loss: 0.0027 - val_conv1d_8_coeff_determination: 0.7203 - val_conv1d_8_1_coeff_determination: 0.7054
# Epoch 21/500
# 85/90 [===========================>..] - ETA: 0s - loss: 0.0013 - conv1d_8_loss: 6.2626e-04 - conv1d_8_1_loss: 6.3201e-04 - conv1d_8_coeff_determination: 0.9561 - conv1d_8_1_coeff_determination: 0.9555
# Epoch 00021: loss improved from 0.00126 to 0.00125, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0012 - conv1d_8_loss: 6.2140e-04 - conv1d_8_1_loss: 6.2705e-04 - conv1d_8_coeff_determination: 0.9562 - conv1d_8_1_coeff_determination: 0.9556 - val_loss: 0.0041 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0021 - val_conv1d_8_coeff_determination: 0.7602 - val_conv1d_8_1_coeff_determination: 0.7478
# Epoch 22/500
# 83/90 [==========================>...] - ETA: 0s - loss: 0.0011 - conv1d_8_loss: 5.7543e-04 - conv1d_8_1_loss: 5.7404e-04 - conv1d_8_coeff_determination: 0.9596 - conv1d_8_1_coeff_determination: 0.9597
# Epoch 00022: loss improved from 0.00125 to 0.00114, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0011 - conv1d_8_loss: 5.7144e-04 - conv1d_8_1_loss: 5.7007e-04 - conv1d_8_coeff_determination: 0.9598 - conv1d_8_1_coeff_determination: 0.9598 - val_loss: 0.0045 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0023 - val_conv1d_8_coeff_determination: 0.7543 - val_conv1d_8_1_coeff_determination: 0.7378
# Epoch 23/500
# 90/90 [==============================] - ETA: 0s - loss: 0.0011 - conv1d_8_loss: 5.5626e-04 - conv1d_8_1_loss: 5.5425e-04 - conv1d_8_coeff_determination: 0.9608 - conv1d_8_1_coeff_determination: 0.9608
# Epoch 00023: loss improved from 0.00114 to 0.00111, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0011 - conv1d_8_loss: 5.5626e-04 - conv1d_8_1_loss: 5.5425e-04 - conv1d_8_coeff_determination: 0.9608 - conv1d_8_1_coeff_determination: 0.9608 - val_loss: 0.0042 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0022 - val_conv1d_8_coeff_determination: 0.7804 - val_conv1d_8_1_coeff_determination: 0.7638
# Epoch 24/500
# 83/90 [==========================>...] - ETA: 0s - loss: 0.0011 - conv1d_8_loss: 5.3911e-04 - conv1d_8_1_loss: 5.3882e-04 - conv1d_8_coeff_determination: 0.9622 - conv1d_8_1_coeff_determination: 0.9621
# Epoch 00024: loss improved from 0.00111 to 0.00108, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0011 - conv1d_8_loss: 5.4219e-04 - conv1d_8_1_loss: 5.4245e-04 - conv1d_8_coeff_determination: 0.9619 - conv1d_8_1_coeff_determination: 0.9618 - val_loss: 0.0040 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.7955 - val_conv1d_8_1_coeff_determination: 0.7889
# Epoch 25/500
# 80/90 [=========================>....] - ETA: 0s - loss: 0.0011 - conv1d_8_loss: 5.4122e-04 - conv1d_8_1_loss: 5.4280e-04 - conv1d_8_coeff_determination: 0.9619 - conv1d_8_1_coeff_determination: 0.9617
# Epoch 00025: loss improved from 0.00108 to 0.00107, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0011 - conv1d_8_loss: 5.3476e-04 - conv1d_8_1_loss: 5.3630e-04 - conv1d_8_coeff_determination: 0.9622 - conv1d_8_1_coeff_determination: 0.9620 - val_loss: 0.0041 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0021 - val_conv1d_8_coeff_determination: 0.7854 - val_conv1d_8_1_coeff_determination: 0.7670
# Epoch 26/500
# 84/90 [===========================>..] - ETA: 0s - loss: 0.0010 - conv1d_8_loss: 5.2436e-04 - conv1d_8_1_loss: 5.2348e-04 - conv1d_8_coeff_determination: 0.9628 - conv1d_8_1_coeff_determination: 0.9628
# Epoch 00026: loss improved from 0.00107 to 0.00105, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0010 - conv1d_8_loss: 5.2500e-04 - conv1d_8_1_loss: 5.2418e-04 - conv1d_8_coeff_determination: 0.9629 - conv1d_8_1_coeff_determination: 0.9629 - val_loss: 0.0041 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0021 - val_conv1d_8_coeff_determination: 0.7813 - val_conv1d_8_1_coeff_determination: 0.7663
# Epoch 27/500
# 82/90 [==========================>...] - ETA: 0s - loss: 0.0011 - conv1d_8_loss: 5.2784e-04 - conv1d_8_1_loss: 5.3033e-04 - conv1d_8_coeff_determination: 0.9632 - conv1d_8_1_coeff_determination: 0.9630
# Epoch 00027: loss did not improve from 0.00105
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0010 - conv1d_8_loss: 5.2348e-04 - conv1d_8_1_loss: 5.2649e-04 - conv1d_8_coeff_determination: 0.9632 - conv1d_8_1_coeff_determination: 0.9630 - val_loss: 0.0043 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0022 - val_conv1d_8_coeff_determination: 0.7902 - val_conv1d_8_1_coeff_determination: 0.7740
# Epoch 28/500
# 87/90 [============================>.] - ETA: 0s - loss: 0.0010 - conv1d_8_loss: 5.2003e-04 - conv1d_8_1_loss: 5.2793e-04 - conv1d_8_coeff_determination: 0.9631 - conv1d_8_1_coeff_determination: 0.9623
# Epoch 00028: loss improved from 0.00105 to 0.00104, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0010 - conv1d_8_loss: 5.1798e-04 - conv1d_8_1_loss: 5.2535e-04 - conv1d_8_coeff_determination: 0.9632 - conv1d_8_1_coeff_determination: 0.9625 - val_loss: 0.0045 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0023 - val_conv1d_8_coeff_determination: 0.7588 - val_conv1d_8_1_coeff_determination: 0.7473
# Epoch 29/500
# 88/90 [============================>.] - ETA: 0s - loss: 9.7363e-04 - conv1d_8_loss: 4.8661e-04 - conv1d_8_1_loss: 4.8703e-04 - conv1d_8_coeff_determination: 0.9659 - conv1d_8_1_coeff_determination: 0.9658
# Epoch 00029: loss improved from 0.00104 to 0.00097, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 9.6959e-04 - conv1d_8_loss: 4.8453e-04 - conv1d_8_1_loss: 4.8506e-04 - conv1d_8_coeff_determination: 0.9660 - conv1d_8_1_coeff_determination: 0.9659 - val_loss: 0.0038 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.8023 - val_conv1d_8_1_coeff_determination: 0.7880
# Epoch 30/500
# 78/90 [=========================>....] - ETA: 0s - loss: 9.7737e-04 - conv1d_8_loss: 4.8856e-04 - conv1d_8_1_loss: 4.8881e-04 - conv1d_8_coeff_determination: 0.9660 - conv1d_8_1_coeff_determination: 0.9659
# Epoch 00030: loss improved from 0.00097 to 0.00097, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 9.6622e-04 - conv1d_8_loss: 4.8344e-04 - conv1d_8_1_loss: 4.8279e-04 - conv1d_8_coeff_determination: 0.9660 - conv1d_8_1_coeff_determination: 0.9660 - val_loss: 0.0043 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0022 - val_conv1d_8_coeff_determination: 0.7723 - val_conv1d_8_1_coeff_determination: 0.7602
# Epoch 31/500
# 85/90 [===========================>..] - ETA: 0s - loss: 9.5961e-04 - conv1d_8_loss: 4.7845e-04 - conv1d_8_1_loss: 4.8116e-04 - conv1d_8_coeff_determination: 0.9666 - conv1d_8_1_coeff_determination: 0.9664
# Epoch 00031: loss improved from 0.00097 to 0.00096, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 9.5669e-04 - conv1d_8_loss: 4.7701e-04 - conv1d_8_1_loss: 4.7968e-04 - conv1d_8_coeff_determination: 0.9666 - conv1d_8_1_coeff_determination: 0.9663 - val_loss: 0.0040 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.7879 - val_conv1d_8_1_coeff_determination: 0.7843
# Epoch 32/500
# 83/90 [==========================>...] - ETA: 0s - loss: 9.2571e-04 - conv1d_8_loss: 4.6214e-04 - conv1d_8_1_loss: 4.6358e-04 - conv1d_8_coeff_determination: 0.9673 - conv1d_8_1_coeff_determination: 0.9672
# Epoch 00032: loss improved from 0.00096 to 0.00092, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 9.2228e-04 - conv1d_8_loss: 4.6032e-04 - conv1d_8_1_loss: 4.6196e-04 - conv1d_8_coeff_determination: 0.9676 - conv1d_8_1_coeff_determination: 0.9674 - val_loss: 0.0040 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.7991 - val_conv1d_8_1_coeff_determination: 0.7915
# Epoch 33/500
# 80/90 [=========================>....] - ETA: 0s - loss: 8.9288e-04 - conv1d_8_loss: 4.4639e-04 - conv1d_8_1_loss: 4.4649e-04 - conv1d_8_coeff_determination: 0.9686 - conv1d_8_1_coeff_determination: 0.9685
# Epoch 00033: loss improved from 0.00092 to 0.00089, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 8.9091e-04 - conv1d_8_loss: 4.4517e-04 - conv1d_8_1_loss: 4.4575e-04 - conv1d_8_coeff_determination: 0.9686 - conv1d_8_1_coeff_determination: 0.9685 - val_loss: 0.0043 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0022 - val_conv1d_8_coeff_determination: 0.7538 - val_conv1d_8_1_coeff_determination: 0.7467
# Epoch 34/500
# 88/90 [============================>.] - ETA: 0s - loss: 8.5682e-04 - conv1d_8_loss: 4.2721e-04 - conv1d_8_1_loss: 4.2961e-04 - conv1d_8_coeff_determination: 0.9699 - conv1d_8_1_coeff_determination: 0.9697
# Epoch 00034: loss improved from 0.00089 to 0.00086, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 8.6085e-04 - conv1d_8_loss: 4.2949e-04 - conv1d_8_1_loss: 4.3136e-04 - conv1d_8_coeff_determination: 0.9699 - conv1d_8_1_coeff_determination: 0.9697 - val_loss: 0.0042 - val_conv1d_8_loss: 0.0020 - val_conv1d_8_1_loss: 0.0021 - val_conv1d_8_coeff_determination: 0.7792 - val_conv1d_8_1_coeff_determination: 0.7687
# Epoch 35/500
# 86/90 [===========================>..] - ETA: 0s - loss: 8.3403e-04 - conv1d_8_loss: 4.1713e-04 - conv1d_8_1_loss: 4.1690e-04 - conv1d_8_coeff_determination: 0.9707 - conv1d_8_1_coeff_determination: 0.9707
# Epoch 00035: loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 8.2762e-04 - conv1d_8_loss: 4.1393e-04 - conv1d_8_1_loss: 4.1369e-04 - conv1d_8_coeff_determination: 0.9708 - conv1d_8_1_coeff_determination: 0.9708 - val_loss: 0.0034 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0017 - val_conv1d_8_coeff_determination: 0.8217 - val_conv1d_8_1_coeff_determination: 0.8148
# Epoch 36/500
# 88/90 [============================>.] - ETA: 0s - loss: 7.7642e-04 - conv1d_8_loss: 3.8822e-04 - conv1d_8_1_loss: 3.8819e-04 - conv1d_8_coeff_determination: 0.9728 - conv1d_8_1_coeff_determination: 0.9728
# Epoch 00036: loss improved from 0.00083 to 0.00078, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 7.7576e-04 - conv1d_8_loss: 3.8795e-04 - conv1d_8_1_loss: 3.8781e-04 - conv1d_8_coeff_determination: 0.9728 - conv1d_8_1_coeff_determination: 0.9728 - val_loss: 0.0039 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.7901 - val_conv1d_8_1_coeff_determination: 0.7828
# Epoch 37/500
# 87/90 [============================>.] - ETA: 0s - loss: 7.2050e-04 - conv1d_8_loss: 3.6071e-04 - conv1d_8_1_loss: 3.5980e-04 - conv1d_8_coeff_determination: 0.9748 - conv1d_8_1_coeff_determination: 0.9748
# Epoch 00037: loss improved from 0.00078 to 0.00072, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 7.2488e-04 - conv1d_8_loss: 3.6276e-04 - conv1d_8_1_loss: 3.6212e-04 - conv1d_8_coeff_determination: 0.9744 - conv1d_8_1_coeff_determination: 0.9744 - val_loss: 0.0037 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0019 - val_conv1d_8_coeff_determination: 0.7934 - val_conv1d_8_1_coeff_determination: 0.7842
# Epoch 38/500
# 86/90 [===========================>..] - ETA: 0s - loss: 7.3542e-04 - conv1d_8_loss: 3.6603e-04 - conv1d_8_1_loss: 3.6939e-04 - conv1d_8_coeff_determination: 0.9742 - conv1d_8_1_coeff_determination: 0.9739
# Epoch 00038: loss did not improve from 0.00072
# 90/90 [==============================] - 0s 5ms/step - loss: 7.4103e-04 - conv1d_8_loss: 3.6898e-04 - conv1d_8_1_loss: 3.7206e-04 - conv1d_8_coeff_determination: 0.9741 - conv1d_8_1_coeff_determination: 0.9738 - val_loss: 0.0039 - val_conv1d_8_loss: 0.0019 - val_conv1d_8_1_loss: 0.0020 - val_conv1d_8_coeff_determination: 0.8005 - val_conv1d_8_1_coeff_determination: 0.7938
# Epoch 39/500
# 81/90 [==========================>...] - ETA: 0s - loss: 6.8624e-04 - conv1d_8_loss: 3.4382e-04 - conv1d_8_1_loss: 3.4242e-04 - conv1d_8_coeff_determination: 0.9760 - conv1d_8_1_coeff_determination: 0.9761
# Epoch 00039: loss improved from 0.00072 to 0.00068, saving model to best_weights.h5
# 90/90 [==============================] - 0s 6ms/step - loss: 6.8070e-04 - conv1d_8_loss: 3.4093e-04 - conv1d_8_1_loss: 3.3977e-04 - conv1d_8_coeff_determination: 0.9761 - conv1d_8_1_coeff_determination: 0.9762 - val_loss: 0.0036 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0018 - val_conv1d_8_coeff_determination: 0.8012 - val_conv1d_8_1_coeff_determination: 0.7931
# Epoch 40/500
# 84/90 [===========================>..] - ETA: 0s - loss: 7.2932e-04 - conv1d_8_loss: 3.6257e-04 - conv1d_8_1_loss: 3.6675e-04 - conv1d_8_coeff_determination: 0.9750 - conv1d_8_1_coeff_determination: 0.9746
# Epoch 00040: loss did not improve from 0.00068
# 90/90 [==============================] - 0s 5ms/step - loss: 7.1343e-04 - conv1d_8_loss: 3.5479e-04 - conv1d_8_1_loss: 3.5864e-04 - conv1d_8_coeff_determination: 0.9753 - conv1d_8_1_coeff_determination: 0.9750 - val_loss: 0.0044 - val_conv1d_8_loss: 0.0021 - val_conv1d_8_1_loss: 0.0022 - val_conv1d_8_coeff_determination: 0.7761 - val_conv1d_8_1_coeff_determination: 0.7707
# Epoch 41/500
# 88/90 [============================>.] - ETA: 0s - loss: 7.1371e-04 - conv1d_8_loss: 3.5295e-04 - conv1d_8_1_loss: 3.6075e-04 - conv1d_8_coeff_determination: 0.9754 - conv1d_8_1_coeff_determination: 0.9748
# Epoch 00041: loss did not improve from 0.00068
# 90/90 [==============================] - 0s 5ms/step - loss: 7.1663e-04 - conv1d_8_loss: 3.5424e-04 - conv1d_8_1_loss: 3.6239e-04 - conv1d_8_coeff_determination: 0.9754 - conv1d_8_1_coeff_determination: 0.9748 - val_loss: 0.0044 - val_conv1d_8_loss: 0.0022 - val_conv1d_8_1_loss: 0.0023 - val_conv1d_8_coeff_determination: 0.7611 - val_conv1d_8_1_coeff_determination: 0.7509
# Epoch 42/500
# 80/90 [=========================>....] - ETA: 0s - loss: 7.0713e-04 - conv1d_8_loss: 3.5099e-04 - conv1d_8_1_loss: 3.5613e-04 - conv1d_8_coeff_determination: 0.9755 - conv1d_8_1_coeff_determination: 0.9751
# Epoch 00042: loss did not improve from 0.00068
# 90/90 [==============================] - 1s 6ms/step - loss: 6.9958e-04 - conv1d_8_loss: 3.4752e-04 - conv1d_8_1_loss: 3.5206e-04 - conv1d_8_coeff_determination: 0.9756 - conv1d_8_1_coeff_determination: 0.9753 - val_loss: 0.0034 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0018 - val_conv1d_8_coeff_determination: 0.8122 - val_conv1d_8_1_coeff_determination: 0.8071
# Epoch 43/500
# 87/90 [============================>.] - ETA: 0s - loss: 6.0440e-04 - conv1d_8_loss: 3.0304e-04 - conv1d_8_1_loss: 3.0136e-04 - conv1d_8_coeff_determination: 0.9791 - conv1d_8_1_coeff_determination: 0.9791
# Epoch 00043: loss improved from 0.00068 to 0.00060, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 6.0370e-04 - conv1d_8_loss: 3.0262e-04 - conv1d_8_1_loss: 3.0108e-04 - conv1d_8_coeff_determination: 0.9791 - conv1d_8_1_coeff_determination: 0.9791 - val_loss: 0.0035 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0017 - val_conv1d_8_coeff_determination: 0.8071 - val_conv1d_8_1_coeff_determination: 0.8050
# Epoch 44/500
# 87/90 [============================>.] - ETA: 0s - loss: 5.9894e-04 - conv1d_8_loss: 3.0074e-04 - conv1d_8_1_loss: 2.9819e-04 - conv1d_8_coeff_determination: 0.9793 - conv1d_8_1_coeff_determination: 0.9793
# Epoch 00044: loss improved from 0.00060 to 0.00059, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 5.9449e-04 - conv1d_8_loss: 2.9850e-04 - conv1d_8_1_loss: 2.9599e-04 - conv1d_8_coeff_determination: 0.9794 - conv1d_8_1_coeff_determination: 0.9794 - val_loss: 0.0032 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8247 - val_conv1d_8_1_coeff_determination: 0.8211
# Epoch 45/500
# 88/90 [============================>.] - ETA: 0s - loss: 6.2892e-04 - conv1d_8_loss: 3.1374e-04 - conv1d_8_1_loss: 3.1518e-04 - conv1d_8_coeff_determination: 0.9783 - conv1d_8_1_coeff_determination: 0.9781
# Epoch 00045: loss did not improve from 0.00059
# 90/90 [==============================] - 1s 6ms/step - loss: 6.3074e-04 - conv1d_8_loss: 3.1462e-04 - conv1d_8_1_loss: 3.1612e-04 - conv1d_8_coeff_determination: 0.9782 - conv1d_8_1_coeff_determination: 0.9780 - val_loss: 0.0037 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0019 - val_conv1d_8_coeff_determination: 0.7848 - val_conv1d_8_1_coeff_determination: 0.7780
# Epoch 46/500
# 80/90 [=========================>....] - ETA: 0s - loss: 5.8452e-04 - conv1d_8_loss: 2.9329e-04 - conv1d_8_1_loss: 2.9123e-04 - conv1d_8_coeff_determination: 0.9798 - conv1d_8_1_coeff_determination: 0.9799
# Epoch 00046: loss improved from 0.00059 to 0.00058, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.8285e-04 - conv1d_8_loss: 2.9206e-04 - conv1d_8_1_loss: 2.9079e-04 - conv1d_8_coeff_determination: 0.9798 - conv1d_8_1_coeff_determination: 0.9798 - val_loss: 0.0034 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0017 - val_conv1d_8_coeff_determination: 0.8125 - val_conv1d_8_1_coeff_determination: 0.8082
# Epoch 47/500
# 89/90 [============================>.] - ETA: 0s - loss: 5.7259e-04 - conv1d_8_loss: 2.8678e-04 - conv1d_8_1_loss: 2.8581e-04 - conv1d_8_coeff_determination: 0.9801 - conv1d_8_1_coeff_determination: 0.9800
# Epoch 00047: loss improved from 0.00058 to 0.00057, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.7293e-04 - conv1d_8_loss: 2.8690e-04 - conv1d_8_1_loss: 2.8603e-04 - conv1d_8_coeff_determination: 0.9801 - conv1d_8_1_coeff_determination: 0.9800 - val_loss: 0.0032 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8419 - val_conv1d_8_1_coeff_determination: 0.8399
# Epoch 48/500
# 88/90 [============================>.] - ETA: 0s - loss: 5.8425e-04 - conv1d_8_loss: 2.9130e-04 - conv1d_8_1_loss: 2.9295e-04 - conv1d_8_coeff_determination: 0.9799 - conv1d_8_1_coeff_determination: 0.9797
# Epoch 00048: loss did not improve from 0.00057
# 90/90 [==============================] - 0s 4ms/step - loss: 5.8359e-04 - conv1d_8_loss: 2.9100e-04 - conv1d_8_1_loss: 2.9258e-04 - conv1d_8_coeff_determination: 0.9799 - conv1d_8_1_coeff_determination: 0.9797 - val_loss: 0.0031 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8237 - val_conv1d_8_1_coeff_determination: 0.8226
# Epoch 49/500
# 87/90 [============================>.] - ETA: 0s - loss: 5.3481e-04 - conv1d_8_loss: 2.6777e-04 - conv1d_8_1_loss: 2.6703e-04 - conv1d_8_coeff_determination: 0.9817 - conv1d_8_1_coeff_determination: 0.9817
# Epoch 00049: loss improved from 0.00057 to 0.00053, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 5.3144e-04 - conv1d_8_loss: 2.6600e-04 - conv1d_8_1_loss: 2.6544e-04 - conv1d_8_coeff_determination: 0.9818 - conv1d_8_1_coeff_determination: 0.9817 - val_loss: 0.0030 - val_conv1d_8_loss: 0.0015 - val_conv1d_8_1_loss: 0.0015 - val_conv1d_8_coeff_determination: 0.8275 - val_conv1d_8_1_coeff_determination: 0.8247
# Epoch 50/500
# 89/90 [============================>.] - ETA: 0s - loss: 5.2020e-04 - conv1d_8_loss: 2.6141e-04 - conv1d_8_1_loss: 2.5880e-04 - conv1d_8_coeff_determination: 0.9821 - conv1d_8_1_coeff_determination: 0.9821
# Epoch 00050: loss improved from 0.00053 to 0.00052, saving model to best_weights.h5
# 90/90 [==============================] - 0s 3ms/step - loss: 5.2171e-04 - conv1d_8_loss: 2.6208e-04 - conv1d_8_1_loss: 2.5962e-04 - conv1d_8_coeff_determination: 0.9821 - conv1d_8_1_coeff_determination: 0.9821 - val_loss: 0.0032 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8299 - val_conv1d_8_1_coeff_determination: 0.8282
# Epoch 51/500
# 86/90 [===========================>..] - ETA: 0s - loss: 5.0313e-04 - conv1d_8_loss: 2.5249e-04 - conv1d_8_1_loss: 2.5064e-04 - conv1d_8_coeff_determination: 0.9826 - conv1d_8_1_coeff_determination: 0.9826
# Epoch 00051: loss improved from 0.00052 to 0.00050, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 5.0076e-04 - conv1d_8_loss: 2.5136e-04 - conv1d_8_1_loss: 2.4941e-04 - conv1d_8_coeff_determination: 0.9827 - conv1d_8_1_coeff_determination: 0.9827 - val_loss: 0.0033 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8173 - val_conv1d_8_1_coeff_determination: 0.8159
# Epoch 52/500
# 90/90 [==============================] - ETA: 0s - loss: 5.0255e-04 - conv1d_8_loss: 2.5099e-04 - conv1d_8_1_loss: 2.5157e-04 - conv1d_8_coeff_determination: 0.9828 - conv1d_8_1_coeff_determination: 0.9826
# Epoch 00052: loss did not improve from 0.00050
# 90/90 [==============================] - 0s 4ms/step - loss: 5.0255e-04 - conv1d_8_loss: 2.5099e-04 - conv1d_8_1_loss: 2.5157e-04 - conv1d_8_coeff_determination: 0.9828 - conv1d_8_1_coeff_determination: 0.9826 - val_loss: 0.0031 - val_conv1d_8_loss: 0.0015 - val_conv1d_8_1_loss: 0.0015 - val_conv1d_8_coeff_determination: 0.8281 - val_conv1d_8_1_coeff_determination: 0.8262
# Epoch 53/500
# 89/90 [============================>.] - ETA: 0s - loss: 4.6925e-04 - conv1d_8_loss: 2.3591e-04 - conv1d_8_1_loss: 2.3333e-04 - conv1d_8_coeff_determination: 0.9838 - conv1d_8_1_coeff_determination: 0.9839
# Epoch 00053: loss improved from 0.00050 to 0.00047, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 4.7193e-04 - conv1d_8_loss: 2.3722e-04 - conv1d_8_1_loss: 2.3471e-04 - conv1d_8_coeff_determination: 0.9837 - conv1d_8_1_coeff_determination: 0.9837 - val_loss: 0.0034 - val_conv1d_8_loss: 0.0017 - val_conv1d_8_1_loss: 0.0017 - val_conv1d_8_coeff_determination: 0.8221 - val_conv1d_8_1_coeff_determination: 0.8204
# Epoch 54/500
# 88/90 [============================>.] - ETA: 0s - loss: 4.7113e-04 - conv1d_8_loss: 2.3648e-04 - conv1d_8_1_loss: 2.3465e-04 - conv1d_8_coeff_determination: 0.9837 - conv1d_8_1_coeff_determination: 0.9837
# Epoch 00054: loss did not improve from 0.00047
# 90/90 [==============================] - 0s 4ms/step - loss: 4.7343e-04 - conv1d_8_loss: 2.3763e-04 - conv1d_8_1_loss: 2.3580e-04 - conv1d_8_coeff_determination: 0.9837 - conv1d_8_1_coeff_determination: 0.9837 - val_loss: 0.0036 - val_conv1d_8_loss: 0.0018 - val_conv1d_8_1_loss: 0.0018 - val_conv1d_8_coeff_determination: 0.8033 - val_conv1d_8_1_coeff_determination: 0.7974
# Epoch 55/500
# 85/90 [===========================>..] - ETA: 0s - loss: 4.7778e-04 - conv1d_8_loss: 2.3827e-04 - conv1d_8_1_loss: 2.3951e-04 - conv1d_8_coeff_determination: 0.9838 - conv1d_8_1_coeff_determination: 0.9836
# Epoch 00055: loss did not improve from 0.00047
# 90/90 [==============================] - 0s 4ms/step - loss: 4.7828e-04 - conv1d_8_loss: 2.3872e-04 - conv1d_8_1_loss: 2.3956e-04 - conv1d_8_coeff_determination: 0.9837 - conv1d_8_1_coeff_determination: 0.9835 - val_loss: 0.0032 - val_conv1d_8_loss: 0.0016 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8247 - val_conv1d_8_1_coeff_determination: 0.8207
# Epoch 56/500
# 83/90 [==========================>...] - ETA: 0s - loss: 4.8516e-04 - conv1d_8_loss: 2.4100e-04 - conv1d_8_1_loss: 2.4417e-04 - conv1d_8_coeff_determination: 0.9834 - conv1d_8_1_coeff_determination: 0.9831
# Epoch 00056: loss did not improve from 0.00047
# 90/90 [==============================] - 0s 5ms/step - loss: 4.8245e-04 - conv1d_8_loss: 2.3985e-04 - conv1d_8_1_loss: 2.4260e-04 - conv1d_8_coeff_determination: 0.9836 - conv1d_8_1_coeff_determination: 0.9834 - val_loss: 0.0030 - val_conv1d_8_loss: 0.0015 - val_conv1d_8_1_loss: 0.0015 - val_conv1d_8_coeff_determination: 0.8189 - val_conv1d_8_1_coeff_determination: 0.8159
# Epoch 57/500
# 89/90 [============================>.] - ETA: 0s - loss: 4.5428e-04 - conv1d_8_loss: 2.2709e-04 - conv1d_8_1_loss: 2.2718e-04 - conv1d_8_coeff_determination: 0.9846 - conv1d_8_1_coeff_determination: 0.9845
# Epoch 00057: loss improved from 0.00047 to 0.00045, saving model to best_weights.h5
# 90/90 [==============================] - 0s 5ms/step - loss: 4.5321e-04 - conv1d_8_loss: 2.2652e-04 - conv1d_8_1_loss: 2.2669e-04 - conv1d_8_coeff_determination: 0.9846 - conv1d_8_1_coeff_determination: 0.9845 - val_loss: 0.0031 - val_conv1d_8_loss: 0.0015 - val_conv1d_8_1_loss: 0.0016 - val_conv1d_8_coeff_determination: 0.8223 - val_conv1d_8_1_coeff_determination: 0.8176
# Epoch 58/500
# 77/90 [========================>.....] - ETA: 0s - loss: 4.6313e-04 - conv1d_8_loss: 2.3219e-04 - conv1d_8_1_loss: 2.3094e-04 - conv1d_8_coeff_determination: 0.9842 - conv1d_8_1_coeff_determination: 0.9842
# Epoch 00058: loss improved from 0.00045 to 0.00045, saving model to best_weights.h5
# 90/90 [==============================] - 0s 4ms/step - loss: 4.4716e-04 - conv1d_8_loss: 2.2398e-04 - conv1d_8_1_loss: 2.2317e-04 - conv1d_8_coeff_determination: 0.9847 - conv1d_8_1_coeff_determination: 0.9846 - val_loss: 0.0028 - val_conv1d_8_loss: 0.0014 - val_conv1d_8_1_loss: 0.0014 - val_conv1d_8_coeff_determination: 0.8425 - val_conv1d_8_1_coeff_determination: 0.8401
# Epoch 59/500
# 90/90 [==============================] - ETA: 0s - loss: 4.6798e-04 - conv1d_8_loss: 2.3285e-04 - conv1d_8_1_loss: 2.3513e-04 - conv1d_8_coeff_determination: 0.9842 - conv1d_8_1_coeff_determination: 0.9840
# Epoch 00059: loss did not improve from 0.00045
# 90/90 [==============================] - 1s 6ms/step - loss: 4.6798e-04 - conv1d_8_loss: 2.3285e-04 - conv1d_8_1_loss: 2.3513e-04 - conv1d_8_coeff_determination: 0.9842 - conv1d_8_1_coeff_determination: 0.9840 - val_loss: 0.0028 - val_conv1d_8_loss: 0.0014 - val_conv1d_8_1_loss: 0.0014 - val_conv1d_8_coeff_determination: 0.8428 - val_conv1d_8_1_coeff_determination: 0.8420
# Epoch 60/500
# 88/90 [============================>.] - ETA: 0s - loss: 4.0952e-04 - conv1d_8_loss: 2.0576e-04 - conv1d_8_1_loss: 2.0377e-04 - conv1d_8_coeff_determination: 0.9861 - conv1d_8_1_coeff_determination: 0.9861
# Epoch 00060: loss improved from 0.00045 to 0.00041, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 4.0824e-04 - conv1d_8_loss: 2.0508e-04 - conv1d_8_1_loss: 2.0316e-04 - conv1d_8_coeff_determination: 0.9861 - conv1d_8_1_coeff_determination: 0.9861 - val_loss: 0.0025 - val_conv1d_8_loss: 0.0012 - val_conv1d_8_1_loss: 0.0012 - val_conv1d_8_coeff_determination: 0.8534 - val_conv1d_8_1_coeff_determination: 0.8518
# Epoch 61/500
# ...
# Epoch 477/500
# 87/90 [============================>.] - ETA: 0s - loss: 6.6847e-06 - conv1d_8_loss: 3.1080e-06 - conv1d_8_1_loss: 3.5767e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998
# Epoch 00477: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 6.6157e-06 - conv1d_8_loss: 3.0767e-06 - conv1d_8_1_loss: 3.5390e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998 - val_loss: 9.2986e-04 - val_conv1d_8_loss: 4.5275e-04 - val_conv1d_8_1_loss: 4.7711e-04 - val_conv1d_8_coeff_determination: 0.9477 - val_conv1d_8_1_coeff_determination: 0.9448
# Epoch 478/500
# 87/90 [============================>.] - ETA: 0s - loss: 1.7569e-05 - conv1d_8_loss: 7.5499e-06 - conv1d_8_1_loss: 1.0019e-05 - conv1d_8_coeff_determination: 0.9995 - conv1d_8_1_coeff_determination: 0.9993
# Epoch 00478: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7534e-05 - conv1d_8_loss: 7.5619e-06 - conv1d_8_1_loss: 9.9723e-06 - conv1d_8_coeff_determination: 0.9995 - conv1d_8_1_coeff_determination: 0.9993 - val_loss: 9.2902e-04 - val_conv1d_8_loss: 4.5402e-04 - val_conv1d_8_1_loss: 4.7501e-04 - val_conv1d_8_coeff_determination: 0.9473 - val_conv1d_8_1_coeff_determination: 0.9448
# Epoch 479/500
# 86/90 [===========================>..] - ETA: 0s - loss: 8.7006e-06 - conv1d_8_loss: 3.9964e-06 - conv1d_8_1_loss: 4.7042e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9997
# Epoch 00479: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 8.6380e-06 - conv1d_8_loss: 3.9690e-06 - conv1d_8_1_loss: 4.6690e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9997 - val_loss: 8.4648e-04 - val_conv1d_8_loss: 4.1157e-04 - val_conv1d_8_1_loss: 4.3491e-04 - val_conv1d_8_coeff_determination: 0.9524 - val_conv1d_8_1_coeff_determination: 0.9496
# Epoch 480/500
# 84/90 [===========================>..] - ETA: 0s - loss: 2.1822e-05 - conv1d_8_loss: 9.5838e-06 - conv1d_8_1_loss: 1.2238e-05 - conv1d_8_coeff_determination: 0.9994 - conv1d_8_1_coeff_determination: 0.9992
# Epoch 00480: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 6ms/step - loss: 2.0787e-05 - conv1d_8_loss: 9.1484e-06 - conv1d_8_1_loss: 1.1638e-05 - conv1d_8_coeff_determination: 0.9994 - conv1d_8_1_coeff_determination: 0.9992 - val_loss: 9.4835e-04 - val_conv1d_8_loss: 4.6145e-04 - val_conv1d_8_1_loss: 4.8690e-04 - val_conv1d_8_coeff_determination: 0.9466 - val_conv1d_8_1_coeff_determination: 0.9436
# Epoch 481/500
# 85/90 [===========================>..] - ETA: 0s - loss: 9.2598e-06 - conv1d_8_loss: 4.1948e-06 - conv1d_8_1_loss: 5.0650e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9997
# Epoch 00481: loss did not improve from 0.00000
# 90/90 [==============================] - 1s 6ms/step - loss: 9.3054e-06 - conv1d_8_loss: 4.2016e-06 - conv1d_8_1_loss: 5.1038e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9997 - val_loss: 9.6793e-04 - val_conv1d_8_loss: 4.7408e-04 - val_conv1d_8_1_loss: 4.9385e-04 - val_conv1d_8_coeff_determination: 0.9466 - val_conv1d_8_1_coeff_determination: 0.9443
# Epoch 482/500
# 82/90 [==========================>...] - ETA: 0s - loss: 7.8279e-06 - conv1d_8_loss: 3.5141e-06 - conv1d_8_1_loss: 4.3138e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9997
# Epoch 00482: loss did not improve from 0.00000
# 90/90 [==============================] - 1s 6ms/step - loss: 7.4643e-06 - conv1d_8_loss: 3.3653e-06 - conv1d_8_1_loss: 4.0990e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9997 - val_loss: 0.0010 - val_conv1d_8_loss: 5.1097e-04 - val_conv1d_8_1_loss: 5.3739e-04 - val_conv1d_8_coeff_determination: 0.9420 - val_conv1d_8_1_coeff_determination: 0.9389
# Epoch 483/500
# 85/90 [===========================>..] - ETA: 0s - loss: 5.0914e-06 - conv1d_8_loss: 2.4408e-06 - conv1d_8_1_loss: 2.6506e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998
# Epoch 00483: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 5.0333e-06 - conv1d_8_loss: 2.4114e-06 - conv1d_8_1_loss: 2.6219e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998 - val_loss: 0.0010 - val_conv1d_8_loss: 4.8828e-04 - val_conv1d_8_1_loss: 5.1327e-04 - val_conv1d_8_coeff_determination: 0.9440 - val_conv1d_8_1_coeff_determination: 0.9411
# Epoch 484/500
# 85/90 [===========================>..] - ETA: 0s - loss: 4.8905e-06 - conv1d_8_loss: 2.3367e-06 - conv1d_8_1_loss: 2.5538e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998
# Epoch 00484: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 4.8105e-06 - conv1d_8_loss: 2.3024e-06 - conv1d_8_1_loss: 2.5081e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998 - val_loss: 0.0010 - val_conv1d_8_loss: 4.9196e-04 - val_conv1d_8_1_loss: 5.2157e-04 - val_conv1d_8_coeff_determination: 0.9434 - val_conv1d_8_1_coeff_determination: 0.9400
# Epoch 485/500
# 88/90 [============================>.] - ETA: 0s - loss: 1.2275e-05 - conv1d_8_loss: 5.3552e-06 - conv1d_8_1_loss: 6.9195e-06 - conv1d_8_coeff_determination: 0.9996 - conv1d_8_1_coeff_determination: 0.9995
# Epoch 00485: loss did not improve from 0.00000
# 90/90 [==============================] - 1s 6ms/step - loss: 1.3240e-05 - conv1d_8_loss: 5.7646e-06 - conv1d_8_1_loss: 7.4749e-06 - conv1d_8_coeff_determination: 0.9996 - conv1d_8_1_coeff_determination: 0.9995 - val_loss: 9.6746e-04 - val_conv1d_8_loss: 4.7008e-04 - val_conv1d_8_1_loss: 4.9739e-04 - val_conv1d_8_coeff_determination: 0.9465 - val_conv1d_8_1_coeff_determination: 0.9433
# Epoch 486/500
# 85/90 [===========================>..] - ETA: 0s - loss: 9.1933e-06 - conv1d_8_loss: 4.1908e-06 - conv1d_8_1_loss: 5.0025e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9997
# Epoch 00486: loss did not improve from 0.00000
# 90/90 [==============================] - 1s 8ms/step - loss: 8.9762e-06 - conv1d_8_loss: 4.0856e-06 - conv1d_8_1_loss: 4.8906e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9997 - val_loss: 0.0010 - val_conv1d_8_loss: 4.9540e-04 - val_conv1d_8_1_loss: 5.2337e-04 - val_conv1d_8_coeff_determination: 0.9435 - val_conv1d_8_1_coeff_determination: 0.9402
# Epoch 487/500
# 90/90 [==============================] - ETA: 0s - loss: 1.0876e-05 - conv1d_8_loss: 4.8334e-06 - conv1d_8_1_loss: 6.0425e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9996
# Epoch 00487: loss did not improve from 0.00000
# 90/90 [==============================] - 1s 6ms/step - loss: 1.0876e-05 - conv1d_8_loss: 4.8334e-06 - conv1d_8_1_loss: 6.0425e-06 - conv1d_8_coeff_determination: 0.9997 - conv1d_8_1_coeff_determination: 0.9996 - val_loss: 9.1256e-04 - val_conv1d_8_loss: 4.3759e-04 - val_conv1d_8_1_loss: 4.7497e-04 - val_conv1d_8_coeff_determination: 0.9498 - val_conv1d_8_1_coeff_determination: 0.9455
# Epoch 488/500
# 87/90 [============================>.] - ETA: 0s - loss: 2.5032e-05 - conv1d_8_loss: 1.0851e-05 - conv1d_8_1_loss: 1.4180e-05 - conv1d_8_coeff_determination: 0.9993 - conv1d_8_1_coeff_determination: 0.9991
# Epoch 00488: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 2.6538e-05 - conv1d_8_loss: 1.1455e-05 - conv1d_8_1_loss: 1.5083e-05 - conv1d_8_coeff_determination: 0.9992 - conv1d_8_1_coeff_determination: 0.9990 - val_loss: 8.2499e-04 - val_conv1d_8_loss: 4.0842e-04 - val_conv1d_8_1_loss: 4.1657e-04 - val_conv1d_8_coeff_determination: 0.9522 - val_conv1d_8_1_coeff_determination: 0.9512
# Epoch 489/500
# 89/90 [============================>.] - ETA: 0s - loss: 7.7799e-05 - conv1d_8_loss: 3.4194e-05 - conv1d_8_1_loss: 4.3605e-05 - conv1d_8_coeff_determination: 0.9977 - conv1d_8_1_coeff_determination: 0.9971
# Epoch 00489: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 7.7467e-05 - conv1d_8_loss: 3.4057e-05 - conv1d_8_1_loss: 4.3410e-05 - conv1d_8_coeff_determination: 0.9977 - conv1d_8_1_coeff_determination: 0.9971 - val_loss: 0.0013 - val_conv1d_8_loss: 6.1330e-04 - val_conv1d_8_1_loss: 6.5915e-04 - val_conv1d_8_coeff_determination: 0.9298 - val_conv1d_8_1_coeff_determination: 0.9245
# Epoch 490/500
# 89/90 [============================>.] - ETA: 0s - loss: 1.7365e-05 - conv1d_8_loss: 7.5981e-06 - conv1d_8_1_loss: 9.7673e-06 - conv1d_8_coeff_determination: 0.9995 - conv1d_8_1_coeff_determination: 0.9993
# Epoch 00490: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7324e-05 - conv1d_8_loss: 7.5806e-06 - conv1d_8_1_loss: 9.7430e-06 - conv1d_8_coeff_determination: 0.9995 - conv1d_8_1_coeff_determination: 0.9993 - val_loss: 0.0011 - val_conv1d_8_loss: 5.1976e-04 - val_conv1d_8_1_loss: 5.5054e-04 - val_conv1d_8_coeff_determination: 0.9407 - val_conv1d_8_1_coeff_determination: 0.9371
# Epoch 491/500
# 90/90 [==============================] - ETA: 0s - loss: 1.9384e-05 - conv1d_8_loss: 8.6214e-06 - conv1d_8_1_loss: 1.0762e-05 - conv1d_8_coeff_determination: 0.9994 - conv1d_8_1_coeff_determination: 0.9993
# Epoch 00491: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 1.9384e-05 - conv1d_8_loss: 8.6214e-06 - conv1d_8_1_loss: 1.0762e-05 - conv1d_8_coeff_determination: 0.9994 - conv1d_8_1_coeff_determination: 0.9993 - val_loss: 0.0010 - val_conv1d_8_loss: 4.9118e-04 - val_conv1d_8_1_loss: 5.1716e-04 - val_conv1d_8_coeff_determination: 0.9432 - val_conv1d_8_1_coeff_determination: 0.9402
# Epoch 492/500
# 82/90 [==========================>...] - ETA: 0s - loss: 1.5234e-05 - conv1d_8_loss: 6.8593e-06 - conv1d_8_1_loss: 8.3745e-06 - conv1d_8_coeff_determination: 0.9996 - conv1d_8_1_coeff_determination: 0.9995
# Epoch 00492: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 4ms/step - loss: 1.4538e-05 - conv1d_8_loss: 6.5472e-06 - conv1d_8_1_loss: 7.9908e-06 - conv1d_8_coeff_determination: 0.9996 - conv1d_8_1_coeff_determination: 0.9995 - val_loss: 9.5153e-04 - val_conv1d_8_loss: 4.6317e-04 - val_conv1d_8_1_loss: 4.8836e-04 - val_conv1d_8_coeff_determination: 0.9468 - val_conv1d_8_1_coeff_determination: 0.9439
# Epoch 493/500
# 80/90 [=========================>....] - ETA: 0s - loss: 5.5703e-06 - conv1d_8_loss: 2.5660e-06 - conv1d_8_1_loss: 3.0043e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998
# Epoch 00493: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 4ms/step - loss: 5.4508e-06 - conv1d_8_loss: 2.5114e-06 - conv1d_8_1_loss: 2.9393e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9998 - val_loss: 0.0010 - val_conv1d_8_loss: 5.0510e-04 - val_conv1d_8_1_loss: 5.3259e-04 - val_conv1d_8_coeff_determination: 0.9422 - val_conv1d_8_1_coeff_determination: 0.9389
# Epoch 494/500
# 87/90 [============================>.] - ETA: 0s - loss: 3.7790e-06 - conv1d_8_loss: 1.8045e-06 - conv1d_8_1_loss: 1.9745e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9999
# Epoch 00494: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 3.7641e-06 - conv1d_8_loss: 1.7990e-06 - conv1d_8_1_loss: 1.9651e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9999 - val_loss: 9.4920e-04 - val_conv1d_8_loss: 4.5999e-04 - val_conv1d_8_1_loss: 4.8921e-04 - val_conv1d_8_coeff_determination: 0.9472 - val_conv1d_8_1_coeff_determination: 0.9438
# Epoch 495/500
# 84/90 [===========================>..] - ETA: 0s - loss: 4.6375e-06 - conv1d_8_loss: 2.1603e-06 - conv1d_8_1_loss: 2.4772e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9998
# Epoch 00495: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 4.6175e-06 - conv1d_8_loss: 2.1515e-06 - conv1d_8_1_loss: 2.4660e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9998 - val_loss: 9.1229e-04 - val_conv1d_8_loss: 4.4381e-04 - val_conv1d_8_1_loss: 4.6847e-04 - val_conv1d_8_coeff_determination: 0.9493 - val_conv1d_8_1_coeff_determination: 0.9464
# Epoch 496/500
# 83/90 [==========================>...] - ETA: 0s - loss: 4.8405e-06 - conv1d_8_loss: 2.2421e-06 - conv1d_8_1_loss: 2.5983e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9998
# Epoch 00496: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 4.6880e-06 - conv1d_8_loss: 2.1818e-06 - conv1d_8_1_loss: 2.5062e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9998 - val_loss: 9.9824e-04 - val_conv1d_8_loss: 4.8533e-04 - val_conv1d_8_1_loss: 5.1291e-04 - val_conv1d_8_coeff_determination: 0.9444 - val_conv1d_8_1_coeff_determination: 0.9412
# Epoch 497/500
# 83/90 [==========================>...] - ETA: 0s - loss: 3.4674e-06 - conv1d_8_loss: 1.6446e-06 - conv1d_8_1_loss: 1.8228e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9999
# Epoch 00497: loss improved from 0.00000 to 0.00000, saving model to best_weights.h5
# 90/90 [==============================] - 1s 6ms/step - loss: 3.5217e-06 - conv1d_8_loss: 1.6666e-06 - conv1d_8_1_loss: 1.8551e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9999 - val_loss: 9.4595e-04 - val_conv1d_8_loss: 4.5963e-04 - val_conv1d_8_1_loss: 4.8632e-04 - val_conv1d_8_coeff_determination: 0.9469 - val_conv1d_8_1_coeff_determination: 0.9437
# Epoch 498/500
# 84/90 [===========================>..] - ETA: 0s - loss: 6.9201e-06 - conv1d_8_loss: 3.0162e-06 - conv1d_8_1_loss: 3.9039e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9997
# Epoch 00498: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 7.7831e-06 - conv1d_8_loss: 3.3829e-06 - conv1d_8_1_loss: 4.4002e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9997 - val_loss: 9.8047e-04 - val_conv1d_8_loss: 4.7400e-04 - val_conv1d_8_1_loss: 5.0647e-04 - val_conv1d_8_coeff_determination: 0.9445 - val_conv1d_8_1_coeff_determination: 0.9407
# Epoch 499/500
# 80/90 [=========================>....] - ETA: 0s - loss: 7.3348e-06 - conv1d_8_loss: 3.4087e-06 - conv1d_8_1_loss: 3.9261e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9997
# Epoch 00499: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 7.0927e-06 - conv1d_8_loss: 3.2993e-06 - conv1d_8_1_loss: 3.7934e-06 - conv1d_8_coeff_determination: 0.9998 - conv1d_8_1_coeff_determination: 0.9997 - val_loss: 9.3843e-04 - val_conv1d_8_loss: 4.5784e-04 - val_conv1d_8_1_loss: 4.8059e-04 - val_conv1d_8_coeff_determination: 0.9472 - val_conv1d_8_1_coeff_determination: 0.9445
# Epoch 500/500
# 89/90 [============================>.] - ETA: 0s - loss: 4.0825e-06 - conv1d_8_loss: 1.9322e-06 - conv1d_8_1_loss: 2.1503e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9999
# Epoch 00500: loss did not improve from 0.00000
# 90/90 [==============================] - 0s 5ms/step - loss: 4.0697e-06 - conv1d_8_loss: 1.9272e-06 - conv1d_8_1_loss: 2.1425e-06 - conv1d_8_coeff_determination: 0.9999 - conv1d_8_1_coeff_determination: 0.9999 - val_loss: 9.9656e-04 - val_conv1d_8_loss: 4.8446e-04 - val_conv1d_8_1_loss: 5.1210e-04 - val_conv1d_8_coeff_determination: 0.9446 - val_conv1d_8_1_coeff_determination: 0.9413

# %% [markdown]
# ### Check accuracy of Autoencoder

# %%
import matplotlib.pyplot as plt
model.load_weights(weights_filepath)
recoded_1 = model.predict(snapshots_train)[0]

for i in range(0,snapshots_train.shape[0],50):
    plt.figure(figsize=(7,6))
    plt.plot(snapshots_train[i,:,0:],label='Truth',linewidth=3)
    plt.plot(recoded_1[i,:,0:],'ro',label='Reconstructed')
    plt.xlabel('x')
    plt.ylabel('u')
    plt.ylim((0,0.5))
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ### Check accuracy of Autoencoder+LSTM

# %%
import matplotlib.pyplot as plt
model.load_weights(weights_filepath)
recoded_1 = model.predict(snapshots_train)[1]

for i in range(0,snapshots_train.shape[0],50):
    plt.figure(figsize=(7,6))
    plt.plot(snapshots_train[i+1,:,0:],label='Truth',linewidth=3)
    plt.plot(recoded_1[i,:,0:],'ro',label='Reconstructed')
    plt.xlabel('x')
    plt.ylabel('u')
    plt.ylim((0,0.5))
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# ### Get encoded representation

# %%
get_latent_representation = K.function([model.layers[0].input],
                                  [model.layers[12].output]) # Layer number 10 is the MaxPooling2D before entry to LSTM
layer_output = get_latent_representation([snapshots_train])[0]

# %%
plt.figure()
plt.plot(layer_output[:,0],label='Dimension 1')
plt.plot(layer_output[:,1],label='Dimension 2')
plt.legend()
plt.show()

# %%
np.save('Latent.npy',layer_output)
